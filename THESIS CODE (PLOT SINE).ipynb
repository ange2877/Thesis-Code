# %%
type 1 sine

# %%
import sympy as sp

# Define symbols
x, y, t, u, k, a, b, i = sp.symbols('x y t u k a b i')

# Evaluate coefficients (modify as needed)
#k = 1
#u = -1
#a = 1
#b = sp.E  # Base of natural logarithm
#y = 0  # Can be changed if needed

# Define the polylogarithm function Li_k(x)
def Li_k(x, k_val, n_terms=10):
    return sum((x**n)/(n**k_val) for n in range(1, n_terms+1))

# Define the cosine function using Euler's formula
def sp_sin(y_val, t_val):
    return (sp.exp(i * y_val * t_val) - sp.exp(-i * y_val * t_val)) / (2 * i)

# Define the generating function exactly as in the image
numerator = Li_k(1 - (a*b)**(-(1-u)*t), k)
denominator = t * sp.ln(a*b) * (b**(2*t) - u*a**(-t))
generating_function = (numerator / denominator) * sp.sin(y*t)

# Number of terms to compute
n_terms = 6

# Compute Taylor series expansion
taylor_series = sp.series(generating_function, t, 0, n_terms).removeO()

# List to store the tangent numbers
tangent_number = []

# Compute coefficients
for n in range(n_terms):
    coeff = taylor_series.coeff(t, n)
    T_n = coeff * sp.factorial(n)
    tangent_number.append(sp.simplify(T_n))

# Generate and display the generalized polynomials
print("\nGeneralized polynomials:")
polynomials = []
for n in range(n_terms):
    poly = sum(sp.binomial(n, m) * x**(n-m) * tangent_number[m] for m in range(n+1))
    simplified = sp.simplify(poly)
    polynomials.append(simplified)
    print(f"T_{n,1}^({k})(x,y;{u},{a},{b}) = {simplified}")
# Out:
# Generalized polynomials:
# T_(0, 1)^(k)(x,y;u,a,b) = 0
# T_(1, 1)^(k)(x,y;u,a,b) = y
# T_(2, 1)^(k)(x,y;u,a,b) = y*(2**k*(u**2 - 2*u + 1)*log(a*b) + 2**(k + 1)*x*(u - 1) + 2**(k + 1)*(u*log(a) + 2*log(b)) - 2*(u - 1)**2*log(a*b))/(2**k*(u - 1))
# T_(3, 1)^(k)(x,y;u,a,b) = y*(3*12**k*x**2*(u - 1)**2 + 2**k*(6*2**k*(u - 1)**4*log(a*b)**2 - 6*3**k*(u - 1)**2*(u*log(a) + (u**2 - 2*u + 1)*log(a*b) + 2*log(b))*log(a*b) + 6**k*(u - 1)*(u**3*log(a*b)**2 - 3*u**2*log(a*b)**2 - u*y**2 + 3*u*log(a*b)**2 + y**2 - log(a*b)**2) + 3*6**k*(u*log(a) + 2*log(b))*(u**2 - 2*u + 1)*log(a*b) + 3*6**k*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)) + 3*6**k*x*(u - 1)*(2*2**k*(u*log(a) + 2*log(b)) + 2**k*(u**2 - 2*u + 1)*log(a*b) - 2*(u - 1)**2*log(a*b)))/(12**k*(u - 1)**2)
# ...

# %%
type 1 plot sine

# %%
from sympy import log  
import sympy as sp
import matplotlib.pyplot as plt

# Define the symbols
x, y, u, k, a, b, i = sp.symbols('x y u k a b i')

# Define the polynomial
polynomial =   y*(30*179159040**k*x**3*(u - 1)**3*(2*2**k*(u*log(a) + 2*log(b)) + 2**k*(u**2 - 2*u + 1)*log(a*b) - 2*(u - 1)**2*log(a*b)) + 15*358318080**k*x**4*(u - 1)**4 + 30*59719680**k*x**2*(u - 1)**2*(6*2**k*(u - 1)**4*log(a*b)**2 - 6*3**k*(u - 1)**2*(u*log(a) + (u**2 - 2*u + 1)*log(a*b) + 2*log(b))*log(a*b) + 6**k*(u - 1)*(u**3*log(a*b)**2 - 3*u**2*log(a*b)**2 - u*y**2 + 3*u*log(a*b)**2 + y**2 - log(a*b)**2) + 3*6**k*(u*log(a) + 2*log(b))*(u**2 - 2*u + 1)*log(a*b) + 3*6**k*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)) + 15*622080**k*x*(u - 1)*(-24*12**(2*k)*(u - 1)**6*log(a*b)**3 + 24*192**k*(u - 1)**4*(u*log(a) + 2*log(b))*log(a*b)**2 + 36*192**k*(u - 1)**4*(u**2 - 2*u + 1)*log(a*b)**3 + 4*288**k*y**2*(u - 1)**4*log(a*b) - 24*288**k*(u - 1)**2*(u*log(a) + 2*log(b))*(u**2 - 2*u + 1)*log(a*b)**2 + 2*288**k*(u - 1)**2*(12*u*(u - 1)**2 - 4*(u - 1)*(u**3 - 1) - 3*(u**2 - 2*u + 1)**2)*log(a*b)**3 - 12*288**k*(u - 1)**2*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b) + 576**k*(u - 1)**2*(u**4*log(a*b)**2 - 4*u**3*log(a*b)**2 - 2*u**2*y**2 + 6*u**2*log(a*b)**2 + 4*u*y**2 - 4*u*log(a*b)**2 - 2*y**2 + log(a*b)**2)*log(a*b) + 4*576**k*(u - 1)*(u*log(a) + 2*log(b))*(u**3*log(a*b)**2 - 3*u**2*log(a*b)**2 - u*y**2 + 3*u*log(a*b)**2 + y**2 - log(a*b)**2) + 6*576**k*(u**2 - 2*u + 1)*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b) + 4*576**k*(u*(u - 1)**2*log(a)**3 + 8*(u - 1)**2*log(b)**3 + 6*(u*log(a) + 2*log(b))**3 - 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))) + 6912**k*(360*10368**k*(u - 1)**8*log(a*b)**4 - 360*12960**k*(u - 1)**6*(u*log(a) + 2*(u**2 - 2*u + 1)*log(a*b) + 2*log(b))*log(a*b)**3 - 60*17280**k*y**2*(u - 1)**6*log(a*b)**2 + 540*17280**k*(u - 1)**4*(u*log(a) + 2*log(b))*(u**2 - 2*u + 1)*log(a*b)**3 + 90*17280**k*(u - 1)**4*(2*(u - 1)*(u**3 - 3*u**2 + 3*u - 1) + 3*(u**2 - 2*u + 1)**2)*log(a*b)**4 + 180*17280**k*(u - 1)**4*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b)**2 + 60*25920**k*y**2*(u - 1)**4*(u*log(a) + (u**2 - 2*u + 1)*log(a*b) + 2*log(b))*log(a*b) + 30*25920**k*(u - 1)**3*(6*u**2*(1 - u) + 4*u*(u - 1)*(u**2 + 1) - (u - 1)*(u**4 + 1) + 2*(u**2 - 2*u + 1)*(-u**3 + 3*u*(u - 1) + 1))*log(a*b)**4 - 30*25920**k*(u - 1)**2*(u*log(a) + 2*log(b))*(-12*u*(u - 1)**2 + 4*(u - 1)*(u**3 - 1) + 3*(u**2 - 2*u + 1)**2)*log(a*b)**3 - 180*25920**k*(u - 1)**2*(u**2 - 2*u + 1)*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b)**2 - 60*25920**k*(u - 1)**2*(u*(u - 1)**2*log(a)**3 + 8*(u - 1)**2*log(b)**3 + 6*(u*log(a) + 2*log(b))**3 - 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))*log(a*b) + 10*51840**k*y**2*(1 - u**3)*(u - 1)**3*log(a*b)**2 + 3*51840**k*(u - 1)**3*(u**5*log(a*b)**4 - 5*u**4*log(a*b)**4 + 10*u**3*log(a*b)**4 + 10*u**2*y**2*log(a*b)**2 - 10*u**2*log(a*b)**4 + u*y**4 - 10*u*y**2*log(a*b)**2 + 5*u*log(a*b)**4 - y**4 - log(a*b)**4) + 15*51840**k*(u - 1)**2*(u*log(a) + 2*log(b))*(u**4*log(a*b)**2 - 4*u**3*log(a*b)**2 - 2*u**2*y**2 + 6*u**2*log(a*b)**2 + 4*u*y**2 - 4*u*log(a*b)**2 - 2*y**2 + log(a*b)**2)*log(a*b) + 30*51840**k*(u - 1)*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*(u**3*log(a*b)**2 - 3*u**2*log(a*b)**2 - u*y**2 + 3*u*log(a*b)**2 + y**2 - log(a*b)**2) + 30*51840**k*(u**2 - 2*u + 1)*(u*(u - 1)**2*log(a)**3 + 8*(u - 1)**2*log(b)**3 + 6*(u*log(a) + 2*log(b))**3 - 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))*log(a*b) + 15*51840**k*(-u*(u - 1)**3*log(a)**4 + 16*(u - 1)**3*log(b)**4 + 8*(u - 1)**2*(u*log(a) + 2*log(b))*(u*log(a)**3 + 8*log(b)**3) + 6*(u - 1)**2*(u*log(a)**2 - 4*log(b)**2)**2 + 36*(u - 1)*(u*log(a) + 2*log(b))**2*(-u*log(a)**2 + 4*log(b)**2) + 24*(u*log(a) + 2*log(b))**4)))/(3*358318080**k*(u - 1)**4)

# Substitute i with the imaginary unit (1j)
polynomial = polynomial.subs(i, 1j)

# Function to plot zeros for given parameter values
def plot_zeros(poly, k_value, u_value, a_value, b_value, x_value, x_range=(-30, 30), y_range=(-30, 30), title=""):
    # Substitute the parameter values
    poly_at_values = poly.subs({k: k_value, u: u_value, a: a_value, b: b_value, x: x_value})
    
    try:
        # Calculate the roots
        roots = sp.solveset(poly_at_values, y, domain=sp.S.Complexes)
        
        # Convert to numerical roots
        roots_list = list(sp.nroots(poly_at_values, n=15))
        
        # Separate real and imaginary parts
        real_parts = [root.as_real_imag()[0] for root in roots_list]
        imag_parts = [root.as_real_imag()[1] for root in roots_list]
        
        # Plot the zeros
        plt.figure(figsize=(10, 8))
        plt.scatter(real_parts, imag_parts, color='blue', marker='o', s=200, label='Zeros')
        plt.axhline(0, color='black', linewidth=1)
        plt.axvline(0, color='black', linewidth=1)
        plt.xlim(x_range[0], x_range[1])
        plt.ylim(y_range[0], y_range[1])
        plt.xlabel("Real Part")
        plt.ylabel("Imaginary Part")
        plt.title(title)
        plt.grid(True)
        plt.show()
    except Exception as e:
        print(f"Error plotting for x={x_value}: {str(e)}")

# Example plots with different parameter values
plot_zeros(polynomial, k_value=2, u_value=-2, a_value=-1, b_value=1, x_value=-3,
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=-3)")
plot_zeros(polynomial, k_value=2, u_value=-2, a_value=-1, b_value=1, x_value=-1, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=-1)")
plot_zeros(polynomial, k_value=2, u_value=2, a_value=-1, b_value=1, x_value=1, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=1)")
plot_zeros(polynomial, k_value=1, u_value=2, a_value=-1, b_value=1, x_value=3, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2,  a=1, b=-1, x=3)")

# %%
saving into png

# %%
from sympy import log  
import sympy as sp
import matplotlib.pyplot as plt

# Define the symbols
x, y, u, k, a, b, i = sp.symbols('x y u k a b i')

# Define the polynomial
polynomial =   y*(30*179159040**k*x**3*(u - 1)**3*(2*2**k*(u*log(a) + 2*log(b)) + 2**k*(u**2 - 2*u + 1)*log(a*b) - 2*(u - 1)**2*log(a*b)) + 15*358318080**k*x**4*(u - 1)**4 + 30*59719680**k*x**2*(u - 1)**2*(6*2**k*(u - 1)**4*log(a*b)**2 - 6*3**k*(u - 1)**2*(u*log(a) + (u**2 - 2*u + 1)*log(a*b) + 2*log(b))*log(a*b) + 6**k*(u - 1)*(u**3*log(a*b)**2 - 3*u**2*log(a*b)**2 - u*y**2 + 3*u*log(a*b)**2 + y**2 - log(a*b)**2) + 3*6**k*(u*log(a) + 2*log(b))*(u**2 - 2*u + 1)*log(a*b) + 3*6**k*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)) + 15*622080**k*x*(u - 1)*(-24*12**(2*k)*(u - 1)**6*log(a*b)**3 + 24*192**k*(u - 1)**4*(u*log(a) + 2*log(b))*log(a*b)**2 + 36*192**k*(u - 1)**4*(u**2 - 2*u + 1)*log(a*b)**3 + 4*288**k*y**2*(u - 1)**4*log(a*b) - 24*288**k*(u - 1)**2*(u*log(a) + 2*log(b))*(u**2 - 2*u + 1)*log(a*b)**2 + 2*288**k*(u - 1)**2*(12*u*(u - 1)**2 - 4*(u - 1)*(u**3 - 1) - 3*(u**2 - 2*u + 1)**2)*log(a*b)**3 - 12*288**k*(u - 1)**2*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b) + 576**k*(u - 1)**2*(u**4*log(a*b)**2 - 4*u**3*log(a*b)**2 - 2*u**2*y**2 + 6*u**2*log(a*b)**2 + 4*u*y**2 - 4*u*log(a*b)**2 - 2*y**2 + log(a*b)**2)*log(a*b) + 4*576**k*(u - 1)*(u*log(a) + 2*log(b))*(u**3*log(a*b)**2 - 3*u**2*log(a*b)**2 - u*y**2 + 3*u*log(a*b)**2 + y**2 - log(a*b)**2) + 6*576**k*(u**2 - 2*u + 1)*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b) + 4*576**k*(u*(u - 1)**2*log(a)**3 + 8*(u - 1)**2*log(b)**3 + 6*(u*log(a) + 2*log(b))**3 - 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))) + 6912**k*(360*10368**k*(u - 1)**8*log(a*b)**4 - 360*12960**k*(u - 1)**6*(u*log(a) + 2*(u**2 - 2*u + 1)*log(a*b) + 2*log(b))*log(a*b)**3 - 60*17280**k*y**2*(u - 1)**6*log(a*b)**2 + 540*17280**k*(u - 1)**4*(u*log(a) + 2*log(b))*(u**2 - 2*u + 1)*log(a*b)**3 + 90*17280**k*(u - 1)**4*(2*(u - 1)*(u**3 - 3*u**2 + 3*u - 1) + 3*(u**2 - 2*u + 1)**2)*log(a*b)**4 + 180*17280**k*(u - 1)**4*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b)**2 + 60*25920**k*y**2*(u - 1)**4*(u*log(a) + (u**2 - 2*u + 1)*log(a*b) + 2*log(b))*log(a*b) + 30*25920**k*(u - 1)**3*(6*u**2*(1 - u) + 4*u*(u - 1)*(u**2 + 1) - (u - 1)*(u**4 + 1) + 2*(u**2 - 2*u + 1)*(-u**3 + 3*u*(u - 1) + 1))*log(a*b)**4 - 30*25920**k*(u - 1)**2*(u*log(a) + 2*log(b))*(-12*u*(u - 1)**2 + 4*(u - 1)*(u**3 - 1) + 3*(u**2 - 2*u + 1)**2)*log(a*b)**3 - 180*25920**k*(u - 1)**2*(u**2 - 2*u + 1)*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b)**2 - 60*25920**k*(u - 1)**2*(u*(u - 1)**2*log(a)**3 + 8*(u - 1)**2*log(b)**3 + 6*(u*log(a) + 2*log(b))**3 - 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))*log(a*b) + 10*51840**k*y**2*(1 - u**3)*(u - 1)**3*log(a*b)**2 + 3*51840**k*(u - 1)**3*(u**5*log(a*b)**4 - 5*u**4*log(a*b)**4 + 10*u**3*log(a*b)**4 + 10*u**2*y**2*log(a*b)**2 - 10*u**2*log(a*b)**4 + u*y**4 - 10*u*y**2*log(a*b)**2 + 5*u*log(a*b)**4 - y**4 - log(a*b)**4) + 15*51840**k*(u - 1)**2*(u*log(a) + 2*log(b))*(u**4*log(a*b)**2 - 4*u**3*log(a*b)**2 - 2*u**2*y**2 + 6*u**2*log(a*b)**2 + 4*u*y**2 - 4*u*log(a*b)**2 - 2*y**2 + log(a*b)**2)*log(a*b) + 30*51840**k*(u - 1)*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*(u**3*log(a*b)**2 - 3*u**2*log(a*b)**2 - u*y**2 + 3*u*log(a*b)**2 + y**2 - log(a*b)**2) + 30*51840**k*(u**2 - 2*u + 1)*(u*(u - 1)**2*log(a)**3 + 8*(u - 1)**2*log(b)**3 + 6*(u*log(a) + 2*log(b))**3 - 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))*log(a*b) + 15*51840**k*(-u*(u - 1)**3*log(a)**4 + 16*(u - 1)**3*log(b)**4 + 8*(u - 1)**2*(u*log(a) + 2*log(b))*(u*log(a)**3 + 8*log(b)**3) + 6*(u - 1)**2*(u*log(a)**2 - 4*log(b)**2)**2 + 36*(u - 1)*(u*log(a) + 2*log(b))**2*(-u*log(a)**2 + 4*log(b)**2) + 24*(u*log(a) + 2*log(b))**4)))/(3*358318080**k*(u - 1)**4)

# Substitute i with the imaginary unit (1j)
polynomial = polynomial.subs(i, 1j)

# Function to plot zeros for given parameter values
def plot_zeros(poly, k_value, u_value, a_value, b_value, x_value, x_range=(-30, 30), y_range=(-30, 30), title=""):
    # Substitute the parameter values
    poly_at_values = poly.subs({k: k_value, u: u_value, a: a_value, b: b_value, x: x_value})
    
    try:
        # Calculate the roots
        roots = sp.solveset(poly_at_values, y, domain=sp.S.Complexes)
        
        # Convert to numerical roots
        roots_list = list(sp.nroots(poly_at_values, n=15))
        
        # Separate real and imaginary parts
        real_parts = [root.as_real_imag()[0] for root in roots_list]
        imag_parts = [root.as_real_imag()[1] for root in roots_list]
        
        # Plot the zeros
        plt.figure(figsize=(10, 8))
        plt.scatter(real_parts, imag_parts, color='blue', marker='o', s=200, label='Zeros')
        plt.axhline(0, color='black', linewidth=1)
        plt.axvline(0, color='black', linewidth=1)
        plt.xlim(x_range[0], x_range[1])
        plt.ylim(y_range[0], y_range[1])
        plt.xlabel("Real Part")
        plt.ylabel("Imaginary Part")
        plt.title(title)
        plt.grid(True)

        # Create a filename from the parameters
        filename = f"zeros_k_{k_value}_u_{u_value}_a_{a_value}_b_{b_value}_x_{x_value}.png"
    
        # Save the figure
        plt.savefig(filename, bbox_inches='tight', dpi=300)
        plt.close()  # Close the figure to free memory
        
    except Exception as e:
        print(f"Error plotting for y={y_value}: {str(e)}")
        
# Example plots with different parameter values
plot_zeros(polynomial, k_value=2, u_value=-2, a_value=-1, b_value=1, x_value=-3,
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=-3)")
plot_zeros(polynomial, k_value=2, u_value=-2, a_value=-1, b_value=1, x_value=-1, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=-1)")
plot_zeros(polynomial, k_value=2, u_value=2, a_value=-1, b_value=1, x_value=1, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=1)")
plot_zeros(polynomial, k_value=1, u_value=2, a_value=-1, b_value=1, x_value=3, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2,  a=1, b=-1, x=3)")

# %%
type 2 sine

# %%
import sympy as sp

# Define symbols
x, y, t, u, k, a, b, i = sp.symbols('x y t u k a b i')

# Evaluate coefficients (modify as needed)
#k = 1
#u = -1
#a = 1
#b = sp.E  # Base of natural logarithm
#y = 0  # Can be changed if needed

# Define the polyexponential function Ei_k(x)
def Ei_k(x, k, n_terms=10):
    return sum((x**n) / (n**k * sp.factorial(n-1)) for n in range(1, n_terms + 1))

# Define the cosine function using Euler's formula
def sp_sin(y_val, t_val):
    return (sp.exp(i * y_val * t_val) - sp.exp(-i * y_val * t_val)) / (2 * i)

# Define the generating function exactly as in the image
numerator = Ei_k(sp.log(1 + (1 - u)*t*sp.ln(a*b)), k)
denominator = t * sp.ln(a*b) * (b**(2*t) - u*a**(-t))
generating_function = (numerator / denominator) * sp.sin(y*t)

# Number of terms to compute
n_terms = 6

# Compute Taylor series expansion
taylor_series = sp.series(generating_function, t, 0, n_terms).removeO()

# List to store the tangent numbers
tangent_number = []

# Compute coefficients
for n in range(n_terms):
    coeff = taylor_series.coeff(t, n)
    T_n = coeff * sp.factorial(n)
    tangent_number.append(sp.simplify(T_n))


# Generate and display the generalized polynomials
print("\nGeneralized polynomials:")
polynomials = []
for n in range(n_terms):
    poly = sum(sp.binomial(n, m) * x**(n-m) * tangent_number[m] for m in range(n+1))
    simplified = sp.simplify(poly)
    polynomials.append(simplified)
    print(f"T_{n,1}^({k})(x,y;{u},{a},{b}) = {simplified}")
# Out:
# Generalized polynomials:
# T_(0, 1)^(k)(x,y;u,a,b) = 0
# T_(1, 1)^(k)(x,y;u,a,b) = y
# T_(2, 1)^(k)(x,y;u,a,b) = y*(2**k*(u - 1)**2*log(a*b) + 2**(k + 1)*x*(u - 1) + 2**(k + 1)*(u*log(a) + 2*log(b)) - 2*(u - 1)**2*log(a*b))/(2**k*(u - 1))
# T_(3, 1)^(k)(x,y;u,a,b) = y*(3*12**k*x*(u - 1)*(2**k*(u - 1)**2*log(a*b) + 2**(k + 1)*(u*log(a) + 2*log(b)) - 2*(u - 1)**2*log(a*b)) + 2**k*(12**k*(u - 1)**2*(-y**2 + 2*(u - 1)**2*log(a*b)**2) + 3*12**k*(u - 1)**2*(u*log(a) + 2*log(b))*log(a*b) + 12**k*(-3*u*(u - 1)*log(a)**2 + (12*u - 12)*log(b)**2 + 6*(u*log(a) + 2*log(b))**2) + 3*4**k*(u - 1)**4*log(a*b)**2 - 6**(k + 1)*(u - 1)**4*log(a*b)**2 - 6**(k + 1)*(u - 1)**2*(u*log(a) + 2*log(b))*log(a*b)) + 3*24**k*x**2*(u - 1)**2)/(24**k*(u - 1)**2)
# ...

# %%
plot type 2 sine

# %%
from sympy import log  
import sympy as sp
import matplotlib.pyplot as plt

# Define the symbols
x, y, u, k, a, b, i = sp.symbols('x y u k a b i')

# Define the polynomial
polynomial =  y*(-13824**k*(120*103680**k*(u - 1)**8*log(a*b)**4 + 60*103680**k*(u - 1)**6*(u*log(a) + 2*log(b))*log(a*b)**3 + 30*138240**k*y**2*(u - 1)**6*log(a*b)**2 - 315*138240**k*(u - 1)**8*log(a*b)**4 - 270*138240**k*(u - 1)**6*(u*log(a) + 2*log(b))*log(a*b)**3 + 90*138240**k*(u - 1)**4*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2 - 2*(u*log(a) + 2*log(b))**2)*log(a*b)**2 - 60*207360**k*y**2*(u - 1)**6*log(a*b)**2 - 60*207360**k*y**2*(u - 1)**4*(u*log(a) + 2*log(b))*log(a*b) + 300*207360**k*(u - 1)**8*log(a*b)**4 + 330*207360**k*(u - 1)**6*(u*log(a) + 2*log(b))*log(a*b)**3 + 180*207360**k*(u - 1)**4*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b)**2 + 60*207360**k*(u - 1)**2*(u*(u - 1)**2*log(a)**3 + 8*(u - 1)**2*log(b)**3 + 6*(u*log(a) + 2*log(b))**3 - 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))*log(a*b) + 30*414720**k*(u - 1)**4*(y**2 - 3*(u - 1)**2*log(a*b)**2)*(u*log(a) + 2*log(b))*log(a*b) + 414720**k*(u - 1)**4*(-3*y**4 + 20*y**2*(u - 1)**2*log(a*b)**2 - 72*(u - 1)**4*log(a*b)**4) + 30*414720**k*(u - 1)**2*(y**2 - 2*(u - 1)**2*log(a*b)**2)*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2) - 30*414720**k*(u - 1)**2*(u*(u - 1)**2*log(a)**3 + 8*(u - 1)**2*log(b)**3 + 6*(u*log(a) + 2*log(b))**3 - 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))*log(a*b) + 15*414720**k*(u*(u - 1)**3*log(a)**4 - 16*(u - 1)**3*log(b)**4 - 8*(u - 1)**2*(u*log(a) + 2*log(b))*(u*log(a)**3 + 8*log(b)**3) - 6*(u - 1)**2*(u*log(a)**2 - 4*log(b)**2)**2 - 24*(u*log(a) + 2*log(b))**4 + 36*(u*log(a) + 2*log(b))**2*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2)) - 15*82944**k*(u - 1)**8*log(a*b)**4) + 30*2866544640**k*x**3*(u - 1)**3*(2**k*(u - 1)**2*log(a*b) + 2*2**k*(u*log(a) + 2*log(b)) - 2*(u - 1)**2*log(a*b)) + 30*477757440**k*x**2*(u - 1)**2*(-12**k*(u - 1)**2*(y**2 - 2*(u - 1)**2*log(a*b)**2) + 3*12**k*(u - 1)**2*(u*log(a) + 2*log(b))*log(a*b) + 3*12**k*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2) + 3*4**k*(u - 1)**4*log(a*b)**2 - 6*6**k*(u - 1)**4*log(a*b)**2 - 6*6**k*(u - 1)**2*(u*log(a) + 2*log(b))*log(a*b)) + 15*5733089280**k*x**4*(u - 1)**4 - 30*9953280**k*x*(u - 1)*(2*144**k*(u - 1)**6*log(a*b)**3 - 9*192**k*(u - 1)**6*log(a*b)**3 - 6*192**k*(u - 1)**4*(u*log(a) + 2*log(b))*log(a*b)**2 - 2*288**k*y**2*(u - 1)**4*log(a*b) + 11*288**k*(u - 1)**6*log(a*b)**3 + 12*288**k*(u - 1)**4*(u*log(a) + 2*log(b))*log(a*b)**2 + 6*288**k*(u - 1)**2*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b) + 576**k*(u - 1)**4*(y**2 - 3*(u - 1)**2*log(a*b)**2)*log(a*b) + 2*576**k*(u - 1)**2*(y**2 - 2*(u - 1)**2*log(a*b)**2)*(u*log(a) + 2*log(b)) - 3*576**k*(u - 1)**2*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b) + 2*576**k*(-u*(u - 1)**2*log(a)**3 - 8*(u - 1)**2*log(b)**3 - 6*(u*log(a) + 2*log(b))**3 + 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))))/(3*5733089280**k*(u - 1)**4)

# Substitute i with the imaginary unit (1j)
polynomial = polynomial.subs(i, 1j)

# Function to plot zeros for given parameter values
def plot_zeros(poly, k_value, u_value, a_value, b_value, x_value, x_range=(-30, 30), y_range=(-30, 30), title=""):
    # Substitute the parameter values
    poly_at_values = poly.subs({k: k_value, u: u_value, a: a_value, b: b_value, x: x_value})
    
    try:
        # Calculate the roots
        roots = sp.solveset(poly_at_values, y, domain=sp.S.Complexes)
        
        # Convert to numerical roots
        roots_list = list(sp.nroots(poly_at_values, n=15))
        
        # Separate real and imaginary parts
        real_parts = [root.as_real_imag()[0] for root in roots_list]
        imag_parts = [root.as_real_imag()[1] for root in roots_list]
        
        # Plot the zeros
        plt.figure(figsize=(10, 8))
        plt.scatter(real_parts, imag_parts, color='blue', marker='o', s=200, label='Zeros')
        plt.axhline(0, color='black', linewidth=1)
        plt.axvline(0, color='black', linewidth=1)
        plt.xlim(x_range[0], x_range[1])
        plt.ylim(y_range[0], y_range[1])
        plt.xlabel("Real Part")
        plt.ylabel("Imaginary Part")
        plt.title(title)
        plt.grid(True)
        plt.show()
    except Exception as e:
        print(f"Error plotting for x={x_value}: {str(e)}")

# Example plots with different parameter values
plot_zeros(polynomial, k_value=2, u_value=-2, a_value=-1, b_value=1, x_value=-3,
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=-3)")
plot_zeros(polynomial, k_value=2, u_value=-2, a_value=-1, b_value=1, x_value=-1, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=-1)")
plot_zeros(polynomial, k_value=2, u_value=2, a_value=-1, b_value=1, x_value=1, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=1)")
plot_zeros(polynomial, k_value=1, u_value=2, a_value=-1, b_value=1, x_value=3, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2,  a=1, b=-1, x=3)")

# %%
saving into pnj

# %%
from sympy import log  
import sympy as sp
import matplotlib.pyplot as plt

# Define the symbols
x, y, u, k, a, b, i = sp.symbols('x y u k a b i')

# Define the polynomial
polynomial =  y*(-13824**k*(120*103680**k*(u - 1)**8*log(a*b)**4 + 60*103680**k*(u - 1)**6*(u*log(a) + 2*log(b))*log(a*b)**3 + 30*138240**k*y**2*(u - 1)**6*log(a*b)**2 - 315*138240**k*(u - 1)**8*log(a*b)**4 - 270*138240**k*(u - 1)**6*(u*log(a) + 2*log(b))*log(a*b)**3 + 90*138240**k*(u - 1)**4*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2 - 2*(u*log(a) + 2*log(b))**2)*log(a*b)**2 - 60*207360**k*y**2*(u - 1)**6*log(a*b)**2 - 60*207360**k*y**2*(u - 1)**4*(u*log(a) + 2*log(b))*log(a*b) + 300*207360**k*(u - 1)**8*log(a*b)**4 + 330*207360**k*(u - 1)**6*(u*log(a) + 2*log(b))*log(a*b)**3 + 180*207360**k*(u - 1)**4*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b)**2 + 60*207360**k*(u - 1)**2*(u*(u - 1)**2*log(a)**3 + 8*(u - 1)**2*log(b)**3 + 6*(u*log(a) + 2*log(b))**3 - 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))*log(a*b) + 30*414720**k*(u - 1)**4*(y**2 - 3*(u - 1)**2*log(a*b)**2)*(u*log(a) + 2*log(b))*log(a*b) + 414720**k*(u - 1)**4*(-3*y**4 + 20*y**2*(u - 1)**2*log(a*b)**2 - 72*(u - 1)**4*log(a*b)**4) + 30*414720**k*(u - 1)**2*(y**2 - 2*(u - 1)**2*log(a*b)**2)*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2) - 30*414720**k*(u - 1)**2*(u*(u - 1)**2*log(a)**3 + 8*(u - 1)**2*log(b)**3 + 6*(u*log(a) + 2*log(b))**3 - 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))*log(a*b) + 15*414720**k*(u*(u - 1)**3*log(a)**4 - 16*(u - 1)**3*log(b)**4 - 8*(u - 1)**2*(u*log(a) + 2*log(b))*(u*log(a)**3 + 8*log(b)**3) - 6*(u - 1)**2*(u*log(a)**2 - 4*log(b)**2)**2 - 24*(u*log(a) + 2*log(b))**4 + 36*(u*log(a) + 2*log(b))**2*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2)) - 15*82944**k*(u - 1)**8*log(a*b)**4) + 30*2866544640**k*x**3*(u - 1)**3*(2**k*(u - 1)**2*log(a*b) + 2*2**k*(u*log(a) + 2*log(b)) - 2*(u - 1)**2*log(a*b)) + 30*477757440**k*x**2*(u - 1)**2*(-12**k*(u - 1)**2*(y**2 - 2*(u - 1)**2*log(a*b)**2) + 3*12**k*(u - 1)**2*(u*log(a) + 2*log(b))*log(a*b) + 3*12**k*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2) + 3*4**k*(u - 1)**4*log(a*b)**2 - 6*6**k*(u - 1)**4*log(a*b)**2 - 6*6**k*(u - 1)**2*(u*log(a) + 2*log(b))*log(a*b)) + 15*5733089280**k*x**4*(u - 1)**4 - 30*9953280**k*x*(u - 1)*(2*144**k*(u - 1)**6*log(a*b)**3 - 9*192**k*(u - 1)**6*log(a*b)**3 - 6*192**k*(u - 1)**4*(u*log(a) + 2*log(b))*log(a*b)**2 - 2*288**k*y**2*(u - 1)**4*log(a*b) + 11*288**k*(u - 1)**6*log(a*b)**3 + 12*288**k*(u - 1)**4*(u*log(a) + 2*log(b))*log(a*b)**2 + 6*288**k*(u - 1)**2*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b) + 576**k*(u - 1)**4*(y**2 - 3*(u - 1)**2*log(a*b)**2)*log(a*b) + 2*576**k*(u - 1)**2*(y**2 - 2*(u - 1)**2*log(a*b)**2)*(u*log(a) + 2*log(b)) - 3*576**k*(u - 1)**2*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b) + 2*576**k*(-u*(u - 1)**2*log(a)**3 - 8*(u - 1)**2*log(b)**3 - 6*(u*log(a) + 2*log(b))**3 + 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))))/(3*5733089280**k*(u - 1)**4)

# Substitute i with the imaginary unit (1j)
polynomial = polynomial.subs(i, 1j)

# Function to plot zeros for given parameter values
def plot_zeros(poly, k_value, u_value, a_value, b_value, x_value, x_range=(-30, 30), y_range=(-30, 30), title=""):
    # Substitute the parameter values
    poly_at_values = poly.subs({k: k_value, u: u_value, a: a_value, b: b_value, x: x_value})
    
    try:
        # Calculate the roots
        roots = sp.solveset(poly_at_values, y, domain=sp.S.Complexes)
        
        # Convert to numerical roots
        roots_list = list(sp.nroots(poly_at_values, n=15))
        
        # Separate real and imaginary parts
        real_parts = [root.as_real_imag()[0] for root in roots_list]
        imag_parts = [root.as_real_imag()[1] for root in roots_list]
        
        # Plot the zeros
        plt.figure(figsize=(10, 8))
        plt.scatter(real_parts, imag_parts, color='blue', marker='o', s=200, label='Zeros')
        plt.axhline(0, color='black', linewidth=1)
        plt.axvline(0, color='black', linewidth=1)
        plt.xlim(x_range[0], x_range[1])
        plt.ylim(y_range[0], y_range[1])
        plt.xlabel("Real Part")
        plt.ylabel("Imaginary Part")
        plt.title(title)
        plt.grid(True)

        # Create a filename from the parameters
        filename = f"zeros_k_{k_value}_u_{u_value}_a_{a_value}_b_{b_value}_x_{x_value}.png"
    
        # Save the figure
        plt.savefig(filename, bbox_inches='tight', dpi=300)
        plt.close()  # Close the figure to free memory
        
    except Exception as e:
        print(f"Error plotting for y={y_value}: {str(e)}")

# Example plots with different parameter values
plot_zeros(polynomial, k_value=2, u_value=-2, a_value=-1, b_value=1, x_value=-3,
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=-3)")
plot_zeros(polynomial, k_value=2, u_value=-2, a_value=-1, b_value=1, x_value=-1, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=-1)")
plot_zeros(polynomial, k_value=2, u_value=2, a_value=-1, b_value=1, x_value=1, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=1)")
plot_zeros(polynomial, k_value=1, u_value=2, a_value=-1, b_value=1, x_value=3, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2,  a=1, b=-1, x=3)")

# %%
type 2

# %%
from sympy import log  
import sympy as sp
import matplotlib.pyplot as plt

# Define the symbols
x, y, u, k, a, b, i = sp.symbols('x y u k a b i')

# Define the polynomial
polynomial =  y*(-13824**k*(120*103680**k*(u - 1)**8*log(a*b)**4 + 60*103680**k*(u - 1)**6*(u*log(a) + 2*log(b))*log(a*b)**3 + 30*138240**k*y**2*(u - 1)**6*log(a*b)**2 - 315*138240**k*(u - 1)**8*log(a*b)**4 - 270*138240**k*(u - 1)**6*(u*log(a) + 2*log(b))*log(a*b)**3 + 90*138240**k*(u - 1)**4*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2 - 2*(u*log(a) + 2*log(b))**2)*log(a*b)**2 - 60*207360**k*y**2*(u - 1)**6*log(a*b)**2 - 60*207360**k*y**2*(u - 1)**4*(u*log(a) + 2*log(b))*log(a*b) + 300*207360**k*(u - 1)**8*log(a*b)**4 + 330*207360**k*(u - 1)**6*(u*log(a) + 2*log(b))*log(a*b)**3 + 180*207360**k*(u - 1)**4*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b)**2 + 60*207360**k*(u - 1)**2*(u*(u - 1)**2*log(a)**3 + 8*(u - 1)**2*log(b)**3 + 6*(u*log(a) + 2*log(b))**3 - 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))*log(a*b) + 30*414720**k*(u - 1)**4*(y**2 - 3*(u - 1)**2*log(a*b)**2)*(u*log(a) + 2*log(b))*log(a*b) + 414720**k*(u - 1)**4*(-3*y**4 + 20*y**2*(u - 1)**2*log(a*b)**2 - 72*(u - 1)**4*log(a*b)**4) + 30*414720**k*(u - 1)**2*(y**2 - 2*(u - 1)**2*log(a*b)**2)*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2) - 30*414720**k*(u - 1)**2*(u*(u - 1)**2*log(a)**3 + 8*(u - 1)**2*log(b)**3 + 6*(u*log(a) + 2*log(b))**3 - 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))*log(a*b) + 15*414720**k*(u*(u - 1)**3*log(a)**4 - 16*(u - 1)**3*log(b)**4 - 8*(u - 1)**2*(u*log(a) + 2*log(b))*(u*log(a)**3 + 8*log(b)**3) - 6*(u - 1)**2*(u*log(a)**2 - 4*log(b)**2)**2 - 24*(u*log(a) + 2*log(b))**4 + 36*(u*log(a) + 2*log(b))**2*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2)) - 15*82944**k*(u - 1)**8*log(a*b)**4) + 30*2866544640**k*x**3*(u - 1)**3*(2**k*(u - 1)**2*log(a*b) + 2*2**k*(u*log(a) + 2*log(b)) - 2*(u - 1)**2*log(a*b)) + 30*477757440**k*x**2*(u - 1)**2*(-12**k*(u - 1)**2*(y**2 - 2*(u - 1)**2*log(a*b)**2) + 3*12**k*(u - 1)**2*(u*log(a) + 2*log(b))*log(a*b) + 3*12**k*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2) + 3*4**k*(u - 1)**4*log(a*b)**2 - 6*6**k*(u - 1)**4*log(a*b)**2 - 6*6**k*(u - 1)**2*(u*log(a) + 2*log(b))*log(a*b)) + 15*5733089280**k*x**4*(u - 1)**4 - 30*9953280**k*x*(u - 1)*(2*144**k*(u - 1)**6*log(a*b)**3 - 9*192**k*(u - 1)**6*log(a*b)**3 - 6*192**k*(u - 1)**4*(u*log(a) + 2*log(b))*log(a*b)**2 - 2*288**k*y**2*(u - 1)**4*log(a*b) + 11*288**k*(u - 1)**6*log(a*b)**3 + 12*288**k*(u - 1)**4*(u*log(a) + 2*log(b))*log(a*b)**2 + 6*288**k*(u - 1)**2*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b) + 576**k*(u - 1)**4*(y**2 - 3*(u - 1)**2*log(a*b)**2)*log(a*b) + 2*576**k*(u - 1)**2*(y**2 - 2*(u - 1)**2*log(a*b)**2)*(u*log(a) + 2*log(b)) - 3*576**k*(u - 1)**2*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b) + 2*576**k*(-u*(u - 1)**2*log(a)**3 - 8*(u - 1)**2*log(b)**3 - 6*(u*log(a) + 2*log(b))**3 + 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))))/(3*5733089280**k*(u - 1)**4)

# Substitute i with the imaginary unit (1j)
polynomial = polynomial.subs(i, 1j)

# Function to plot zeros for given parameter values
def plot_zeros(poly, k_value, u_value, a_value, b_value, x_value, x_range=(-30, 30), y_range=(-30, 30), title=""):
    # Substitute the parameter values
    poly_at_values = poly.subs({k: k_value, u: u_value, a: a_value, b: b_value, x: x_value})
    
    try:
        # Calculate the roots
        roots = sp.solveset(poly_at_values, y, domain=sp.S.Complexes)
        
        # Convert to numerical roots
        roots_list = list(sp.nroots(poly_at_values, n=15))
        
        # Separate real and imaginary parts
        real_parts = [root.as_real_imag()[0] for root in roots_list]
        imag_parts = [root.as_real_imag()[1] for root in roots_list]
        
        # Plot the zeros
        plt.figure(figsize=(10, 8))
        plt.scatter(real_parts, imag_parts, color='blue', marker='o', s=200, label='Zeros')
        plt.axhline(0, color='black', linewidth=1)
        plt.axvline(0, color='black', linewidth=1)
        plt.xlim(x_range[0], x_range[1])
        plt.ylim(y_range[0], y_range[1])
        plt.xlabel("Real Part")
        plt.ylabel("Imaginary Part")
        plt.title(title)
        plt.grid(True)
        plt.show()
    except Exception as e:
        print(f"Error plotting for x={x_value}: {str(e)}")

# Example plots with different parameter values
plot_zeros(polynomial, k_value=2, u_value=-2, a_value=-1, b_value=1, x_value=-5,
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=-5)")
plot_zeros(polynomial, k_value=2, u_value=-2, a_value=-1, b_value=1, x_value=-3, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=-3)")
plot_zeros(polynomial, k_value=2, u_value=2, a_value=-1, b_value=1, x_value=-2, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=-2)")
plot_zeros(polynomial, k_value=1, u_value=2, a_value=-1, b_value=1, x_value=0, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2,  a=1, b=-1, x=0)")

# %%
from sympy import log  
import sympy as sp
import matplotlib.pyplot as plt

# Define the symbols
x, y, u, k, a, b, i = sp.symbols('x y u k a b i')

# Define the polynomial
polynomial =  y*(-13824**k*(120*103680**k*(u - 1)**8*log(a*b)**4 + 60*103680**k*(u - 1)**6*(u*log(a) + 2*log(b))*log(a*b)**3 + 30*138240**k*y**2*(u - 1)**6*log(a*b)**2 - 315*138240**k*(u - 1)**8*log(a*b)**4 - 270*138240**k*(u - 1)**6*(u*log(a) + 2*log(b))*log(a*b)**3 + 90*138240**k*(u - 1)**4*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2 - 2*(u*log(a) + 2*log(b))**2)*log(a*b)**2 - 60*207360**k*y**2*(u - 1)**6*log(a*b)**2 - 60*207360**k*y**2*(u - 1)**4*(u*log(a) + 2*log(b))*log(a*b) + 300*207360**k*(u - 1)**8*log(a*b)**4 + 330*207360**k*(u - 1)**6*(u*log(a) + 2*log(b))*log(a*b)**3 + 180*207360**k*(u - 1)**4*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b)**2 + 60*207360**k*(u - 1)**2*(u*(u - 1)**2*log(a)**3 + 8*(u - 1)**2*log(b)**3 + 6*(u*log(a) + 2*log(b))**3 - 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))*log(a*b) + 30*414720**k*(u - 1)**4*(y**2 - 3*(u - 1)**2*log(a*b)**2)*(u*log(a) + 2*log(b))*log(a*b) + 414720**k*(u - 1)**4*(-3*y**4 + 20*y**2*(u - 1)**2*log(a*b)**2 - 72*(u - 1)**4*log(a*b)**4) + 30*414720**k*(u - 1)**2*(y**2 - 2*(u - 1)**2*log(a*b)**2)*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2) - 30*414720**k*(u - 1)**2*(u*(u - 1)**2*log(a)**3 + 8*(u - 1)**2*log(b)**3 + 6*(u*log(a) + 2*log(b))**3 - 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))*log(a*b) + 15*414720**k*(u*(u - 1)**3*log(a)**4 - 16*(u - 1)**3*log(b)**4 - 8*(u - 1)**2*(u*log(a) + 2*log(b))*(u*log(a)**3 + 8*log(b)**3) - 6*(u - 1)**2*(u*log(a)**2 - 4*log(b)**2)**2 - 24*(u*log(a) + 2*log(b))**4 + 36*(u*log(a) + 2*log(b))**2*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2)) - 15*82944**k*(u - 1)**8*log(a*b)**4) + 30*2866544640**k*x**3*(u - 1)**3*(2**k*(u - 1)**2*log(a*b) + 2*2**k*(u*log(a) + 2*log(b)) - 2*(u - 1)**2*log(a*b)) + 30*477757440**k*x**2*(u - 1)**2*(-12**k*(u - 1)**2*(y**2 - 2*(u - 1)**2*log(a*b)**2) + 3*12**k*(u - 1)**2*(u*log(a) + 2*log(b))*log(a*b) + 3*12**k*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2) + 3*4**k*(u - 1)**4*log(a*b)**2 - 6*6**k*(u - 1)**4*log(a*b)**2 - 6*6**k*(u - 1)**2*(u*log(a) + 2*log(b))*log(a*b)) + 15*5733089280**k*x**4*(u - 1)**4 - 30*9953280**k*x*(u - 1)*(2*144**k*(u - 1)**6*log(a*b)**3 - 9*192**k*(u - 1)**6*log(a*b)**3 - 6*192**k*(u - 1)**4*(u*log(a) + 2*log(b))*log(a*b)**2 - 2*288**k*y**2*(u - 1)**4*log(a*b) + 11*288**k*(u - 1)**6*log(a*b)**3 + 12*288**k*(u - 1)**4*(u*log(a) + 2*log(b))*log(a*b)**2 + 6*288**k*(u - 1)**2*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b) + 576**k*(u - 1)**4*(y**2 - 3*(u - 1)**2*log(a*b)**2)*log(a*b) + 2*576**k*(u - 1)**2*(y**2 - 2*(u - 1)**2*log(a*b)**2)*(u*log(a) + 2*log(b)) - 3*576**k*(u - 1)**2*(-u*(u - 1)*log(a)**2 + 4*(u - 1)*log(b)**2 + 2*(u*log(a) + 2*log(b))**2)*log(a*b) + 2*576**k*(-u*(u - 1)**2*log(a)**3 - 8*(u - 1)**2*log(b)**3 - 6*(u*log(a) + 2*log(b))**3 + 6*(u*log(a) + 2*log(b))*(u*(u - 1)*log(a)**2 + 4*(1 - u)*log(b)**2))))/(3*5733089280**k*(u - 1)**4)

# Substitute i with the imaginary unit (1j)
polynomial = polynomial.subs(i, 1j)

# Function to plot zeros for given parameter values
def plot_zeros(poly, k_value, u_value, a_value, b_value, x_value, x_range=(-30, 30), y_range=(-30, 30), title=""):
    # Substitute the parameter values
    poly_at_values = poly.subs({k: k_value, u: u_value, a: a_value, b: b_value, x: x_value})
    
    try:
        # Calculate the roots
        roots = sp.solveset(poly_at_values, y, domain=sp.S.Complexes)
        
         # Convert to numerical roots
        roots_list = list(sp.nroots(poly_at_values, n=15))
        
        # Separate real and imaginary parts
        real_parts = [root.as_real_imag()[0] for root in roots_list]
        imag_parts = [root.as_real_imag()[1] for root in roots_list]
        
        # Plot the zeros
        plt.figure(figsize=(10, 8))
        plt.scatter(real_parts, imag_parts, color='blue', marker='o', s=200, label='Zeros')
        plt.axhline(0, color='black', linewidth=1)
        plt.axvline(0, color='black', linewidth=1)
        plt.xlim(x_range[0], x_range[1])
        plt.ylim(y_range[0], y_range[1])
        plt.xlabel("Real Part")
        plt.ylabel("Imaginary Part")
        plt.title(title)
        plt.grid(True)

        # Create a filename from the parameters
        filename = f"zeros_k_{k_value}_u_{u_value}_a_{a_value}_b_{b_value}_x_{x_value}.png"
    
        # Save the figure
        plt.savefig(filename, bbox_inches='tight', dpi=300)
        plt.close()  # Close the figure to free memory
        
    except Exception as e:
        print(f"Error plotting for y={y_value}: {str(e)}")
        
# Example plots with different parameter values
plot_zeros(polynomial, k_value=2, u_value=-2, a_value=-1, b_value=1, x_value=-5,
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=-5)")
plot_zeros(polynomial, k_value=2, u_value=-2, a_value=-1, b_value=1, x_value=-3, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=-3)")
plot_zeros(polynomial, k_value=2, u_value=2, a_value=-1, b_value=1, x_value=-2, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2, a=1, b=-1, x=-2)")
plot_zeros(polynomial, k_value=1, u_value=2, a_value=-1, b_value=1, x_value=0, 
           title="Distribution of Zeros T^(k,C)_(5,1)(x,y;u,a,b) where (k=2, u=-2,  a=1, b=-1, x=0)")
