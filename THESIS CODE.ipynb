# %%
FROBENIUS-TANGENT POLYNOMIALS AND NUMBERS

# %%
import sympy as sp

# Define symbols
k, t= sp.symbols('k t')

# Evaluate coefficients
#u=-1

# Number of terms to compute
num_terms = 5

# Define the generating function
generating_function = ((1-u)  / (sp.exp(2 * t) -u))

# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get T_n(x)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get T_n(x)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials T_n(x)
for n, T_n in enumerate(tangent_number):
    print(f"T_{n} = {T_n}")

# Now, generate the polynomials T_n(x)
polynomials_x = []
for n in range(n_number):
    T_n_x = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x.append(T_n_x)

# Display the polynomials T_n(x)
for n, T_n_x in enumerate(polynomials_x):
    print(f"T_{n}(x) = {T_n_x}")
# Out:
# T_0 = -u/(1 - u) + 1/(1 - u)
# T_1 = -2*u/((1 - u)*(u - 1)) + 2/((1 - u)*(u - 1))
# T_2 = -2*u*(2/(u - 1) + 4/(u - 1)**2)/(1 - u) + 2*(2/(u - 1) + 4/(u - 1)**2)/(1 - u)
# T_3 = -6*u*(4/(3*(u - 1)) + 8/(u - 1)**2 + 8/(u - 1)**3)/(1 - u) + 6*(4/(3*(u - 1)) + 8/(u - 1)**2 + 8/(u - 1)**3)/(1 - u)
# T_4 = -24*u*(2/(3*(u - 1)) + 28/(3*(u - 1)**2) + 24/(u - 1)**3 + 16/(u - 1)**4)/(1 - u) + 24*(2/(3*(u - 1)) + 28/(3*(u - 1)**2) + 24/(u - 1)**3 + 16/(u - 1)**4)/(1 - u)
# T_0(x) = -u/(1 - u) + 1/(1 - u)
# T_1(x) = -2*u/((1 - u)*(u - 1)) + x*(-u/(1 - u) + 1/(1 - u)) + 2/((1 - u)*(u - 1))
# T_2(x) = -2*u*(2/(u - 1) + 4/(u - 1)**2)/(1 - u) + x**2*(-u/(1 - u) + 1/(1 - u)) + 2*x*(-2*u/((1 - u)*(u - 1)) + 2/((1 - u)*(u - 1))) + 2*(2/(u - 1) + 4/(u - 1)**2)/(1 - u)
# ...

# %%
FROBENIUS-TANGENT POLYNOMIALS AND NUMBERS (CHECKED)

# %%
import sympy as sp

# Define symbols
k, t= sp.symbols('k t')

# Evaluate coefficients
u=-1

# Number of terms to compute
num_terms = 5

# Define the generating function
generating_function = ((1-u)  / (sp.exp(2 * t) -u))

# Number of terms to compute
n_number = 5

# List to store the tangent polynomials
tangent_number = []

# Compute the Taylor series expansion of the generating function
taylor_series = sp.series(generating_function, t, 0, n_number).removeO()

# Extract the coefficients of t^n / n! to get T_n(x)
for n in range(n_number):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get T_n(x)
    I_n = coeff * sp.factorial(n)
    tangent_number.append(I_n)

# Display the polynomials T_n(x)
for n, T_n in enumerate(tangent_number):
    print(f"T_{n} = {T_n}")

# Now, generate the polynomials T_n(x)
polynomials_x = []
for n in range(n_number):
    T_n_x = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x.append(T_n_x)

# Display the polynomials T_n(x)
for n, T_n_x in enumerate(polynomials_x):
    print(f"T_{n}(x) = {T_n_x}")
# Out:
# T_0 = 1
# T_1 = -1
# T_2 = 0
# T_3 = 2
# T_4 = 0
# T_0(x) = 1
# T_1(x) = x - 1
# T_2(x) = x**2 - 2*x
# T_3(x) = x**3 - 3*x**2 + 2
# T_4(x) = x**4 - 4*x**3 + 8*x

# %%
TYPE 1 POLYNOMIALS AND NUMBERS

# %%
import sympy as sp

# Define symbols
x, t, u, k = sp.symbols('x t u k')

# Evaluate coefficients
#k=1
#u=-1

# Define the polylogarithmic function l_i_k(x)
def l_i_k(x, k, n_terms=10):
    return sum((x**n) / (n**k) for n in range(1, n_terms + 1))

# Define the generating function
numerator = l_i_k(1 - sp.exp(-(1 - u) * t), k)
denominator = t * (sp.exp(2 * t) - u)
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# Compute Taylor series expansion
taylor_series = sp.series(generating_function, t, 0, n_terms).removeO()

# List to store the tangent numbers
tangent_number = []

# Compute the first few tangent numbers
for n in range(n_terms):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get I_n(x)
    T_n = coeff * sp.factorial(n)
    tangent_number.append(T_n)

# Display the polynomials I_n(x)
for n, T_n in enumerate(tangent_number):
    print(f"T_{n,1}^((k)) = {sp.simplify(T_n)}")

# Now, generate the polynomials T_n(x)
polynomials_x = []
for n in range(n_terms):
    T_n_x = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x.append(sp.simplify(T_n_x))

# Display the polynomials T_n(x)
for n, T_n_x in enumerate(polynomials_x):
    print(f"T_{n}(x) = {T_n_x}")
# Out:
# T_(0, 1)^((k)) = 1
# T_(1, 1)^((k)) = (2**k*u**2 - 2*2**k*u + 5*2**k - 2*u**2 + 4*u - 2)/(2*2**k*(u - 1))
# T_(2, 1)^((k)) = (6*2**k*(u - 1)**6 + 6*3**k*(u - 1)**4*(-u**2 + 2*u - 3) + 3*6**k*u*(1 - u)*(u - 1)**3 + 6**k*(u - 1)**3*(u**3 - 1) + 6*6**k*(u - 1)**2*(u**2 - 2*u + 1) + 12*6**k*(u*(2*u + (u - 1)**2 - 2) - 2*u - (u - 1)**2 + 2))/(3*6**k*(u - 1)**4)
# T_(3, 1)^((k)) = (-14*144**k*u**6 + 84*144**k*u**5 - 258*144**k*u**4 + 424*144**k*u**3 - 450*144**k*u**2 + 324*144**k*u - 110*144**k + 288**k*u**6 - 6*288**k*u**5 + 23*288**k*u**4 - 28*288**k*u**3 + 71*288**k*u**2 + 66*288**k*u + 65*288**k - 24*72**k*u**6 + 144*72**k*u**5 - 360*72**k*u**4 + 480*72**k*u**3 - 360*72**k*u**2 + 144*72**k*u - 24*72**k + 36*96**k*u**6 - 216*96**k*u**5 + 588*96**k*u**4 - 912*96**k*u**3 + 828*96**k*u**2 - 408*96**k*u + 84*96**k)/(4*288**k*(u**3 - 3*u**2 + 3*u - 1))
# ...

# %%
TYPE 1 POLYNOMIALS AND NUMBERS (CHECKED)

# %%
import sympy as sp

# Define symbols
x, t, u, k = sp.symbols('x t u k')

# Evaluate coefficients
k=1
u=-1

# Define the polylogarithmic function l_i_k(x)
def l_i_k(x, k, n_terms=10):
    return sum((x**n) / (n**k) for n in range(1, n_terms + 1))

# Define the generating function
numerator = l_i_k(1 - sp.exp(-(1 - u) * t), k)
denominator = t * (sp.exp(2 * t) - u)
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# Compute Taylor series expansion
taylor_series = sp.series(generating_function, t, 0, n_terms).removeO()

# List to store the tangent numbers
tangent_number = []

# Compute the first few tangent numbers
for n in range(n_terms):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get I_n(x)
    T_n = coeff * sp.factorial(n)
    tangent_number.append(T_n)

# Display the polynomials I_n(x)
for n, T_n in enumerate(tangent_number):
    print(f"T_{n,1}^((k)) = {sp.simplify(T_n)}")

# Now, generate the polynomials T_n(x)
polynomials_x = []
for n in range(n_terms):
    T_n_x = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x.append(sp.simplify(T_n_x))

# Display the polynomials T_n(x)
for n, T_n_x in enumerate(polynomials_x):
    print(f"T_{n}(x) = {T_n_x}")
# Out:
# T_(0, 1)^((k)) = 1
# T_(1, 1)^((k)) = -1
# T_(2, 1)^((k)) = 0
# T_(3, 1)^((k)) = 2
# T_(4, 1)^((k)) = 0
# T_0(x) = 1
# T_1(x) = x - 1
# T_2(x) = x*(x - 2)
# T_3(x) = x**3 - 3*x**2 + 2
# T_4(x) = x*(x**3 - 4*x**2 + 8)

# %%
COSINE TYPE 1 POLYNOMIAL

# %%
import sympy as sp

# Define all needed symbols including imaginary unit i
y, x, t, u, k, i = sp.symbols('y x t u k i')

# Evaluate coefficients
#k=1
#u=-1
#y=0
#x=0

# Define the polylogarithmic function l_i_k(x)
def l_i_k(x, k, n_terms=10):
    return sum((x**n) / (n**k) for n in range(1, n_terms + 1))

# Define the cosine function using Euler's formula
def sp_cos(y_val, t_val):
    return (sp.exp(i * y_val * t_val) + sp.exp(-i * y_val * t_val)) / 2

# Define the generating function
# Fixed the arguments to l_i_k (removed y which was incorrectly placed)
numerator = l_i_k(1 - sp.exp(-(1 - u) * t), k)
denominator = t * (sp.exp(2 * t) - u)
generating_function = (numerator / denominator)  * sp_cos(y, t)

# Number of terms to compute
n_terms = 10

# Compute Taylor series expansion
try:
    taylor_series = sp.series(generating_function, t, 0, n_terms).removeO()
except Exception as e:
    print(f"Error computing series: {e}")
    taylor_series = 0

# List to store the tangent numbers
tangent_number = []

# Compute the first few tangent numbers
for n in range(n_terms):
    try:
        # Coefficient of t^n in the Taylor series
        coeff = taylor_series.coeff(t, n) if taylor_series != 0 else 0
        # Multiply by n! to get T_n(x)
        T_n = coeff * sp.factorial(n)
        tangent_number.append(sp.simplify(T_n))
    except Exception as e:
        print(f"Error processing term n={n}: {e}")
        tangent_number.append(0)

# Now, generate the polynomials T_n(x, y)
print("\nGeneralized polynomials:")
polynomials_x_y = []
for n in range(n_terms):
    try:
        T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
        simplified = sp.simplify(T_n_x_y)
        polynomials_x_y.append(simplified)
        print(f"T^(C)_{n}(x, y) = {simplified}")
    except Exception as e:
        print(f"Error generating polynomial for n={n}: {e}")
        polynomials_x_y.append(0)
# Out:
# Generalized polynomials:
# T^(C)_0(x, y) = 1
# T^(C)_1(x, y) = (2**k*u**2 - 2*2**k*u + 2*2**k*x*(u - 1) + 5*2**k - 2*u**2 + 4*u - 2)/(2*2**k*(u - 1))
# T^(C)_2(x, y) = (3*12**k*x**2*(u - 1)**4 + 2**k*(6*2**k*(u - 1)**6 + 6*3**k*(u - 1)**4*(-u**2 + 2*u - 3) + 6**k*(u - 1)**3*(u**3 - 1) + 3*6**k*(u - 1)**3*(i**2*u*y**2 - i**2*y**2 - u**2 + u) + 6*6**k*(u - 1)**2*(u**2 - 2*u + 1) + 12*6**k*(u*(2*u + (u - 1)**2 - 2) - 2*u - (u - 1)**2 + 2)) + 3*6**k*x*(u - 1)**3*(2**k*u**2 - 2*2**k*u + 5*2**k - 2*u**2 + 4*u - 2))/(3*12**k*(u - 1)**4)
# ...

# %%
COSINE TYPE 1 (CHECKED)

# %%
import sympy as sp

# Define all needed symbols including imaginary unit i
y, x, t, u, k, i = sp.symbols('y x t u k i')

# Evaluate coefficients
k=1
u=-1
y=0
#x=0

# Define the polylogarithmic function l_i_k(x)
def l_i_k(x, k, n_terms=10):
    return sum((x**n) / (n**k) for n in range(1, n_terms + 1))

# Define the cosine function using Euler's formula
def sp_cos(y_val, t_val):
    return (sp.exp(i * y_val * t_val) + sp.exp(-i * y_val * t_val)) / 2

# Define the generating function
# Fixed the arguments to l_i_k (removed y which was incorrectly placed)
numerator = l_i_k(1 - sp.exp(-(1 - u) * t), k)
denominator = t * (sp.exp(2 * t) - u)
generating_function = (numerator / denominator)  * sp_cos(y, t)

# Number of terms to compute
n_terms = 6

# Compute Taylor series expansion
try:
    taylor_series = sp.series(generating_function, t, 0, n_terms).removeO()
except Exception as e:
    print(f"Error computing series: {e}")
    taylor_series = 0

# List to store the tangent numbers
tangent_number = []

# Compute the first few tangent numbers
for n in range(n_terms):
    try:
        # Coefficient of t^n in the Taylor series
        coeff = taylor_series.coeff(t, n) if taylor_series != 0 else 0
        # Multiply by n! to get T_n(x)
        T_n = coeff * sp.factorial(n)
        tangent_number.append(sp.simplify(T_n))
    except Exception as e:
        print(f"Error processing term n={n}: {e}")
        tangent_number.append(0)

# Display the polynomials I_n(x)
print("\nType I Frobenius-type poly-tangent polynomials:")
for n, T_n in enumerate(tangent_number):
    print(f"T_{n,1}^(({k}))(x) = {T_n}")  # Fixed to show k in output

# Now, generate the polynomials T_n(x, y)
print("\nGeneralized polynomials:")
polynomials_x_y = []
for n in range(n_terms):
    try:
        T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
        simplified = sp.simplify(T_n_x_y)
        polynomials_x_y.append(simplified)
        print(f"T^(C)_{n}(x, y) = {simplified}")
    except Exception as e:
        print(f"Error generating polynomial for n={n}: {e}")
        polynomials_x_y.append(0)
# Out:
# Type I Frobenius-type poly-tangent polynomials:
# T_(0, 1)^((1))(x) = 1
# T_(1, 1)^((1))(x) = -1
# T_(2, 1)^((1))(x) = 0
# T_(3, 1)^((1))(x) = 2
# T_(4, 1)^((1))(x) = 0
# T_(5, 1)^((1))(x) = -16
#
# Generalized polynomials:
# T^(C)_0(x, y) = 1
# T^(C)_1(x, y) = x - 1
# T^(C)_2(x, y) = x*(x - 2)
# T^(C)_3(x, y) = x**3 - 3*x**2 + 2
# T^(C)_4(x, y) = x*(x**3 - 4*x**2 + 8)
# T^(C)_5(x, y) = x**5 - 5*x**4 + 20*x**2 - 16

# %%
ZERO OF COSINE TYPE 1

# %%
import sympy as sp
import matplotlib.pyplot as plt

# Define the symbols
x, y, u, k, i = sp.symbols('x y u k i')

# Define the polynomial
polynomial =  (120*129139955417281965443158269448123698900803812907023768934405261460645704359238800947484782322152992931840000000000000000000000000000000**k*x**7*(u - 1)**2*(u**5 - 5*u**4 + 10*u**3 - 10*u**2 + 5*u - 1)*(6*2**k*(u - 1)**6 + 6*3**k*(u - 1)**4*(-u**2 + 2*u - 3) + 6**k*(u - 1)**3*(u**3 - 1) + 3*6**k*(u - 1)**3*(i**2*u*y**2 - i**2*y**2 - u**2 + u) + 6*6**k*(u - 1)**2*(u**2 - 2*u + 1) + 12*6**k*(u*(2*u + (u - 1)**2 - 2) - 2*u - (u - 1)**2 + 2))*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**7 - 7*u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1)*(u**9 - 9*u**8 + 36*u**7 - 84*u**6 + 126*u**5 - 126*u**4 + 84*u**3 - 36*u**2 + 9*u - 1) - 210*1345207868930020473366231973417955196883373051114830926400054806881726087075404176536299815855760343040000000000000000000000000000000**k*x**6*(u - 1)*(u**5 - 5*u**4 + 10*u**3 - 10*u**2 + 5*u - 1)*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**7 - 7*u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1)*(u**9 - 9*u**8 + 36*u**7 - 84*u**6 + 126*u**5 - 126*u**4 + 84*u**3 - 36*u**2 + 9*u - 1)*(24*12**(2*k)*(u - 1)**8 + 36*192**k*(u - 1)**6*(-u**2 + 2*u - 1) - 48*192**k*(u - 1)**6 - 24*24**(2*k)*(u - 1)*(u**2*(2*u + (u - 1)**2 - 2) - 2*u*(2*u + (u - 1)**2 - 2) + 2*u + (u - 1)**2 - 2) + 12*288**k*i**2*y**2*(u - 1)**6 + 48*288**k*(u - 1)**4*(u**2 - 2*u + 1) + 2*288**k*(u - 1)**4*(-12*u*(u - 1)**2 + 4*(u - 1)*(u**3 - 1) + 3*(u**2 - 2*u + 1)**2) + 48*288**k*(u - 1)**3*(2*u + (u - 1)**2 - 2) + 4*576**k*u*(u - 1)**4*(3*i**2*y**2 + u**2 + 1) - 576**k*(u - 1)**4*(u**4 + 1) - 6*576**k*(u - 1)**4*(i**2*u**2*y**2 + i**2*y**2 + u**2) + 8*576**k*(u - 1)**3*(-3*i**2*u*y**2 + 3*i**2*y**2 - u**3 + 3*u**2 - 3*u + 1) + 32*576**k*(-u*(u - 1)*(6*u + (u - 1)**2) + 6*u + (u - 1)**3 + 6*(u - 1)**2 - 6)) + 252*14946754099222449704069244149088391076481922790164788071111720076463623189726713072625553509508448256000000000000000000000000000000**k*x**5*(u**5 - 5*u**4 + 10*u**3 - 10*u**2 + 5*u - 1)*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**7 - 7*u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1)*(u**9 - 9*u**8 + 36*u**7 - 84*u**6 + 126*u**5 - 126*u**4 + 84*u**3 - 36*u**2 + 9*u - 1)*(120*10368**k*(u - 1)**10 + 240*12960**k*(u - 1)**8*(-u**2 + 2*u - 2) + 60*17280**k*i**2*y**2*(u - 1)**8 + 30*17280**k*(u - 1)**6*(2*(u - 1)*(u**3 - 3*u**2 + 3*u - 1) + 3*(u**2 - 2*u + 1)**2) + 360*17280**k*(u - 1)**6*(u**2 - 2*u + 1) + 240*17280**k*(u - 1)**5*(2*u + (u - 1)**2 - 2) + 60*25920**k*i**2*y**2*(u - 1)**6*(-u**2 + 2*u - 3) + 10*25920**k*(u - 1)**5*(6*u**2*(1 - u) + 4*u*(u - 1)*(u**2 + 1) - (u - 1)*(u**4 + 1) + 2*(u**2 - 2*u + 1)*(-u**3 + 3*u*(u - 1) + 1)) + 20*25920**k*(u - 1)**4*(12*u*(u - 1)**2 - 4*(u - 1)*(u**3 - 1) - 3*(u**2 - 2*u + 1)**2) - 240*25920**k*(u - 1)**3*(2*u + (u - 1)**2 - 2)*(u**2 - 2*u + 1) + 160*25920**k*(u - 1)**3*(-6*u - (u - 1)**3 - 6*(u - 1)**2 + 6) + 51840**k*(u - 1)**5*(u**5 - 1) + 5*51840**k*(u - 1)**5*(i**4*u*y**4 -
1)**6*(u**5 - 5*u**4 + 10*u**3 - 10*u**2 + 5*u - 1)*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**7 - 7*u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1)*(u**9 - 9*u**8 + 36*u**7 - 84*u**6 + 126*u**5 - 126*u**4 + 84*u**3 - 36*u**2 + 9*u - 1))

# Substitute i with the imaginary unit (1j)
polynomial = polynomial.subs(i, 1j)

# Function to plot zeros for given parameter values
def plot_zeros(poly, k_value, u_value, y_value, x_range=(-20, 20), y_range=(-20, 20), title=""):
    # Substitute the parameter values
    poly_at_values = poly.subs({k: k_value, u: u_value, y: y_value})
    
    # Calculate the roots
    roots = sp.solveset(poly_at_values, x, domain=sp.S.Complexes)
    
    # Convert the roots to a list of complex numbers
    roots_list = [root.evalf() for root in roots]
    
    # Separate real and imaginary parts
    real_parts = [root.as_real_imag()[0] for root in roots_list]
    imag_parts = [root.as_real_imag()[1] for root in roots_list]
    
    # Plot the zeros
    plt.figure(figsize=(10, 8))
    plt.scatter(real_parts, imag_parts, color='blue', marker='o', s=200, label='Zeros')
    plt.axhline(0, color='black', linewidth=1)
    plt.axvline(0, color='black', linewidth=1)
    plt.xlim(x_range[0], x_range[1])
    plt.ylim(y_range[0], y_range[1])
    plt.xlabel("Real Part")
    plt.ylabel("Imaginary Part")
    plt.title(title)
    plt.grid(True)
    plt.show()

# Example plots with different parameter values
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=-3,
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=-3)")
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=0, 
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=0)")
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=0.5, 
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=0.5)")
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=3, 
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=3)")

# %%
import sympy as sp
import matplotlib.pyplot as plt

# Define the symbols
x, y, u, k, i = sp.symbols('x y u k i')

# Define the polynomial
polynomial =  (120*129139955417281965443158269448123698900803812907023768934405261460645704359238800947484782322152992931840000000000000000000000000000000**k*x**7*(u - 1)**2*(u**5 - 5*u**4 + 10*u**3 - 10*u**2 + 5*u - 1)*(6*2**k*(u - 1)**6 + 6*3**k*(u - 1)**4*(-u**2 + 2*u - 3) + 6**k*(u - 1)**3*(u**3 - 1) + 3*6**k*(u - 1)**3*(i**2*u*y**2 - i**2*y**2 - u**2 + u) + 6*6**k*(u - 1)**2*(u**2 - 2*u + 1) + 12*6**k*(u*(2*u + (u - 1)**2 - 2) - 2*u - (u - 1)**2 + 2))*(u**6 - 6*u
 + 3*u - 1) + 3*(u**2 - 2*u + 1)**2) + 360*17280**k*(u - 1)**6*(u**2 - 2*u + 1) + 240*17280**k*(u - 1)**5*(2*u + (u - 1)**2 - 2) + 60*25920**k*i**2*y**2*(u - 1)**6*(-u**2 + 2*u - 3) + 10*25920**k*(u - 1)**5*(6*u**2*(1 - u) + 4*u*(u - 1)*(u**2 + 1) - (u - 1)*(u**4 + 1) + 2*(u**2 - 2*u + 1)*(-u**3 + 3*u*(u - 1) + 1)) + 20*25920**k*(u - 1)**4*(12*u*(u - 1)**2 - 4*(u - 1)*(u**3 - 1) - 3*(u**2 - 2*u + 1)**2) - 240*25920**k*(u - 1)**3*(2*u + (u - 1)**2 - 2)*(u**2 - 2*u + 1) + 160*25920**k*(u - 1)**3*(-6*u - (u - 1)**3 - 6*(u - 1)**2 + 6) + 51840**k*(u - 1)**5*(u**5 - 1) + 5*51840**k*(u - 1)**5*(i**4*u*y**4 - i**4*y**4 + 2*i**2*u**3*y**2 - 6*i**2*u**2*y**2 + 6*i**2*u*y**2 - 2*i**2*y**2 - u**4 + 2*u**3 - 2*u**2 + u) + 10*51840**k*(u - 1)**4*(6*i**2*u**2*y**2 - 12*i**2*u*y**2 + 6*i**2*y**2 + u**4 - 4*u**3 + 6*u**2 - 4*u + 1) + 80*51840**k*(u - 1)**2*(u**2*(6*u + (u - 1)**2) - 2*u*(6*u + (u - 1)**2) + 6*u + (u - 1)**2) + 40*51840**k*(u - 1)**2*(3*i**2*u*y**2*(2*u + (u - 1)**2 - 2) + 3*i**2*y**2*(-2*u - (u - 1)**2 + 2) + u**3*(2*u + (u - 1)**2 - 2) + 3*u**2*(-2*u - (u - 1)**2 + 2) + 3*u*(2*u + (u - 1)**2 - 2) - 2*u - (u - 1)**2 + 2) + 80*51840**k*(u*(u - 1)*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) - 24*u - (u - 1)**4 - 14*(u - 1)**3 - 36*(u - 1)**2 + 24)) + 2071633973792412229476884033057284346669053588106966431499838365368320000000000000000000**k*(u - 1)**6*(u**5 - 5*u**4 + 10*u**3 - 10*u**2 + 5*u - 1)*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**7 - 7*u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1)*(7560*124674490813522847967833360877748224000000000000**k*i**6*u**12*y**6 - 90720*124674490813522847967833360877748224000000000000**k*i**6*u**11*y**6 + 509040*124674490813522847967833360877748224000000000000**k*i**6*u**10*y**6 - 1764000*124674490813522847967833360877748224000000000000**k*i**6*u**9*y**6 + 4195800*124674490813522847967833360877748224000000000000**k*i**6*u**8*y**6 - 7197120*124674490813522847967833360877748224000000000000**k*i**6*u**7*y**6 + 9102240*124674490813522847967833360877748224000000000000**k*i**6*u**6*y**6 - 8527680*124674490813522847967833360877748224000000000000**k*i**6*u**5*y**6 + 5859000*124674490813522847967833360877748224000000000000
 540*895795200**k*i**4*u**3*y**4 + 585*895795200**k*i**4*u**2*y**4 - 330*895795200**k*i**4*u*y**4 + 75*895795200**k*i**4*y**4 + 15*895795200**k*i**2*u**8*y**2 - 120*895795200**k*i**2*u**7*y**2 + 540*895795200**k*i**2*u**6*y**2 - 1200*895795200**k*i**2*u**5*y**2 + 2250*895795200**k*i**2*u**4*y**2 - 1560*895795200**k*i**2*u**3*y**2 + 60*895795200**k*i**2*u**2*y**2 - 960*895795200**k*i**2*u*y**2 + 975*895795200**k*i**2*y**2 + 895795200**k*u**10 - 10*895795200**k*u**9 + 57*895795200**k*u**8 - 156*895795200**k*u**7 + 406*895795200**k*u**6 - 144*895795200**k*u**5 + 1662*895795200**k*u**4 + 4060*895795200**k*u**3 + 9753*895795200**k*u**2 + 6746*895795200**k*u + 665*895795200**k))/(10*774839732503691792658949616688742193404822877442142613606431568763874226155432805684908693932917957591040000000000000000000000000000000**k*(u - 1)**6*(u**5 - 5*u**4 + 10*u**3 - 10*u**2 + 5*u - 1)*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**7 - 7*u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1)*(u**9 - 9*u**8 + 36*u**7 - 84*u**6 + 126*u**5 - 126*u**4 + 84*u**3 - 36*u**2 + 9*u - 1))



# Substitute i with the imaginary unit (1j)
polynomial = polynomial.subs(i, 1j)

# Function to plot zeros for given parameter values
def plot_zeros(poly, k_value, u_value, y_value, x_range=(-20, 20), y_range=(-20, 20), title=""):
    # Substitute the parameter values
    poly_at_values = poly.subs({k: k_value, u: u_value, y: y_value})
    
    # Calculate the roots
    roots = sp.solveset(poly_at_values, x, domain=sp.S.Complexes)
    
    # Convert the roots to a list of complex numbers
    roots_list = [root.evalf() for root in roots]
    
    # Separate real and imaginary parts
    real_parts = [root.as_real_imag()[0] for root in roots_list]
    imag_parts = [root.as_real_imag()[1] for root in roots_list]
    
    # Plot the zeros
    plt.figure(figsize=(10, 8))
    plt.scatter(real_parts, imag_parts, color='blue', marker='o', s=200, label='Zeros')
    plt.axhline(0, color='black', linewidth=1)
    plt.axvline(0, color='black', linewidth=1)
    plt.xlim(x_range[0], x_range[1])
    plt.ylim(y_range[0], y_range[1])
    plt.xlabel("Real Part")
    plt.ylabel("Imaginary Part")
    plt.title(title)
    plt.grid(True)

    # Create a filename from the title (remove special characters)
    filename = f"zeros_k_{k_value}_u_{u_value}_y_{y_value}.png"
    
    # Save the figure
    plt.savefig(filename, bbox_inches='tight', dpi=300)
    plt.close()  # Close the figure to free memory

# Example plots with different parameter values
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=-3,
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=-3)")
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=0, 
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=0)")
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=0.5, 
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=0.5)")
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=3, 
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=3)")

# %%
TYPE 1 SINE

# %%
import sympy as sp
import math

# Define all needed symbols including imaginary unit i
y, x, t, u, k, i = sp.symbols('y x t u k i')

# Evaluate coefficients
#k=1
#u=-1
#y=0
#X=0

# Define the polylogarithmic function l_i_k(x)
def l_i_k(x, k, n_terms=10):
    return sum((x**n) / (n**k) for n in range(1, n_terms + 1))

# Define the cosine function using Euler's formula
def sp_sin(y_val, t_val):
    return (sp.exp(i * y_val * t_val) - sp.exp(-i * y_val * t_val)) / (2 * i)

# Define the generating function
numerator = l_i_k(1 - sp.exp(-(1 - u) * t), k)
denominator = t * (sp.exp(2 * t) - u)
generating_function = (numerator / denominator) * sp_sin(y, t)

# Number of terms to compute
n_terms = 10

# Compute Taylor series expansion
try:
    taylor_series = sp.series(generating_function, t, 0, n_terms).removeO()
except Exception as e:
    print(f"Error computing series: {e}")
    taylor_series = 0

# List to store the tangent numbers
tangent_number = []

# Compute the first few tangent numbers
for n in range(n_terms):
    try:
        # Coefficient of t^n in the Taylor series
        coeff = taylor_series.coeff(t, n) if taylor_series != 0 else 0
        # Multiply by n! to get I_n(x)
        I_n = coeff * sp.factorial(n)
        tangent_number.append(sp.simplify(I_n))
    except Exception as e:
        print(f"Error processing term n={n}: {e}")
        tangent_number.append(0)

# Now, generate the polynomials T_n(x, y)
print("\nGeneralized polynomials:")
polynomials_x_y = []
for n in range(n_terms):
    try:
        T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
        simplified = sp.simplify(T_n_x_y)
        polynomials_x_y.append(simplified)
        print(f"T^(S)_{n}(x, y) = {simplified}")
    except Exception as e:
        print(f"Error generating polynomial for n={n}: {e}")
        polynomials_x_y.append(0)
# Out:
# Generalized polynomials:
# T^(S)_0(x, y) = 0
# T^(S)_1(x, y) = y
# T^(S)_2(x, y) = y*(2**k*(u**2 - 2*u + 1) + 2**(k + 1)*x*(u - 1) + 2**(k + 2) - 2*(u - 1)**2)/(2**k*(u - 1))
# T^(S)_3(x, y) = y*(3*12**k*x**2*(u - 1)**3 + 2**k*(6*2**k*(u - 1)**5 + 6*3**k*(u - 1)**3*(-u**2 + 2*u - 3) + 6**k*(u - 1)**2*(i**2*u*y**2 - i**2*y**2 + u**3 - 3*u**2 + 3*u - 1) + 6*6**k*(u - 1)*(u**2 - 2*u + 1) + 12*6**k*(2*u + (u - 1)**2 - 2)) + 3*6**k*x*(u - 1)**2*(2**k*(u**2 - 2*u + 1) + 4*2**k - 2*(u - 1)**2))/(12**k*(u - 1)**3)
# ...

# %%
TYPE 1 SINE (CHECKED)

# %%
import sympy as sp
import math

# Define all needed symbols including imaginary unit i
y, x, t, u, k, i = sp.symbols('y x t u k i')

# Evaluate coefficients
k=1
u=-1
y=0
#x=0

# Define the polylogarithmic function l_i_k(x)
def l_i_k(x, k, n_terms=10):
    return sum((x**n) / (n**k) for n in range(1, n_terms + 1))

# Define the cosine function using Euler's formula
def sp_sin(y_val, t_val):
    return (sp.exp(i * y_val * t_val) - sp.exp(-i * y_val * t_val)) / (2 * i)

# Define the generating function
numerator = l_i_k(1 - sp.exp(-(1 - u) * t), k)
denominator = t * (sp.exp(2 * t) - u)
generating_function = (numerator / denominator) * sp_sin(y, t)

# Number of terms to compute
n_terms = 5

# Compute Taylor series expansion
try:
    taylor_series = sp.series(generating_function, t, 0, n_terms).removeO()
except Exception as e:
    print(f"Error computing series: {e}")
    taylor_series = 0

# List to store the tangent numbers
tangent_number = []

# Compute the first few tangent numbers
for n in range(n_terms):
    try:
        # Coefficient of t^n in the Taylor series
        coeff = taylor_series.coeff(t, n) if taylor_series != 0 else 0
        # Multiply by n! to get I_n(x)
        I_n = coeff * sp.factorial(n)
        tangent_number.append(sp.simplify(I_n))
    except Exception as e:
        print(f"Error processing term n={n}: {e}")
        tangent_number.append(0)

# Display the polynomials I_n(x)
print("\nType I Frobenius-type poly-tangent polynomials:")
for n, I_n in enumerate(tangent_number):
    print(f"I_{n,1}^(({k}))(x) = {I_n}")  # Fixed to show k in output

# Now, generate the polynomials T_n(x, y)
print("\nGeneralized polynomials:")
polynomials_x_y = []
for n in range(n_terms):
    try:
        T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
        simplified = sp.simplify(T_n_x_y)
        polynomials_x_y.append(simplified)
        print(f"T^(S)_{n}(x, y) = {simplified}")
    except Exception as e:
        print(f"Error generating polynomial for n={n}: {e}")
        polynomials_x_y.append(0)
# Out:
# Type I Frobenius-type poly-tangent polynomials:
# I_(0, 1)^((1))(x) = 0
# I_(1, 1)^((1))(x) = 0
# I_(2, 1)^((1))(x) = 0
# I_(3, 1)^((1))(x) = 0
# I_(4, 1)^((1))(x) = 0
#
# Generalized polynomials:
# T^(S)_0(x, y) = 0
# T^(S)_1(x, y) = 0
# T^(S)_2(x, y) = 0
# T^(S)_3(x, y) = 0
# T^(S)_4(x, y) = 0

# %%
ZERO OF SINE TYPE 1

# %%
import sympy as sp
import matplotlib.pyplot as plt

# Define the symbols
x, y, u, k, i = sp.symbols('x y u k i')

# Define the polynomial
polynomial = y*(180*1035816986896206114738442016528642173334526794053483215749919182684160000000000000000000**k*x**7*(u - 1)**4*(2**k*(u**2 - 2*u + 1) + 4*2**k - 2*(u - 1)**2)*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**7 - 7*u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1) + 1750457110463182821353767900590832000539033600000000000**k*(u - 1
u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1)*(-720*149299200**k*(u - 1)**10 + 1800*179159040**k*(u - 1)**8*(u**2 - 2*u + 1) + 1440*179159040**k*(u - 1)**8 + 120*223948800**k*(u - 1)**6*(12*u*(u - 1)**2 - 4*(u - 1)*(u**3 - 1) - 9*(u**2 - 2*u + 1)**2) + 120*223948800**k*(u - 1)**5*(-i**2*y**2*(u - 1)**3 - 24*u - 12*(u - 1)**2 - 24*(u - 1)*(u**2 - 2*u + 1) + 24) + 180*298598400**k*i**2*y**2*(u - 1)**6*(u**2 - 2*u + 1) + 240*298598400**k*i**2*y**2*(u - 1)**6 + 960*298598400**k*(u - 1)**4*(6*u + (u - 1)**2) + 360*298598400**k*(u - 1)**4*(2*(u - 1)*(u**3 - 3*u**2 + 3*u - 1) + 3*(u**2 - 2*u + 1)**2) + 90*298598400**k*(u - 1)**4*(6*u**2*(u - 1)**2 - 4*u*(u - 1)**2*(u**2 + 1) + (u - 1)**2*(u**4 + 1) - 4*(u - 1)*(u**2 - 2*u + 1)*(-u**3 + 3*u*(u - 1) + 1) + (u**2 - 2*u + 1)**3) + 2160*298598400**k*(u - 1)**3*(2*u + (u - 1)**2 - 2)*(u**2 - 2*u + 1) - 6*447897600**k*i**4*y**4*(u - 1)**6 + 240*447897600**k*i**2*y**2*(u - 1)**4*(-u**2 + 2*u - 1) + 10*447897600**k*i**2*y**2*(u - 1)**4*(12*u*(u - 1)**2 - 4*(u - 1)*(u**3 - 1) - 3*(u**2 - 2*u + 1)**2) + 240*447897600**k*i**2*y**2*(u - 1)**3*(-2*u - (u - 1)**2 + 2) + 2*447897600**k*(u - 1)**4*(-60*u**2*(u - 1)**2 + 30*u*(u - 1)*(u**3 - 1) - 6*(u - 1)*(u**5 - 1) - 15*(u**2 - 2*u + 1)*(u**4 + 6*u**2 - 4*u*(u**2 + 1) + 1) - 10*(-u**3 + 3*u*(u - 1) + 1)**2) + 120*447897600**k*(u - 1)**3*(6*u**2*(1 - u) + 4*u*(u - 1)*(u**2 + 1) - (u - 1)*(u**4 + 1) + 2*(u**2 - 2*u + 1)*(-u**3 + 3*u*(u - 1) + 1)) - 960*447897600**k*(u - 1)**2*(6*u + (u - 1)**2)*(u**2 - 2*u + 1) + 480*447897600**k*(u - 1)**2*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) - 120*447897600**k*(u - 1)*(2*u + (u - 1)**2 - 2)*(-12*u*(u - 1)**2 + 4*(u - 1)*(u**3 - 1) + 3*(u**2 - 2*u + 1)**2) + 895795200**k*(u - 1)**4*(3*i**4*u**2*y**4 - 6*i**4*u*y**4 + 3*i**4*y**4 + 5*i**2*u**4*y**2 - 20*i**2*u**3*y**2 + 30*i**2*u**2*y**2 - 20*i**2*u*y**2 + 5*i**2*y**2 + u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 
k*(u - 1)**2*(-2*u - (u - 1)**2 + 2) + 576**k*(u - 1)**3*(2*i**2*u**2*y**2 - 4*i**2*u*y**2 + 2*i**2*y**2 + u**4 - 4*u**3 + 6*u**2 - 4*u + 1) + 8*576**k*(u - 1)**2*(i**2*u*y**2 - i**2*y**2 + u**3 - 3*u**2 + 3*u - 1) + 32*576**k*(u - 1)*(6*u + (u - 1)**2)) + 210*39962075111736347019230016069777861625560447301446111718746882048000000000000000000**k*x**4*(u - 1)*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**7 - 7*u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1)*(360*10368**k*(u - 1)**8 + 720*12960**k*(u - 1)**6*(-u**2 + 2*u - 2) + 60*17280**k*i**2*y**2*(u - 1)**6 + 90*17280**k*(u - 1)**4*(2*(u - 1)*(u**3 - 3*u**2 + 3*u - 1) + 3*(u**2 - 2*u + 1)**2) + 1080*17280**k*(u - 1)**4*(u**2 - 2*u + 1) + 720*17280**k*(u - 1)**3*(2*u + (u - 1)**2 - 2) + 60*25920**k*i**2*y**2*(u - 1)**4*(-u**2 + 2*u - 3) + 30*25920**k*(u - 1)**3*(6*u**2*(1 - u) + 4*u*(u - 1)*(u**2 + 1) - (u - 1)*(u**4 + 1) + 2*(u**2 - 2*u + 1)*(-u**3 + 3*u*(u - 1) + 1)) - 480*25920**k*(u - 1)**2*(6*u + (u - 1)**2) + 60*25920**k*(u - 1)**2*(12*u*(u - 1)**2 - 4*(u - 1)*(u**3 - 1) - 3*(u**2 - 2*u + 1)**2) - 720*25920**k*(u - 1)*(2*u + (u - 1)**2 - 2)*(u**2 - 2*u + 1) + 10*51840**k*i**2*y**2*(u - 1)**3*(u**3 - 1) + 3*51840**k*(u - 1)**3*(i**4*u*y**4 - i**4*y**4 - 10*i**2*u**2*y**2 + 10*i**2*u*y**2 + u**5 - 5*u**4 + 10*u**3 - 10*u**2 + 5*u - 1) + 30*51840**k*(u - 1)**2*(2*i**2*u**2*y**2 - 4*i**2*u*y**2 + 2*i**2*y**2 + u**4 - 4*u**3 + 6*u**2 - 4*u + 1) + 240*51840**k*(6*u + (u - 1)**2)*(u**2 - 2*u + 1) + 240*51840**k*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 120*51840**k*(i**2*u*y**2*(2*u + (u - 1)**2 - 2) + i**2*y**2*(-2*u - (u - 1)**2 + 2) + u**3*(2*u + (u - 1)**2 - 2) + 3*u**2*(-2*u - (u - 1)**2 + 2) + 3*u*(2*u + (u - 1)**2 - 2) - 2*u - (u - 1)**2 + 2)) + 15*82322681561336419774786046331325584679686344854732800000000000000**k*x*(u - 1)**5*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1)*(-24*12582400952578867200000**k*i**6*u**8*y**6 + 192*12582400952578867200000**k*i**6*u**7*y**6 - 672*12582400952578867200000**k*i**6*u**6*y**6 + 1344*12582400952578867200000**k*i**6*u**5*y**6 - 1680*12582400952578867200000**k*i**6*u**4*y**6 + 1344*12582400952578867200000**k*i**6*u**3*y**6 - 672*12582400952578867200000**k*i**6*u**2*y**6 + 192*12
696000**k*u**2 + 473760*54177693696000**k*u - 57120*54177693696000**k + 42*72236924928000**k*i**4*u**8*y**4 - 336*72236924928000**k*i**4*u**7*y**4 + 1176*72236924928000**k*i**4*u**6*y**4 - 2352*72236924928000**k*i**4*u**5*y**4 + 2940*72236924928000**k*i**4*u**4*y**4 - 2352*72236924928000**k*i**4*u**3*y**4 + 1176*72236924928000**k*i**4*u**2*y**4 - 336*72236924928000**k*i**4*u*y**4 + 42*72236924928000**k*i**4*y**4 + 1050*72236924928000**k*i**2*u**10*y**2 - 10500*72236924928000**k*i**2*u**9*y**2 + 49770*72236924928000**k*i**2*u**8*y**2 - 144480*72236924928000**k*i**2*u**7*y**2 + 282660*72236924928000**k*i**2*u**6*y**2 - 390600*72236924928000**k*i**2*u**5*y**2 + 388500*72236924928000**k*i**2*u**4*y**2 - 275520*72236924928000**k*i**2*u**3*y**2 + 132930*72236924928000**k*i**2*u**2*y**2 - 39060*72236924928000**k*i**2*u*y**2 + 5250*72236924928000**k*i**2*y**2 + 1806*72236924928000**k*u**12 - 21672*72236924928000**k*u**11 + 126756*72236924928000**k*u**10 - 460320*72236924928000**k*u**9 + 1156050*72236924928000**k*u**8 - 2102352*72236924928000**k*u**7 + 2846424*72236924928000**k*u**6 - 2907072*72236924928000**k*u**5 + 2217810*72236924928000**k*u**4 - 1250760*72236924928000**k*u**3 + 540036*72236924928000**k*u**2 - 182112*72236924928000**k*u + 35406*72236924928000**k))/(5*2071633973792412229476884033057284346669053588106966431499838365368320000000000000000000**k*(u - 1)**5*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**7 - 7*u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1))

# Substitute i with the imaginary unit (1j)
polynomial = polynomial.subs(i, 1j)

# Function to plot zeros for given parameter values
def plot_zeros(poly, k_value, u_value, x_value, x_range=(-20, 20), y_range=(-20, 20), title=""):
    # Substitute the parameter values
    poly_at_values = poly.subs({k: k_value, u: u_value, x: x_value})
    
    # Calculate the roots
    roots = sp.solveset(poly_at_values, y, domain=sp.S.Complexes)
    
    # Convert the roots to a list of complex numbers
    roots_list = [root.evalf() for root in roots]
    
    # Separate real and imaginary parts
    real_parts = [root.as_real_imag()[0] for root in roots_list]
    imag_parts = [root.as_real_imag()[1] for root in roots_list]
    
    # Plot the zeros
    plt.figure(figsize=(10, 8))
    plt.scatter(real_parts, imag_parts, color='blue', marker='o', s=200, label='Zeros')
    plt.axhline(0, color='black', linewidth=1)
    plt.axvline(0, color='black', linewidth=1)
    plt.xlim(x_range[0], x_range[1])
    plt.ylim(y_range[0], y_range[1])
    plt.xlabel("Real Part")
    plt.ylabel("Imaginary Part")
    plt.title(title)
    plt.grid(True)
    plt.show()

# #Example plots with different parameter values
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=3, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=-3)")
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=-1, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=-1)")
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=1, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=1)")
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=3, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=3)")

# %%
SAVING IT INTO PNG

# %%
import sympy as sp
import matplotlib.pyplot as plt

# Define the symbols
x, y, u, k, i = sp.symbols('x y u k i')

# Define the polynomial
polynomial = y*(180*1035816986896206114738442016528642173334526794053483215749919182684160000000000000000000**k*x**7*(u - 1)**4*(2**k*(u**2 - 2*u + 1) + 4*2**k - 2*(u - 1)**2)*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**7 - 7*u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1) + 1750457110463182821353767900590832000539033600000000000**k*(u - 1)**5*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**7 - 7*u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(5*1183481709668535570215731200000000**k*i**8*u**8*y**8 - 40*1183481709668535570215731200000000**k*i**8*u**7*y**8 + 140*1183481709668535570215731200000000**k*i**8*u**6*y**8 - 280*1183481709668535570215731200000000**k*i**8*u**5*y**8 + 350*1183481709668535570215731200000000**k*i**8*u**4*y**8 - 280*1183481709668535570215731200000000**k*i**8*u**3*y**8 + 140*1183481709668535570215731200000000**k*i**8*u**2*y**8 - 40*1183481709668535570215731200000000**k*i**8*u*y**8 + 5*1183481709668535570215731200000000**k*i**8*y**8 + 60*1183481709668535570215731200000000**k*i**6*u**10*y**6 - 600*1183481709668535570215731200000000**k*i**6*u**9*y**6 + 3060*1183481709668535570215731200000000**k*i**6*u**8*y**6 - 9360*1183481709668535570215731200000000**k*i**6*u**7*y**6 + 19080*1183481709668535570215731200000000**k*i**6*u**6*y**6 - 28800*1183481709668535570215731200000000**k*i**6*u**5*y**6 + 34200*1183481709668535570215731200000000**k*i**6*u**4*y**6 - 30960*1183481709668535570215731200000000**k*i**6*u**3*y**6 + 19260*1183481709668535570215731200000000**k*i**6*u**2*y**6 - 7080*1183481709668535570215731200000000**k*i**6*u*y**6 + 1140*1183481709668535570215731200000000**k*i**6*y**6 + 126*1183481709668535570215731200000000**k*i**4*u**12*y**4 - 1512*1183481709668535570215731200000000**k*i**4*u**11*y**4 + 9576*1183481709668535570215731200000000**k*i**4*u**10*y**4 - 35280*1183481709668535570215731200000000**k*i**4*u**9*y**4 + 93870*1183481709668535570215731200000000**k*i
**k*i**2*y**2*(u - 1)**3*(-2*u - (u - 1)**2 + 2) + 2*447897600**k*(u - 1)**4*(-60*u**2*(u - 1)**2 + 30*u*(u - 1)*(u**3 - 1) - 6*(u - 1)*(u**5 - 1) - 15*(u**2 - 2*u + 1)*(u**4 + 6*u**2 - 4*u*(u**2 + 1) + 1) - 10*(-u**3 + 3*u*(u - 1) + 1)**2) + 120*447897600**k*(u - 1)**3*(6*u**2*(1 - u) + 4*u*(u - 1)*(u**2 + 1) - (u - 1)*(u**4 + 1) + 2*(u**2 - 2*u + 1)*(-u**3 + 3*u*(u - 1) + 1)) - 960*447897600**k*(u - 1)**2*(6*u + (u - 1)**2)*(u**2 - 2*u + 1) + 480*447897600**k*(u - 1)**2*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) - 120*447897600**k*(u - 1)*(2*u + (u - 1)**2 - 2)*(-12*u*(u - 1)**2 + 4*(u - 1)*(u**3 - 1) + 3*(u**2 - 2*u + 1)**2) + 895795200**k*(u - 1)**4*(3*i**4*u**2*y**4 - 6*i**4*u*y**4 + 3*i**4*y**4 + 5*i**2*u**4*y**2 - 20*i**2*u**3*y**2 + 30*i**2*u**2*y**2 - 20*i**2*u*y**2 + 5*i**2*y**2 + u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1) + 4*895795200**k*(u - 1)**3*(3*i**4*u*y**4 - 3*i**4*y**4 + 10*i**2*u**3*y**2 - 30*i**2*u**2*y**2 + 30*i**2*u*y**2 - 10*i**2*y**2 + 3*u**5 - 15*u**4 + 30*u**3 - 30*u**2 + 15*u - 3) + 60*895795200**k*(u - 1)*(2*u + (u - 1)**2 - 2)*(2*i**2*u**2*y**2 - 4*i**2*u*y**2 + 2*i**2*y**2 + u**4 - 4*u**3 + 6*u**2 - 4*u + 1) + 240*895795200**k*(u**2 - 2*u + 1)*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 192*895795200**k*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) + 160*895795200**k*(i**2*u*y**2*(u - 1)*(6*u + (u - 1)**2) + i**2*y**2*(-6*u - (u - 1)**3 - 6*(u - 1)**2 + 6) + u**3*(u - 1)*(6*u + (u - 1)**2) - 3*u**2*(u - 1)*(6*u + (u - 1)**2) + 3*u*(u - 1)*(6*u + (u - 1)**2) - (u - 1)*(6*u + (u - 1)**2))) + 420*345272328965402038246147338842880724444842264684494405249973060894720000000000000000000**k*x**6*(u - 1)**2*(6*2**k*(u - 1)**5 + 6*3**k*(u - 1)**3*(-u**2 + 2*u - 3) + 6**k*(u - 1)**2*(i**2*u*y**2 - i**2*y**2 + u**3 - 3*u**2 + 3*u - 1) + 6*6**k*(u - 1)*(u**2 - 2*u + 1) + 12*6**k*(2*u + (u - 1)**2 - 2))*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**7 - 7*u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1) + 630*3596586760056271231730701446280007546300440257130150054687219384320000000000000000000**k*x**5*(u - 1)*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**7 - 7*u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1)*(-24*12**(2*k)*(u - 1)**7 + 36*192**k*(u - 1)**5*(u**2 - 2*u + 1) + 48*192**k*(u - 1)**5 + 24*24**(2*k)*(2*u + (u - 1)**2 - 2)*(u**2 - 2*u + 1) - 4*288**k*i**2*y**2*(u - 1)**5 + 48*288**k*(u - 1)**3*(-u**2 + 2*u - 1) + 2*288**k*(u - 1)**3*(12*u*(u - 1)**2 - 4*(u - 1)*(u**3 - 1) - 3*(u**2 - 2*u + 1)**2) + 48*288**k*(u - 1)**2*(-2*u - (u - 1)**2 + 2) + 576**k*(u - 1)**3*(2*i**2*u**2*y**2 - 4*i**2*u*y**2 + 2*i**2*y**2 + u**4 - 4*u**3 + 6*u**2 - 4*u + 1) + 8*576**k*(u - 1)**2*(i**2*u*y**2 - i**2*y**2 + u**3 - 3*u**2 + 3*u - 1) + 32*576**k*(u - 1)*(6*u + (u - 1)**2)) + 210*39962075111736347019230016069777861625560447301446111718746882048000000000000000000**k*x**4*(u - 1)*(u**6 - 6*u**5 + 15*u**4 - 20*u**3 + 15*u**2 - 6*u + 1)*(u**7 - 7*u**6 + 21*u**5 - 35*u**4 + 35*u**3 - 21*u**2 + 7*u - 1)*(u**8 - 8*u**7 + 28*u**6 - 56*u**5 + 70*u**4 - 56*u**3 + 28*u**2 - 8*u + 1)*(360*10368**k*(u - 1)**8 + 720*12960**k*(u - 1)**6*(-u**2 + 2*u - 2) + 60*17280**k*i**2*y**2*(u - 1)**6 + 90*17280**k*(u - 1)**4*(2*(u - 1)*(u**3 - 3*u**2 + 3*u - 1) + 3*(u**2 - 2*u + 1)**2) + 1080*17280**k*(u - 1)**4*(u**2 - 2*u + 1) + 720*17280**k*(u - 1)**3*(2*u + (u - 1)**2 - 2) + 60*25920**k*i**2*y**2*(u - 1)**4*(-u**2 + 2*u - 3) + 30*25920**k*(u - 1)**3*(6*u**2*(1 - u) + 4*u*(u - 1)*(u**2 + 1) - (u - 1)*(u**4 + 1) + 2*(u**2 - 2*u + 1)*(-u**3 + 3*u*(u - 1) + 1)) - 480*25920**k*(u - 1)**2*(6*u + (u - 1)**2) + 60*25920**k*(u - 1)**2*(12*u*(u - 1)**2 - 4*(u - 1)*(u**3 - 1) - 3*(u**2 - 2*u + 1)**2) - 720*25920**k*(u - 1)*(2*u + (u - 1)**2 - 2)*(u**2 - 2*u + 1) + 10*51840**k*i**2*y**2*(u - 1)**3*(u**3 - 1) + 3*51840**k*(u - 1)**3*(i**4*u*y**4 - i**4*y**4 - 10*i**2*u**2*y**2 + 10*i**2*u*y**2 + u**5 - 5*u**4 + 10*u**3 - 10*u**2 + 5*u - 1) + 30*51840**k*(u - 1)**2*(2*i**2*u**2*y**2 - 4*i**2*u*y**2 + 2*i**2*y**2 + u**4 - 4*u**3 + 6*u**2 - 4*u + 1) + 240*51840**k*(6*u + (u - 1)**2)*(u**2 - 2*u + 1) + 240*51840**k*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12
# Substitute i with the imaginary unit (1j)
polynomial = polynomial.subs(i, 1j)

# Function to plot zeros for given parameter values
def plot_zeros(poly, k_value, u_value, x_value, x_range=(-20, 20), y_range=(-20, 20), title=""):
    # Substitute the parameter values
    poly_at_values = poly.subs({k: k_value, u: u_value, x: x_value})
    
    # Calculate the roots
    roots = sp.solveset(poly_at_values, y, domain=sp.S.Complexes)
    
    # Convert the roots to a list of complex numbers
    roots_list = [root.evalf() for root in roots]
    
    # Separate real and imaginary parts
    real_parts = [root.as_real_imag()[0] for root in roots_list]
    imag_parts = [root.as_real_imag()[1] for root in roots_list]
    
    # Plot the zeros
    plt.figure(figsize=(10, 8))
    plt.scatter(real_parts, imag_parts, color='blue', marker='o', s=200, label='Zeros')
    plt.axhline(0, color='black', linewidth=1)
    plt.axvline(0, color='black', linewidth=1)
    plt.xlim(x_range[0], x_range[1])
    plt.ylim(y_range[0], y_range[1])
    plt.xlabel("Real Part")
    plt.ylabel("Imaginary Part")
    plt.title(title)
    plt.grid(True)

    # Create a filename from the title (remove special characters)
    filename = f"zeros_k_{k_value}_u_{u_value}_x_{x_value}.png"
    
    # Save the figure
    plt.savefig(filename, bbox_inches='tight', dpi=300)
    plt.close()  # Close the figure to free memory

#Example plots with different parameter values
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=3, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=-3)")
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=-1, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=-1)")
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=1, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=1)")
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=3, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=3)")

# %%
TYPE 2 POLYNOMIALS AND NUMBERS

# %%
import sympy as sp

# Define symbols
x, t, u, k = sp.symbols('x t u k')

# Evaluate coefficients
#k=1
#u=-1

# Define the polyexponential function Ei_k(x)
def Ei_k(x, k, n_terms=10):
    return sum((x**n) / (n**k * sp.factorial(n-1)) for n in range(1, n_terms + 1))

# Define the generating function
numerator = Ei_k(sp.log(1 + (1 - u) * t), k)
denominator = t * (sp.exp(2 * t) - u)
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# Compute Taylor series expansion
taylor_series = sp.series(generating_function, t, 0, n_terms).removeO()

# List to store the tangent numbers
tangent_number = []

# Compute the first few tangent numbers
for n in range(n_terms):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get I_n(x)
    T_n = coeff * sp.factorial(n)
    tangent_number.append(T_n)

# Display the polynomials I_n(x)
for n, T_n in enumerate(tangent_number):
    print(f"T_{n,1}^((k)) = {sp.simplify(T_n)}")

# Now, generate the polynomials T_n(x)
polynomials_x = []
for n in range(n_terms):
    T_n_x = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x.append(sp.simplify(T_n_x))

# Display the polynomials T_n(x)
for n, T_n_x in enumerate(polynomials_x):
    print(f"T_{n}(x) = {T_n_x}")
# Out:
# T_(0, 1)^((k)) = 1
# T_(1, 1)^((k)) = u/2 - 1/2 + 2/(u - 1) - u/2**k + 2**(-k)
# T_(2, 1)^((k)) = 2**k*(u - 1)**2/6**k - 2*3**k*(u - 1)**2/6**k - 4*3**k/6**k + 4*u/(u - 1)**2 + 2*(u - 1)**2/3 + 2 + 4/(u - 1)**2
# T_(3, 1)^((k)) = (-2*12**k*(u - 1)**6 + 3*16**k*(u - 1)**3*(4*u + 3*(u - 1)**3 - 4) + 24**k*(u - 1)**3*(-24*u - 11*(u - 1)**3 + 24) + 24*24**k*(u - 1)*(-2*u - (u - 1)**2 + 2) + 48**k*(u - 1)**3*(8*u + 3*(u - 1)**3 - 8) + 16*48**k*(u - 1)**2 + 12*48**k*(u - 1)*(2*u + (u - 1)**2 + 6) + 96*48**k)/(2*48**k*(u - 1)**3)
# ...

# %%
TYPE 2 POLYNOMIALS AND NUMBERS (CHECKED)

# %%
import sympy as sp

# Define symbols
x, t, u, k = sp.symbols('x t u k')

# Evaluate coefficients
k=1
u=-1

# Define the polyexponential function Ei_k(x)
def Ei_k(x, k, n_terms=10):
    return sum((x**n) / (n**k * sp.factorial(n-1)) for n in range(1, n_terms + 1))

# Define the generating function
numerator = Ei_k(sp.log(1 + (1 - u) * t), k)
denominator = t * (sp.exp(2 * t) - u)
generating_function = numerator / denominator

# Number of terms to compute
n_terms = 5

# Compute Taylor series expansion
taylor_series = sp.series(generating_function, t, 0, n_terms).removeO()

# List to store the tangent numbers
tangent_number = []

# Compute the first few tangent numbers
for n in range(n_terms):
    # Coefficient of t^n in the Taylor series
    coeff = taylor_series.coeff(t, n)
    # Multiply by n! to get I_n(x)
    T_n = coeff * sp.factorial(n)
    tangent_number.append(T_n)

# Display the polynomials I_n(x)
for n, T_n in enumerate(tangent_number):
    print(f"T_{n,1}^((k)) = {sp.simplify(T_n)}")

# Now, generate the polynomials T_n(x)
polynomials_x = []
for n in range(n_terms):
    T_n_x = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
    polynomials_x.append(sp.simplify(T_n_x))

# Display the polynomials T_n(x)
for n, T_n_x in enumerate(polynomials_x):
    print(f"T_{n}(x) = {T_n_x}")
# Out:
# T_(0, 1)^((k)) = 1
# T_(1, 1)^((k)) = -1
# T_(2, 1)^((k)) = 0
# T_(3, 1)^((k)) = 2
# T_(4, 1)^((k)) = 0
# T_0(x) = 1
# T_1(x) = x - 1
# T_2(x) = x*(x - 2)
# T_3(x) = x**3 - 3*x**2 + 2
# T_4(x) = x*(x**3 - 4*x**2 + 8)

# %%
COSINE TYPE 2 POLYNOMIALS

# %%
import sympy as sp

# Define all needed symbols including imaginary unit i
y, x, t, u, k, i = sp.symbols('y x t u k i')

# Evaluate coefficients
#k=1
#u=-1
#y=0
#x=0

# Define the polyexponential function Ei_k(x)
def Ei_k(x, k, n_terms=10):
    return sum((x**n) / (n**k * sp.factorial(n-1)) for n in range(1, n_terms + 1))

# Define the cosine function using Euler's formula
def sp_cos(y_val, t_val):
    return (sp.exp(i * y_val * t_val) + sp.exp(-i * y_val * t_val)) / 2

# Define the generating function
numerator = Ei_k(sp.log(1 + (1 - u) * t), k)
denominator = t * (sp.exp(2 * t) - u)
generating_function = (numerator / denominator)  * sp_cos(y, t)

# Number of terms to compute
n_terms = 10

# Compute Taylor series expansion
try:
    taylor_series = sp.series(generating_function, t, 0, n_terms).removeO()
except Exception as e:
    print(f"Error computing series: {e}")
    taylor_series = 0

# List to store the tangent numbers
tangent_number = []

# Compute the first few tangent numbers
for n in range(n_terms):
    try:
        # Coefficient of t^n in the Taylor series
        coeff = taylor_series.coeff(t, n) if taylor_series != 0 else 0
        # Multiply by n! to get T_n(x)
        T_n = coeff * sp.factorial(n)
        tangent_number.append(sp.simplify(T_n))
    except Exception as e:
        print(f"Error processing term n={n}: {e}")
        tangent_number.append(0)

# Now, generate the polynomials T_n(x, y)
print("\nGeneralized polynomials:")
polynomials_x_y = []
for n in range(n_terms):
    try:
        T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
        simplified = sp.simplify(T_n_x_y)
        polynomials_x_y.append(simplified)
        print(f"T^(C)_{n}(x, y) = {simplified}")
    except Exception as e:
        print(f"Error generating polynomial for n={n}: {e}")
        polynomials_x_y.append(0)
# Out:
# Generalized polynomials:
# T^(C)_0(x, y) = 1
# T^(C)_1(x, y) = (2**k*(u - 1)*(u + 2*x - 1) + 4*2**k - 2*(u - 1)**2)/(2*2**k*(u - 1))
# T^(C)_2(x, y) = (12**k*(u - 1)**2*(3*i**2*y**2 + 3*x**2 + 2*(u - 1)**2 + 6) + 12**(k + 1)*(u + 1) + 3*2**k*(u - 1)**2*(2**k*(u - 1)**2 - 2*3**k*(u - 1)**2 - 4*3**k) + 3*6**k*x*(u - 1)*(2**k*(u - 1)**2 + 2**(k + 2) - 2*(u - 1)**2))/(3*12**k*(u - 1)**2)
# ...

# %%
COSINE TYPE 2 POLYNOMIALS

# %%
import sympy as sp

# Define all needed symbols including imaginary unit i
y, x, t, u, k, i = sp.symbols('y x t u k i')

# Evaluate coefficients
k=1
u=-1
y=0
#x=0

# Define the polyexponential function Ei_k(x)
def Ei_k(x, k, n_terms=10):
    return sum((x**n) / (n**k * sp.factorial(n-1)) for n in range(1, n_terms + 1))

# Define the cosine function using Euler's formula
def sp_cos(y_val, t_val):
    return (sp.exp(i * y_val * t_val) + sp.exp(-i * y_val * t_val)) / 2

# Define the generating function
numerator = Ei_k(sp.log(1 + (1 - u) * t), k)
denominator = t * (sp.exp(2 * t) - u)
generating_function = (numerator / denominator)  * sp_cos(y, t)

# Number of terms to compute
n_terms = 6

# Compute Taylor series expansion
try:
    taylor_series = sp.series(generating_function, t, 0, n_terms).removeO()
except Exception as e:
    print(f"Error computing series: {e}")
    taylor_series = 0

# List to store the tangent numbers
tangent_number = []

# Compute the first few tangent numbers
for n in range(n_terms):
    try:
        # Coefficient of t^n in the Taylor series
        coeff = taylor_series.coeff(t, n) if taylor_series != 0 else 0
        # Multiply by n! to get T_n(x)
        T_n = coeff * sp.factorial(n)
        tangent_number.append(sp.simplify(T_n))
    except Exception as e:
        print(f"Error processing term n={n}: {e}")
        tangent_number.append(0)

# Display the polynomials I_n(x)
print("\nType I Frobenius-type poly-tangent polynomials:")
for n, T_n in enumerate(tangent_number):
    print(f"T_{n,1}^(({k}))(x) = {T_n}")  # Fixed to show k in output

# Now, generate the polynomials T_n(x, y)
print("\nGeneralized polynomials:")
polynomials_x_y = []
for n in range(n_terms):
    try:
        T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
        simplified = sp.simplify(T_n_x_y)
        polynomials_x_y.append(simplified)
        print(f"T^(C)_{n}(x, y) = {simplified}")
    except Exception as e:
        print(f"Error generating polynomial for n={n}: {e}")
        polynomials_x_y.append(0)
# Out:
# Type I Frobenius-type poly-tangent polynomials:
# T_(0, 1)^((1))(x) = 1
# T_(1, 1)^((1))(x) = -1
# T_(2, 1)^((1))(x) = 0
# T_(3, 1)^((1))(x) = 2
# T_(4, 1)^((1))(x) = 0
# T_(5, 1)^((1))(x) = -16
#
# Generalized polynomials:
# T^(C)_0(x, y) = 1
# T^(C)_1(x, y) = x - 1
# T^(C)_2(x, y) = x*(x - 2)
# T^(C)_3(x, y) = x**3 - 3*x**2 + 2
# T^(C)_4(x, y) = x*(x**3 - 4*x**2 + 8)
# T^(C)_5(x, y) = x**5 - 5*x**4 + 20*x**2 - 16

# %%
ZERO OF COSINE TYPE 2

# %%
import sympy as sp
import matplotlib.pyplot as plt

# Define the symbols
x, y, u, k, i = sp.symbols('x y u k i')

# Define the polynomial
polynomial =  (3*14181944181993379339671730676083129633996800000000000**k*x*(u - 1)*(10402117189632000**k*i**4*y**4*(u - 1)**7*(10080*u + 5040*(u - 1)**2 - 10080) + 10402117189632000**k*i**2*y**2*(u - 1)**8*(362880*u + 60480*(u - 1)**2) + 10402117189632000**k*i**2*y**2*(u - 1)**6*(725760*u + 20160*(u - 1)**3 + 282240*(u - 1)**2 - 241920) + 10402117189632000**k*(u - 1)**10*(907200*u + 151200*(u - 1)**2) + 10402117189632000**k*(u - 1)**9*(i**6*y**6*(84*u - 84) + 4410*i**4*y**4*(u - 1)**3 + i**4*y**4*(7560*u - 7560) + 58464*i**2*y**2*(u - 1)**5 + 113400*i**2*y**2*(u - 1)**3 + i**2*y**2*(211680*u + 105840*(u - 1)**2 - 211680) + 118124*(u - 1)**7 + 236376*(u - 1)**5 + (u - 1)**2*(467712*u + 233856*(u - 1)**2 - 467712)) + 10402117189632000**k*(u - 1)**8*(2540160*u + 70560*(u - 1)**3 + 987840*(u - 1)**2 - 846720) + 10402117189632000**k*(u - 1)**6*(5806080*u + 24192*(u - 1)**4 + 725760*(u - 1)**3 + 3628800*(u - 1)**2 - 2903040) + 10402117189632000**k*(u - 1)**4*(9676800*u + 5376*(u - 1)**5 + 333312*(u - 1)**4 + 2903040*(u - 1)**3 + 8386560*(u - 1)**2 - 5806080) + 15603175784448000**k*i**4*y**4*(u - 1)**7*(-20160*u - 10080*(u - 1)**2 + 20160) + 15603175784448000**k*i**4*y**4*(u - 1)**5*(-40320*u - 6720*(u - 1)**3 - 40320*(u - 1)**2 + 40320) + 15603175784448000**k*i**2*y**2*(u - 1)**7*(-443520*u - 73920*(u - 1)**3 - 443520*(u - 1)**2 + 443520) + 15603175784448000**k*i**2*y**2*(u - 1)**5*(-967680*u - 40320*(u - 1)**4 - 564480*(u - 1)**3 - 1451520*(u - 1)**2 + 967680) + 15603175784448000**k*i**2*y**2*(u - 1)**3*(-1935360*u - 16128*(u - 1)**5 - 483840*(u - 1)**4 - 2419200*(u - 1)**3 - 3870720*(u - 1)**2 + 1935360) + 15603175784448000**k*(u - 1)**9*(-736512*u - 122752*(u - 1)**3 - 736512*(u - 1)**2 + 736512) + 15603175784448000**k*(u - 1)**8*(-168*i**6*y**6*(u - 1)**2 - 336*i**6*y**6 - 4200*i**4*y**4*(u - 1)**4 - 9240*i**4*y**4*(u - 1)**2 - 42336*i**2*y**2*(u - 1)**6 - 92064*i**2*y**2*(u - 1)**4 - 100800*i**2*y**2*(u - 1)*(2*u + (u - 1)**2 - 2) - 73056*(u - 1)**8 - 156816*(u - 1)**6 + (u - 1)**3*(-338688*u - 169344*(u - 1)**2 + 338688)) + 15603175784448000**k*(u - 1)**7*(-1612800*u - 67200*(u - 1)**4 - 940800*(u - 1)**3 - 2419200*(u - 1)**2 + 1612800) + 15603175784448000**k*(u - 1)**5*(-3548160*u - 29568*(u - 1)**5 - 887040*(u - 1)**4 - 4435200*(u - 1)**3 - 7096320*(u - 1)**2 + 3548160) + 15603175784448000**k*(u - 1)**3*(-7741440*u - 10752*(u - 1)**6 - 666624*(u - 1)**5 - 5806080*(u - 1)**4 - 16773120*(u - 1)**3 - 19353600*(u - 1)**2 + 7741440) - 3072*15603175784448000**k*(u - 1)*(5040*u + (u - 1)**7 + 126*(u - 1)**6 + 1806*(u - 1)**5 + 8400*(u - 1)**4 + 16800*(u - 1)**3 + 15120*(u - 1)**2 - 5040) + 31206351568896000**k*i**4*y**4*(u - 1)**6*(20160*u + 3360*(u - 1)**2) + 31206351568896000**k*i**4*y**4*(u - 1)**4*(120960*u + 3360*(u - 1)**3 + 47040*(u - 1)**2 - 40320) + 31206351568896000**k*i**2*y**2*(u - 1)**8*(120960*u + 20160*(u - 1)**2) + 31206351568896000**k*i**2*y**2*(u - 1)**6*(483840*u + 13440*(u - 1)**3 + 188160*(u - 1)**2 - 161280) + 31206351568896000**k*i**2*y**2*(u - 1)**4*(1935360*u + 8064*(u - 1)**4 + 241920*(u - 1)**3 + 1209600*(
)**8*(120960*u + 3360*(u - 1)**3 + 47040*(u - 1)**2 - 40320) + 7801587892224000**k*i**2*y**2*(u - 1)**7*(-80640*u - 13440*(u - 1)**3 - 80640*(u - 1)**2 + 80640) + 7801587892224000**k*(u - 1)**9*(-456960*u - 76160*(u - 1)**3 - 456960*(u - 1)**2 + 456960) + 7801587892224000**k*(u - 1)**9*(i**4*y**4*(1680 - 1680*u) - 1680*i**4*y**4*(u - 1)**3 - 35280*i**2*y**2*(u - 1)**5 - 57120*i**2*y**2*(u - 1)**3 + i**2*y**2*(-80640*u - 40320*(u - 1)**2 + 80640) - 89712*(u - 1)**7 - 162456*(u - 1)**5 + (u - 1)**2*(-282240*u - 141120*(u - 1)**2 + 282240)) + 7801587892224000**k*(u - 1)**8*(-967680*u - 26880*(u - 1)**3 - 376320*(u - 1)**2 + 322560) + 7801587892224000**k*(u - 1)**5*(-645120*u - 5376*(u - 1)**5 - 161280*(u - 1)**4 - 806400*(u - 1)**3 - 1290240*(u - 1)**2 + 645120)) + 221283368036872296354624892538603171618996894969521766400000000000000**k*x**8*(u - 1)**8*(45*2**k*(u - 1)**2 + 45*2**(k + 2) - 90*(u - 1)**2)/10 + 2344898178239646054839902558876178841600000000**k*(-10*18873601428868300800000**k*(u - 1)**18 + 188736014288683008000000**k*i**6*y**6*(u - 1)**6*(40320*u + 6720*(u - 1)**2) + 188736014288683008000000**k*i**4*y**4*(u - 1)**8*(403200*u + 67200*(u - 1)**2) + 188736014288683008000000**k*i**4*y**4*(u - 1)**6*(1814400*u + 50400*(u - 1)**3 + 705600*(u - 1)**2 - 604800) + 188736014288683008000000**k*i**4*y**4*(u - 1)**4*(9676800*u + 40320*(u - 1)**4 + 1209600*(u - 1)**3 + 6048000*(u - 1)**2 - 4838400) + 188736014288683008000000**k*i**2*y**2*(u - 1)**10*(2903040*u + 483840*(u - 1)**2) + 188736014288683008000000**k*i**2*y**2*(u - 1)**8*(10886400*u + 302400*(u - 1)**3 + 4233600*(u - 1)**2 - 3628800) + 188736014288683008000000**k*i**2*y**2*(u - 1)**6*(38707200*u + 161280*(u - 1)**4 + 4838400*(u - 1)**3 + 24192000*(u - 1)**2 - 19353600) + 188736014288683008000000**k*i**2*y**2*(u - 1)**4*(145152000*u + 80640*(u - 1)**5 + 4999680*(u - 1)**4 + 43545600*(u - 1)**3 + 125798400*(u - 1)**2 - 87091200) + 188736014288683008000000**k*i**2*y**2*(u - 1)**2*(696729600*u + 46080*(u - 1)**6 + 5806080*(u - 1)**5 + 83220480*(u - 1)**4 + 387072000*(u - 1)**3 + 774144000*(u - 1)**2 - 464486400) + 188736014288683008000000**k*(u - 1)**12*(4147200*u + 691200*(u - 1)**2) + 188736014288683008000000**k*(u - 1)**10*(14515200*u + 403200*(u - 1)**3 + 5644800*(u - 1)**2 - 4838400) + 188736014288683008000000**k*(u - 1)**9*(i**8*y**8*(45*u - 45) + 1260*i**6*y**6*(u - 1)**3 + i**6*y**6*(3360*u - 3360) + 25200*i**4*y**4*(u - 1)**5 + 60480*i**4*y**4*(u - 1)**3 + i**4*y**4*(151200*u + 75600*(u - 1)**2 - 151200) + 226800*i**2*y**2*(u - 1)**7 + 518400*i**2*y**2*(u - 1)**5 + i**2*y**2*(u - 1)**2*(1209600*u + 604800*(u - 1)**2 - 1209600) + 362880*(u - 1)**9 + 806400*(u - 1)**7 + (u - 1)**4*(1814400*u + 907200*(u - 1)**2 - 1814400)) + 188736014288683008000000**k*(u - 1)**8*(180*i**8*y**8 + 5120) + 188736014288683008000000**k*(u - 1)**8*(46448640*u + 193536*(u - 1)**4 + 5806080*(u - 1)**3 + 29030400*(u - 1)**2 - 23224320) + 188736014288683008000000**k*(u - 1)**7*(i**6*y**6*(10080*u + 5040*(u - 1)**2 - 10080) + 2611200) + 188736014288683008000000**k*(u - 1)**6*(145152000*u + 80640*(u - 1)**5 + 4999680*(u - 1)**4 + 43545600*(u - 1)**3 + 125798400*(u - 1)**2 - 87091200) + 92928000*188736014288683008000000**k*(u - 1)**6 + 954777600*188736014288683008000000**k*(u - 1)**5 + 188736014288683008000000**k*(u - 1)**4*(464486400*u + 30720*(u - 1)**6 + 3870720*(u - 1)**5 + 55480320*(u - 1)**4 + 258048000*(u - 1)**3 + 516096000*(u - 1)**2 - 309657600) + 4270694400*188736014288683008000000**k*(u - 1)**4 + 9754214400*188736014288683008000000**k*(u - 1)**3 + 188736014288683008000000**k*(u - 1)**2*(1625702400*u + 11520*(u - 1)**7 + 2926080*(u - 1)**6 + 66769920*(u - 1)**5 + 470292480*(u - 1)**4 + 1451520000*(u - 1)**3 + 2206310400*(u - 1)**2 - 1161216000) + 11921817600*188736014288683008000000**k*(u - 1)**2 + 188736014288683008000000**k*(7431782400*u - 7431782400) + 1857945600*188736014288683008000000**k + 20970668254298112000000**k*(u - 1)**16*(405*(u - 1)**2 + 180) + 23592001786085376000000**k*(u - 1)**13*(-360*i**2*y**2*(u - 1)**3 - 2880*u - 6960*(u - 1)**5 - 5760*(u - 1)**3 - 1440*(u - 1)**2 + 2880) + 26962287755526144000000**k*(u - 1)**13*(8820*i**2*y**2*(u - 1)**3 + i**2*y**2*(5040*u - 5040) + 70560*u + 66150*(u - 1)**5 + 76440*(u - 1)**3 + 35280*(u - 1)**2 - 70560) + 26962287755526144000000**k*(u - 1)**12*(40320*u + 6720*(u - 1)**2) + 31456002381447168000000**k*(u - 1)**11*(-1260*i**4*y**4*(u - 1)**3 - 86940*i**2*y**2*(u - 1)**5 - 90720*i**2*y**2*(u - 1)**3 + i**2*y**2*(-60480*u - 30240*(u - 1)**2 + 60480) - 725760*u - 379638*(u - 1)**7 - 544320*(u - 1)**5 - 120960*(u - 1)**3 + (u - 1)**2*(-695520*u - 347760*(u - 1)**2 + 695520) - 725760*(u - 1)**2 + 725760) + 31456002381447168000000**k*(u - 1)**9*(-483840*u - 20160*(u - 1)**4 - 282240*(u - 1)**3 - 725760*(u - 1)**2 + 483840) + 37747202857736601600000**k*i**2*y**2*(u - 1)**10*(604800*u + 100800*(u - 1)**2) + 37747202857736601600000**k*(u - 1)**12*(5040000*u + 840000*(u - 1)**2) + 37747202857736601600000**k*(u - 1)**11*(15750*i**4*y**4*(u - 1)**3 + i**4*y**4*(12600*u - 12600) + 441000*i**2*y**2*(u - 1)**5 + 630000*i**2*y**2*(u - 1)**3 + i**2*y**2*(756000*u + 378000*(u - 1)**2 - 756000) + 1346625*(u - 1)**7 + 2244900*(u - 1)**5 + (u - 1)**2*(3528000*u + 1764000*(u - 1)**2 - 3528000)) + 37747202857736601600000**k*(u - 1)**10*(9072000*u + 252000*(u - 1)**3 + 3528000*(u - 1)**2 - 3024000) + 37747202857736601600000**k*(u - 1)**8*(9676800*u + 40320*(u - 1)**4 + 1209600*(u - 1)**3 + 6048000*(u - 1)**2 - 4838400) + 47184003572170752000000**k*i**2*y**2*(-4838400*u - 806400*(u - 1)**2)*(u - 1)**10 + 47184003572170752000000**k*i**2*y**2*(u - 1)**7*(-4838400*u - 201600*(u - 1)**4 - 2822400*(u - 1)**3 - 7257600*(u - 1)**2 + 4838400) + 47184003572170752000000**k*(u - 1)**11*(-16934400*u - 2822400*(u - 1)**3 - 16934400*(u - 1)**2 + 16934400) + 47184003572170752000000**k*(u - 1)**9*(-27417600*u - 1142400*(u - 1)**4 - 15993600*(u - 1)**3 - 41126400*(u - 1)**2 + 27417600) + 47184003572170752000000**k*(u - 1)**9*(-840*i**6*y**6*(u - 1)**3 - 71400*i**4*y**4*(u - 1)**5 - 100800*i**4*y**4*(u - 1)**3 + i**4*y**4*(-100800*u - 50400*(u - 1)**2 + 100800) - 1218420*i**2*y**2*(u - 1)**7 - 2116800*i**2*y**2*(u - 1)**5 + i**2*y**2*(u - 1)**2*(-3427200*u - 1713600*(u - 1)**2 + 3427200) - 2894720*(u - 1)**9 - 5382720*(u - 1)**7 + (u - 1)**4*(-9747360*u - 4873680*(u - 1)**2 + 9747360)) + 47184003572170752000000**k*(u - 1)**8*(-77414400*u - 322560*(u - 1)**4 - 9676800*(u - 1)**3 - 48384000*(u - 1)**2 + 38707200) + 47184003572170752000000**k*(u - 1)**5*(-38707200*u - 53760*(u - 1)**6 - 3333120*(u - 1)**5 - 29030400*(u - 1)**4 - 83865600*(u - 1)**3 - 96768000*(u - 1)**2 + 38707200) + 62912004762894336000000**k*i**4*y**4*(u - 1)**9*(453600*u + 226800*(u - 1)**2 - 453600) + 62912004762894336000000**k*i**4*y**4*(u - 1)**8*(604800*u + 100800*(u - 1)**2) + 62912004762894336000000**k*i**2*y**2*(u - 1)**10*(12700800*u + 2116800*(u - 1)**2) + 62912004762894336000000**k*i**2*y**2*(u - 1)**8*(32659200*u + 907200*(u - 1)**3 + 12700800*(u - 1)**2 - 10886400) + 62912004762894336000000**k*i**2*y**2*(u - 1)**6*(58060800*u + 241920*(u - 1)**4 + 7257600*(u - 1)**3 + 36288000*(u - 1)**2 - 29030400) + 62912004762894336000000**k*(u - 1)**12*(28062720*u + 4677120*(u - 1)**2) + 62912004762894336000000**k*(u - 1)**10*(81648000*u + 2268000*(u - 1)**3 + 31752000*(u - 1)**2 - 27216000) + 62912004762894336000000**k*(u - 1)**10*(3780*i**6*y**6*(u - 1)**2 + 5040*i**6*y**6 + 141750*i**4*y**4*(u - 1)**4 + 264600*i**4*y**4*(u - 1)**2 + 1772820*i**2*y**2*(u - 1)**6 + 3507840*i**2*y**2*(u - 1)**4 + 3402000*i**2*y**2*(u - 1)*(2*u + (u - 1)**2 - 2) + 3518100*(u - 1)**8 + 7087440*(u - 1)**6 + (u - 1)**3*(14182560*u + 7091280*(u - 1)**2 - 14182560)) + 62912004762894336000000**k*(u - 1)**8*(203212800*u + 846720*(u - 1)**4 + 25401600*(u - 1)**3 + 127008000*(u - 1)**2 - 101606400) + 62912004762894336000000**k*(u - 1)**6*(435456000*u + 241920*(u - 1)**5 + 14999040*(u - 1)**4 + 130636800*(u - 1)**3 + 377395200*(u - 1)**2 - 261273600) + 62912004762894336000000**k*(u - 1)**4*(696729600*u + 46080*(u - 1)**6 + 5806080*(u - 1)**5 + 83220480*(u - 1)**4 + 387072000*(u - 1)**3 + 774144000*(u - 1)**2 - 464486400) + 94368007144341504000000**k*i**6*y**6*(u - 1)**7*(-20160*u - 10080*(u - 1)**2 + 20160) + 94368007144341504000000**k*i**4*y**4*(u - 1)**7*(-1209600*u - 201600*(u - 1)**3 - 1209600*(u - 1)**2 + 1209600) + 94368007144341504000000**k*i**4*y**4*(u - 1)**5*(-2419200*u - 100800*(u - 1)**4 - 1411200*(u - 1)**3 - 3628800*(u - 1)**2 + 2419200) + 94368007144341504000000**k*i**2*y**2*(u - 1)**9*(-12096000*u - 2016000*(u - 1)**3 - 12096000*(u - 1)**2 + 12096000) + 94368007144341504000000**k*i**2*y**2*(u - 1)**7*(-26611200*u - 1108800*(u - 1)**4 - 15523200*(u - 1)**3 - 39916800*(u - 1)**2 + 26611200) + 94368007144341504000000**k*i**2*y**2*(u - 1)**5*(-58060800*u - 483840*(u - 1)**5 - 14515200*(u - 1)**4 - 72576000*(u - 1)**3 - 116121600*(u - 1)**2 + 58060800) + 94368007144341504000000**k*i**2*y**2*(u - 1)**3*(-116121600*u - 161280*(u - 1)**6 - 9999360*(u - 1)**5 - 87091200*(u - 1)**4 - 251596800*(u - 1)**3 - 290304000*(u - 1)**2 + 116121600) + 94368007144341504000000**k*(u - 1)**11*(-20321280*u - 3386880*(u - 1)**3 - 20321280*(u - 1)**2 + 20321280) + 94368007144341504000000**k*(u - 1)**9*(-44190720*u - 1841280*(u - 1)**4 - 25777920*(u - 1)**3 - 66286080*(u - 1)**2 + 44190720) + 94368007144341504000000**k*(u - 1)**9*(i**8*y**8*(90 - 90*u) + i**6*y**6*(10080 - 10080*u) - 4620*i**6*y**6*(u - 1)**3 - 115080*i**4*y**4*(u - 1)**5 - 252000*i**4*y**4*(u - 1)**3 + i**4*y**4*(-554400*u - 277200*(u - 1)**2 + 554400) - 1176120*i**2*y**2*(u - 1)**7 - 2540160*i**2*y**2*(u - 1)**5 + i**2*y**2*(u - 1)**2*(-5523840*u - 2761920*(u - 1)**2 + 5523840) - 2053152*(u - 1)**9 - 4383360*(u - 1)**7 + (u - 1)**4*(-9408960*u - 4704480*(u - 1)**2 + 9408960)) + 94368007144341504000000**k*(u - 1)**7*(-96768000*u - 806400*(u - 1)**5 - 24192000*(u - 1)**4 - 120960000*(u - 1)**3 - 193536000*(u - 1)**2 + 96768000) + 94368007144341504000000**k*(u - 1)**5*(-212889600*u - 295680*(u - 1)**6 - 18332160*(u - 1)**5 - 159667200*(u - 1)**4 - 461260800*(u - 1)**3 - 532224000*(u - 1)**2 + 212889600) + 94368007144341504000000**k*(u - 1)**3*(-464486400*u - 92160*(u - 1)**7 - 11612160*(u - 1)**6 - 166440960*(u - 1)**5 - 774144000*(u - 1)**4 - 1548288000*(u - 1)**3 - 1393459200*(u - 1)**2 + 464486400) - 23040*94368007144341504000000**k*(u - 1)*(40320*u + (u - 1)**8 + 254*(u - 1)**7 + 5796*(u - 1)**6 + 40824*(u - 1)**5 + 126000*(u - 1)**4 + 191520*(u - 1)**3 + 141120*(u - 1)**2 - 40320))/10 + 25408235049795191288514211830656044654224180510720000000000000**k*x**3*(u - 1)**3*(17418240**k*i**2*y**2*(u - 1)**4*(1209600*u + 201600*(u - 1)**2) + 17418240**k*i**2*y**2*(u - 1)**2*(7257600*u + 201600*(u - 1)**3 + 2822400*(u - 1)**2 - 2419200) + 17418240**k*(u - 1)**6*(1209600*u + 201600*(u - 1)**2) + 17418240**k*(u - 1)**6*(840*i**6*y**6 + 8400*i**4*y**4*(u - 1)**2 + 25200*i**4*y**4 + 60480*i**2*y**2*(u - 1)**4 + 151200*i**2*y**2*(u - 1)**2 + 86400*(u - 1)**6 + 201600*(u - 1)**4 + 241920*(u - 1)*(2*u + (u - 1)**2 - 2)) + 17418240**k*(u - 1)**5*(120*i**2*y**2*(3360*u + 1680*(u - 1)**2 - 3360) + 53760) + 17418240**k*(u - 1)**4*(4838400*u + 134400*(u - 1)**3 + 1881600*(u - 1)**2 - 1612800) + 3333120*17418240**k*(u - 1)**4 + 17418240**k*(u - 1)**3*(120*i**4*y**4*(840*u + 420*(u - 1)**2 - 840) + 29030400) + 17418240**k*(u - 1)**2*(19353600*u + 80640*(u - 1)**4 + 2419200*(u - 1)**3 + 12096000*(u - 1)**2 - 9676800) + 83865600*17418240**k*(u - 1)**2 + 17418240**k*(96768000*u - 96768000) + 38707200*17418240**k + 840*2488320**k*(u - 1)**12 + 2903040**k*(u - 1)**10*(-15120*(u - 1)**2 - 10080) + 3483648**k*(u - 1)**7*(12600*i**2*y**2*(u - 1)**3 + 100800*u + 105000*(u - 1)**5 + 126000*(u - 1)**3 + 50400*(u - 1)**2 - 100800) + 4354560**k*(u - 1)**7*(120*i**2*y**2*(840 - 840*u) - 100800*i**2*y**2*(u - 1)**3 - 806400*u - 352800*(u - 1)**5 - 571200*(u - 1)**3 - 403200*(u - 1)**2 + 806400) + 4354560**k*(u - 1)**5*(-806400*u - 134400*(u - 1)**3 - 806400*(u - 1)**2 + 806400) + 5806080**k*i**2*y**2*(u - 1)**5*(604800*u + 302400*(u - 1)**2 - 604800) + 5806080**k*(u - 1)**7*(120*i**4*y**4*(105*u - 105) + 264600*i**2*y**2*(u - 1)**3 + 120*i**2*y**2*(3780*u - 3780) + 2116800*u + 584640*(u - 1)**5 + 1134000*(u - 1)**3 + 1058400*(u - 1)**2 - 2116800) + 5806080**k*(u - 1)**6*(3628800*u + 604800*(u - 1)**2) + 5806080**k*(u - 1)**4*(7257600*u + 201600*(u - 1)**3 + 2822400*(u - 1)**2 - 2419200) + 8709120**k*i**2*y**2*(u - 1)**5*(-1209600*u - 604800*(u - 1)**2 + 1209600) + 8709120**k*i**2*y**2*(u - 1)**3*(-2419200*u - 403200*(u - 1)**3 - 2419200*(u - 1)**2 + 2419200) + 8709120**k*(u - 1)**6*(-25200*i**4*y**4*(u - 1)**2 - 50400*i**4*y**4 - 252000*i**2*y**2*(u - 1)**4 - 554400*i**2*y**2*(u - 1)**2 - 423360*(u - 1)**6 - 920640*(u - 1)**4 - 1008000*(u - 1)*(2*u + (u - 1)**2 - 2)) + 8709120**k*(u - 1)**5*(-4435200*u - 739200*(u - 1)**3 - 4435200*(u - 1)**2 + 4435200) + 8709120**k*(u - 1)**3*(-9676800*u - 403200*(u - 1)**4 - 5644800*(u - 1)**3 - 14515200*(u - 1)**2 + 9676800) - 161280*8709120**k*(u - 1)*(120*u + (u - 1)**5 + 30*(u - 1)**4 + 150*(u - 1)**3 + 240*(u - 1)**2 - 120))/10 + 307338011162322633825867906303615516137495687457669120000000000000**k*x**5*(u - 1)**5*(1440**k*(u - 1)**4*(1260*i**4*y**4 + 5040*i**2*y**2*(u - 1)**2 + 15120*i**2*y**2 + 6048*(u - 1)**4 + 15120*(u - 1)**2) + 1440**k*(u - 1)**3*(40320*u + 20160*(u - 1)**2 - 20160) + 1440**k*(u - 1)**2*(120960*u + 20160*(u - 1)**2) + 282240*1440**k*(u - 1)**2 + 30240*1440**k*(u - 1)*(i**2*y**2*(2*u + (u - 1)**2 - 2) + 24) + 483840*1440**k + 1260*288**k*(u - 1)**8 + 360**k*(u - 1)**6*(-10080*(u - 1)**2 - 10080) + 480**k*(u - 1)**6*(7560*i**2*y**2 + 26460*(u - 1)**2 + 45360) + 480**k*(u - 1)**3*(60480*u + 30240*(u - 1)**2 - 60480) + 720**k*(u - 1)**4*(-15120*i**2*y**2*(u - 1)**2 - 30240*i**2*y**2 - 25200*(u - 1)**4 - 55440*(u - 1)**2) + 720**k*(u - 1)**3*(-120960*u - 60480*(u - 1)**2 + 120960) - 40320*720**k*(u - 1)*(6*u + (u - 1)**3 + 6*(u - 1)**2 - 6))/10 + 4411151918367220709811495109488896641358364672000000000000**k*x**2*(u - 1)**2*(100329062400**k*i**4*y**4*(u - 1)**4*(604800*u + 100800*(u - 1)**2) + 100329062400**k*i**2*y**2*(u - 1)**6*(2419200*u + 403200*(u - 1)**2) + 100329062400**k*i**2*y**2*(u - 1)**4*(10886400*u + 302400*(u - 1)**3 + 4233600*(u - 1)**2 - 3628800) + 100329062400**k*i**2*y**2*(u - 1)**2*(58060800*u + 241920*(u - 1)**4 + 7257600*(u - 1)**3 + 36288000*(u - 1)**2 - 29030400) + 100329062400**k*(u - 1)**8*(2903040*u + 483840*(u - 1)**2) + 100329062400**k*(u - 1)**7*(180*i**6*y**6*(7*u - 7) + 18900*i**4*y**4*(u - 1)**3 + 180*i**4*y**4*(280*u - 280) + 151200*i**2*y**2*(u - 1)**5 + 362880*i**2*y**2*(u - 1)**3 + 180*i**2*y**2*(5040*u + 2520*(u - 1)**2 - 5040) + 226800*(u - 1)**7 + 518400*(u - 1)**5 + 180*(u - 1)**2*(6720*u + 3360*(u - 1)**2 - 6720)) + 100329062400**k*(u - 1)**6*(5040*i**6*y**6 + 46080) + 100329062400**k*(u - 1)**6*(10886400*u + 302400*(u - 1)**3 + 4233600*(u - 1)**2 - 3628800) + 100329062400**k*(u - 1)**5*(180*i**4*y**4*(840*u + 420*(u - 1)**2 - 840) + 5806080) + 100329062400**k*(u - 1)**4*(38707200*u + 161280*(u - 1)**4 + 4838400*(u - 1)**3 + 24192000*(u - 1)**2 - 19353600) + 83220480*100329062400**k*(u - 1)**4 + 387072000*100329062400**k*(u - 1)**3 + 100329062400**k*(u - 1)**2*(145152000*u + 80640*(u - 1)**5 + 4999680*(u - 1)**4 + 43545600*(u - 1)**3 + 125798400*(u - 1)**2 - 87091200) + 774144000*100329062400**k*(u - 1)**2 + 100329062400**k*(696729600*u - 696729600) + 232243200*100329062400**k - 360*12541132800**k*(u - 1)**14 + 14332723200**k*(u - 1)**12*(8820*(u - 1)**2 + 5040) + 16721510400**k*(u - 1)**9*(-7560*i**2*y**2*(u - 1)**3 - 60480*u - 86940*(u - 1)**5 - 90720*(u - 1)**3 - 30240*(u - 1)**2 + 60480) + 20065812480**k*(u - 1)**9*(94500*i**2*y**2*(u - 1)**3 + 180*i**2*y**2*(420*u - 420) + 756000*u + 441000*(u - 1)**5 + 630000*(u - 1)**3 + 378000*(u - 1)**2 - 756000) + 20065812480**k*(u - 1)**8*(604800*u + 100800*(u - 1)**2) + 25082265600**k*(-4838400*u - 806400*(u - 1)**2)*(u - 1)**8 + 25082265600**k*(u - 1)**7*(-12600*i**4*y**4*(u - 1)**3 - 428400*i**2*y**2*(u - 1)**5 - 604800*i**2*y**2*(u - 1)**3 + 180*i**2*y**2*(-3360*u - 1680*(u - 1)**2 + 3360) - 1218420*(u - 1)**7 - 2116800*(u - 1)**5 + 180*(u - 1)**2*(-19040*u - 9520*(u - 1)**2 + 19040)) + 25082265600**k*(u - 1)**5*(-4838400*u - 201600*(u - 1)**4 - 2822400*(u - 1)**3 - 7257600*(u - 1)**2 + 4838400) + 33443020800**k*i**2*y**2*(u - 1)**7*(2721600*u + 1360800*(u - 1)**2 - 2721600) + 33443020800**k*i**2*y**2*(u - 1)**6*(3628800*u + 604800*(u - 1)**2) + 33443020800**k*(u - 1)**8*(12700800*u + 2116800*(u - 1)**2) + 33443020800**k*(u - 1)**8*(56700*i**4*y**4*(u - 1)**2 + 75600*i**4*y**4 + 850500*i**2*y**2*(u - 1)**4 + 1587600*i**2*y**2*(u - 1)**2 + 1772820*(u - 1)**6 + 3507840*(u - 1)**4 + 3402000*(u - 1)*(2*u + (u - 1)**2 - 2)) + 33443020800**k*(u - 1)**6*(32659200*u + 907200*(u - 1)**3 + 12700800*(u - 1)**2 - 10886400) + 33443020800**k*(u - 1)**4*(58060800*u + 241920*(u - 1)**4 + 7257600*(u - 1)**3 + 36288000*(u - 1)**2 - 29030400) + 50164531200**k*i**4*y**4*(u - 1)**5*(-302400*u - 151200*(u - 1)**2 + 302400) + 50164531200**k*i**2*y**2*(u - 1)**5*(-7257600*u - 1209600*(u - 1)**3 - 7257600*(u - 1)**2 + 7257600) + 50164531200**k*i**2*y**2*(u - 1)**3*(-14515200*u - 604800*(u - 1)**4 - 8467200*(u - 1)**3 - 21772800*(u - 1)**2 + 14515200) + 50164531200**k*(u - 1)**7*(-12096000*u - 2016000*(u - 1)**3 - 12096000*(u - 1)**2 + 12096000) + 50164531200**k*(u - 1)**7*(180*i**6*y**6*(14 - 14*u) + 180*i**4*y**4*(840 - 840*u) - 69300*i**4*y**4*(u - 1)**3 - 690480*i**2*y**2*(u - 1)**5 - 1512000*i**2*y**2*(u - 1)**3 + 180*i**2*y**2*(-18480*u - 9240*(u - 1)**2 + 18480) - 1176120*(u - 1)**7 - 2540160*(u - 1)**5 + 180*(u - 1)**2*(-30688*u - 15344*(u - 1)**2 + 30688)) + 50164531200**k*(u - 1)**5*(-26611200*u - 1108800*(u - 1)**4 - 15523200*(u - 1)**3 - 39916800*(u - 1)**2 + 26611200) + 50164531200**k*(u - 1)**3*(-58060800*u - 483840*(u - 1)**5 - 14515200*(u - 1)**4 - 72576000*(u - 1)**3 - 116121600*(u - 1)**2 + 58060800) - 161280*50164531200**k*(u - 1)*(720*u + (u - 1)**6 + 62*(u - 1)**5 + 540*(u - 1)**4 + 1560*(u - 1)**3 + 1800*(u - 1)**2 - 720))/10 + 442566736073744592709249785077206343237993789939043532800000000000000**k*x**9*(u - 1)**9 + 73761122678957432118208297512867723872998964989840588800000000000000**k*x**7*(u - 1)**7*(6**k*(u - 1)**2*(360*i**2*y**2 + 240*(u - 1)**2 + 720) + 6**(k + 1)*(240*u + 240) + (u - 1)**2*(360*2**k*(u - 1)**2 - 720*3**k*(u - 1)**2 - 1440*3**k))/10 + 8537166976731184272940775175100431003819324651601920000000000000**k*x**4*(u - 1)**4*(10368**k*(u - 1)**8*(15750*(u - 1)**2 + 12600) + 12960**k*(u - 1)**5*(-12600*i**2*y**2*(u - 1)**3 - 100800*u - 71400*(u - 1)**5 - 100800*(u - 1)**3 - 50400*(u - 1)**2 + 100800) + 17280**k*(u - 1)**6*(56700*i**2*y**2*(u - 1)**2 + 75600*i**2*y**2 + 141750*(u - 1)**4 + 264600*(u - 1)**2) + 17280**k*(u - 1)**5*(453600*u + 226800*(u - 1)**2 - 453600) + 17280**k*(u - 1)**4*(604800*u + 100800*(u - 1)**2) + 25920**k*i**2*y**2*(u - 1)**3*(-302400*u - 151200*(u - 1)**2 + 302400) + 25920**k*(u - 1)**5*(210*i**4*y**4*(30 - 30*u) + 210*i**2*y**2*(720 - 720*u) - 69300*i**2*y**2*(u - 1)**3 - 554400*u - 115080*(u - 1)**5 - 252000*(u - 1)**3 - 277200*(u - 1)**2 + 554400) + 25920**k*(u - 1)**3*(-1209600*u - 201600*(u - 1)**3 - 1209600*(u - 1)**2 + 1209600) - 100800*25920**k*(u - 1)*(24*u + (u - 1)**4 + 14*(u - 1)**3 + 36*(u - 1)**2 - 24) + 51840**k*i**2*y**2*(u - 1)**2*(604800*u + 100800*(u - 1)**2) + 51840**k*(u - 1)**5*(210*i**4*y**4*(15*u - 15) + 18900*i**2*y**2*(u - 1)**3 + 210*i**2*y**2*(240*u - 240) + 151200*u + 25200*(u - 1)**5 + 60480*(u - 1)**3 + 75600*(u - 1)**2 - 151200) + 51840**k*(u - 1)**4*(403200*u + 67200*(u - 1)**2) + 51840**k*(u - 1)**4*(12600*i**4*y**4 + 40320) + 51840**k*(u - 1)**3*(210*i**2*y**2*(720*u + 360*(u - 1)**2 - 720) + 1209600) + 51840**k*(u - 1)**2*(1814400*u + 50400*(u - 1)**3 + 705600*(u - 1)**2 - 604800) + 6048000*51840**k*(u - 1)**2 + 51840**k*(9676800*u - 9676800) + 4838400*51840**k - 1260*8640**k*(u - 1)**10)/10 + 9220140334869679014776037189108465484124870623730073600000000000000**k*x**6*(u - 1)**6*(-840*12**k*(u - 1)**6 + 16**k*(u - 1)**3*(5040*u + 3780*(u - 1)**3 - 5040) + 24**k*(u - 1)**3*(420*i**2*y**2*(6 - 6*u) - 10080*u - 4620*(u - 1)**3 + 10080) - 420*24**(k + 1)*(u - 1)*(2*u + (u - 1)**2 - 2) + 48**k*(u - 1)**3*(420*i**2*y**2*(3*u - 3) + 3360*u + 1260*(u - 1)**3 - 3360) + 48**k*(u - 1)**2*(5040*i**2*y**2 + 6720) + 5040*48**k*(u - 1)*(2*u + (u - 1)**2 + 6) + 840*48**(k + 1))/10)/(442566736073744592709249785077206343237993789939043532800000000000000**k*(u - 1)**9)
# Substitute i with the imaginary unit (1j)
polynomial = polynomial.subs(i, 1j)

# Function to plot zeros for given parameter values
def plot_zeros(poly, k_value, u_value, y_value, x_range=(-20, 20), y_range=(-20, 20), title=""):
    # Substitute the parameter values
    poly_at_values = poly.subs({k: k_value, u: u_value, y: y_value})
    
    # Calculate the roots
    roots = sp.solveset(poly_at_values, x, domain=sp.S.Complexes)
    
    # Convert the roots to a list of complex numbers
    roots_list = [root.evalf() for root in roots]
    
    # Separate real and imaginary parts
    real_parts = [root.as_real_imag()[0] for root in roots_list]
    imag_parts = [root.as_real_imag()[1] for root in roots_list]
    
    # Plot the zeros
    plt.figure(figsize=(10, 8))
    plt.scatter(real_parts, imag_parts, color='blue', marker='o', s=200, label='Zeros')
    plt.axhline(0, color='black', linewidth=1)
    plt.axvline(0, color='black', linewidth=1)
    plt.xlim(x_range[0], x_range[1])
    plt.ylim(y_range[0], y_range[1])
    plt.xlabel("Real Part")
    plt.ylabel("Imaginary Part")
    plt.title(title)
    plt.grid(True)
    plt.show()

# Example plots with different parameter values
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=-3, 
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=-3)")
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=0, 
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=0)")
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=0.5, 
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=0.5)")
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=3, 
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=3)")

# %%
SAVING IT INTO PNG

# %%
import sympy as sp
import matplotlib.pyplot as plt

# Define the symbols
x, y, u, k, i = sp.symbols('x y u k i')

# Define the polynomial
polynomial =  (3*14181944181993379339671730676083129633996800000000000**k*x*(u - 1)*(10402117189632000**k*i**4*y**4*(u - 1)**7*(10080*u + 5040*(u - 1)**2 - 10080) + 10402117189632000**k*i**2*y**2*(u - 1)**8*(362880*u + 60480*(u - 1)**2) + 10402117189632000**k*i**2*y**2*(u - 1)**6*(725760*u + 20160*(u - 1)**3 + 282240*(u - 1)**2 - 241920) + 10402117189632000**k*(u - 1)**10*(907200*u + 151200*(u - 1)**2) + 10402117189632000**k*(u - 1)**9*(i**6*y**6*(84*u - 84) + 4410*i**4*y**4*(u - 1)**3 + i**4*y**4*(7560*u - 7560) + 58464*i**2*y**2*(u - 1)**5 + 113400*i**2*y**2*(u - 1)**3 + i**2*y**2*(211680*u + 105840*(u - 1)**2 - 211680) + 118124*(u - 1)**7 + 236376*(u - 1)**5 + (u - 1)**2*(467712*u + 233856*(u - 1)**2 - 467712)) + 10402117189632000**k*(u - 1)**8*(2540160*u + 70560*(u - 1)**3 + 987840*(u - 1)**2 - 846720) + 10402117189632000**k*(u - 1)**6*(5806080*u + 24192*(u - 1)**4 + 725760*(u - 1)**3 + 3628800*(u - 1)**2 - 2903040) + 10402117189632000**k*(u - 1)**4*(9676800*u + 5376*(u - 1)**5 + 333312*(u - 1)**4 + 2903040*(u - 1)**3 + 8386560*(u - 1)**2 - 5806080) + 15603175784448000**k*i**4*y**4*(u - 1)**7*(-20160*u - 10080*(u - 1)**2 + 20160) + 15603175784448000**k*i**4*y**4*(u - 1)**5*(-40320*u - 6720*(u - 1)**3 - 40320*(u - 1)**2 + 40320) + 15603175784448000**k*i**2*y**2*(u - 1)**7*(-443520*u - 73920*(u - 1)**3 - 443520*(u - 1)**2 + 443520) + 15603175784448000**k*i**2*y**2*(u - 1)**5*(-967680*u - 40320*(u - 1)**4 - 564480*(u - 1)**3 - 1451520*(u - 1)**2 + 967680) + 15603175784448000**k*i**2*y**2*(u - 1)**3*(-1935360*u - 16128*(u - 1)**5 - 483840*(u - 1)**4 - 2419200*(u - 1)**3 - 3870720*(u - 1)**2 + 1935360) + 15603175784448000**k*(u - 1)**9*(-736512*u - 122752*(u - 1)**3 - 736512*(u - 1)**2 + 736512) + 15603175784448000**k*(u - 1)**8*(-168*i**6*y**6*(u - 1)**2 - 336*i**6*y**6 - 4200*i**4*y**4*(u - 1)**4 - 9240*i**4*y**4*(u - 1)**2 - 42336*i**2*y**2*(u - 1)**6 - 92064*i**2*y**2*(u - 1)**4 - 100800*i**2*y**2*(u - 1)*(2*u + (u - 1)**2 - 2) - 73056*(u - 1)**8 - 156816*(u - 1)**6 + (u - 1)**3*(-338688*u - 169344*(u - 1)**2 + 338688)) + 15603175784448000**k*(u - 1)**7*(-1612800*u - 67200*(u - 1)**4 - 940800*(u - 1)**3 - 2419200*(u - 1)**2 + 1612800) + 15603175784448000**k*(u - 1)**5*(-3548160*u - 29568*(u - 1)**5 - 887040*(u - 1)**4 - 4435200*(u - 1)**3 - 7096320*(u - 1)**2 + 3548160) + 15603175784448000**k*(u - 1)**3*(-7741440*u - 10752*(u - 1)**6 - 666624*(u - 1)**5 - 5806080*(u - 1)**4 - 16773120*(u - 1)**3 - 19353600*(u - 1)**2 + 7741440) - 3072*15603175784448000**k*(u - 1)*(5040*u + (u - 1)**7 + 126*(u - 1)**6 + 1806*(u - 1)**5 + 8400*(u - 1)**4 + 16800*(u - 1)**3 + 15120*(u - 1)**2 - 5040) + 31206351568896000**k*i**4*y**4*(u - 1)**6*(20160*u + 3360*(u - 1)**2) + 31206351568896000**k*i**4*y**4*(u - 1)**4*(120960*u + 3360*(u - 1)**3 + 47040*(u - 1)**2 - 40320) + 31206351568896000**k*i**2*y**2*(u - 1)**8*(120960*u + 20160*(u - 1)**2) + 31206351568896000**k*i**2*y**2*(u - 1)**6*(483840*u + 13440*(u - 1)**3 + 188160*(u - 1)**2 - 161280) + 31206351568896000**k*i**2*y**2*(u - 1)**4*(1935360*u + 8064*(u - 1)**4 + 241920*(u - 1)**3 + 1209600*(u - 1)**2 - 967680) + 31206351568896000**k*i**2*y**2*(u - 1)**2*(9676800*u + 5376*(u - 1)**5 + 333312*(u - 1)**4 + 2903040*(u - 1)**3 + 8386560*(u - 1)**2 - 5806080) + 31206351568896000**k*(u - 1)**10*(161280*u + 26880*(u - 1)**2) + 31206351568896000**k*(u - 1)**8*(580608*u + 16128*(u - 1)**3 + 225792*(u - 1)**2 - 193536) + 31206351568896000**k*(u - 1)**8*(3*i**8*y**8 + 56*i**6*y**6*(u - 1)**2 + 168*i**6*y**6 + 1008*i**4*y**4*(u - 1)**4 + 2520*i**4*y**4*(u - 1)**2 + 8640*i**2*y**2*(u - 1)**6 + 20160*i**2*y**2*(u - 1)**4 + 24192*i**2*y**2*(u - 1)*(2*u + (u - 1)**2 - 2) + 13440*(u - 1)**8 + 30240*(u - 1)**6 + (u - 1)**3*(69120*u + 34560*(u - 1)**2 - 69120)) + 31206351568896000**k*(u - 1)**7*(i**4*y**4*(6720*u + 3360*(u - 1)**2 - 6720) + 768) + 31206351568896000**k*(u - 1)**6*(1935360*u + 8064*(u - 1)**4 + 241920*(u - 1)**3 + 1209600*(u - 1)**2 - 967680) + 195072*31206351568896000**k*(u - 1)**6 + 31206351568896000**k*(u - 1)**5*(i**6*y**6*(672*u + 336*(u - 1)**2 - 672) + 4451328) + 31206351568896000**k*(u - 1)**4*(6451200*u + 3584*(u - 1)**5 + 222208*(u - 1)**4 + 1935360*(u - 1)**3 + 5591040*(u - 1)**2 - 3870720) + 31352832*31206351568896000**k*(u - 1)**4 + 96768000*31206351568896000**k*(u - 1)**3 + 31206351568896000**k*(u - 1)**2*(23224320*u + 1536*(u - 1)**6 + 193536*(u - 1)**5 + 2774016*(u - 1)**4 + 12902400*(u - 1)**3 + 25804800*(u - 1)**2 - 15482880) + 147087360*31206351568896000**k*(u - 1)**2 + 31206351568896000**k*(108380160*u - 108380160) + 30965760*31206351568896000**k + 3*3467372396544000**k*(u - 1)**16 + 3900793946112000**k*(u - 1)**14*(-96*(u - 1)**2 - 48) + 4458050224128000**k*(u - 1)**11*(84*i**2*y**2*(u - 1)**3 + 672*u + 1274*(u - 1)**5 + 1176*(u - 1)**3 + 336*(u - 1)**2 - 672) + 5201058594816000**k*(u - 1)**11*(i**2*y**2*(1008 - 1008*u) - 1512*i**2*y**2*(u - 1)**3 - 12096*u - 9072*(u - 1)**5 - 11592*(u - 1)**3 - 6048*(u - 1)**2 + 12096) + 5201058594816000**k*(u - 1)**9*(-8064*u - 1344*(u - 1)**3 - 8064*(u - 1)**2 + 8064) + 6241270313779200**k*(u - 1)**10*(100800*u + 16800*(u - 1)**2) + 6241270313779200**k*(u - 1)**9*(210*i**4*y**4*(u - 1)**3 + 10500*i**2*y**2*(u - 1)**5 + 12600*i**2*y**2*(u - 1)**3 + i**2*y**2*(10080*u + 5040*(u - 1)**2 - 10080) + 37415*(u - 1)**7 + 58800*(u - 1)**5 + (u - 1)**2*(84000*u + 42000*(u - 1)**2 - 84000)) + 6241270313779200**k*(u - 1)**8*(120960*u + 3360*(u - 1)**3 + 47040*(u - 1)**2 - 40320) + 7801587892224000**k*i**2*y**2*(u - 1)**7*(-80640*u - 13440*(u - 1)**3 - 80640*(u - 1)**2 + 80640) + 7801587892224000**k*(u - 1)**9*(-456960*u - 76160*(u - 1)**3 - 456960*(u - 1)**2 + 456960) + 7801587892224000**k*(u - 1)**9*(i**4*y**4*(1680 - 1680*u) - 1680*i**4*y**4*(u - 1)**3 - 35280*i**2*y**2*(u - 1)**5 - 57120*i**2*y**2*(u - 1)**3 + i**2*y**2*(-80640*u - 40320*(u - 1)**2 + 80640) - 89712*(u - 1)**7 - 162456*(u - 1)**5 + (u - 1)**2*(-282240*u - 141120*(u - 1)**2 + 282240)) + 7801587892224000**k*(u - 1)**8*(-967680*u - 26880*(u - 1)**3 - 376320*(u - 1)**2 + 322560) + 7801587892224000**k*(u - 1)**5*(-645120*u - 5376*(u - 1)**5 - 161280*(u - 1)**4 - 806400*(u - 1)**3 - 1290240*(u - 1)**2 + 645120)) + 221283368036872296354624892538603171618996894969521766400000000000000**k*x**8*(u - 1)**8*(45*2**k*(u - 1)**2 + 45*2**(k + 2) - 90*(u - 1)**2)/10 + 2344898178239646054839902558876178841600000000**k*(-10*18873601428868300800000**k*(u - 1)**18 + 188736014288683008000000**k*i**6*y**6*(u - 1)**6*(40320*u + 6720*(u - 1)**2) + 188736014288683008000000**k*i**4*y**4*(u - 1)**8*(403200*u + 67200*(u - 1)**2) + 188736014288683008000000**k*i**4*y**4*(u - 1)**6*(1814400*u + 50400*(u - 1)**3 + 705600*(u - 1)**2 - 604800) + 188736014288683008000000**k*i**4*y**4*(u - 1)**4*(9676800*u + 40320*(u - 1)**4 + 1209600*(u - 1)**3 + 6048000*(u - 1)**2 - 4838400) + 188736014288683008000000**k*i**2*y**2*(u - 1)**10*(2903040*u + 483840*(u - 1)**2) + 188736014288683008000000**k*i**2*y**2*(u - 1)**8*(10886400*u + 302400*(u - 1)**3 + 4233600*(u - 1)**2 - 3628800) + 188736014288683008000000**k*i**2*y**2*(u - 1)**6*(38707200*u + 161280*(u - 1)**4 + 4838400*(u - 1)**3 + 24192000*(u - 1)**2 - 19353600) + 188736014288683008000000**k*i**2*y**2*(u - 1)**4*(145152000*u + 80640*(u - 1)**5 + 4999680*(u - 1)**4 + 43545600*(u - 1)**3 + 125798400*(u - 1)**2 - 87091200) + 188736014288683008000000**k*i**2*y**2*(u - 1)**2*(696729600*u + 46080*(u - 1)**6 + 5806080*(u - 1)**5 + 83220480*(u - 1)**4 + 387072000*(u - 1)**3 + 774144000*(u - 1)**2 - 464486400) + 188736014288683008000000**k*(u - 1)**12*(4147200*u + 691200*(u - 1)**2) + 188736014288683008000000**k*(u - 1)**10*(14515200*u + 403200*(u - 1)**3 + 5644800*(u - 1)**2 - 4838400) + 188736014288683008000000**k*(u - 1)**9*(i**8*y**8*(45*u - 45) + 1260*i**6*y**6*(u - 1)**3 + i**6*y**6*(3360*u - 3360) + 25200*i**4*y**4*(u - 1)**5 + 60480*i**4*y**4*(u - 1)**3 + i**4*y**4*(151200*u + 75600*(u - 1)**2 - 151200) + 226800*i**2*y**2*(u - 1)**7 + 518400*i**2*y**2*(u - 1)**5 + i**2*y**2*(u - 1)**2*(1209600*u + 604800*(u - 1)**2 - 1209600) + 362880*(u - 1)**9 + 806400*(u - 1)**7 + (u - 1)**4*(1814400*u + 907200*(u - 1)**2 - 1814400)) + 188736014288683008000000**k*(u - 1)**8*(180*i**8*y**8 + 5120) + 188736014288683008000000**k*(u - 1)**8*(46448640*u + 193536*(u - 1)**4 + 5806080*(u - 1)**3 + 29030400*(u - 1)**2 - 23224320) + 188736014288683008000000**k*(u - 1)**7*(i**6*y**6*(10080*u + 5040*(u - 1)**2 - 10080) + 2611200) + 188736014288683008000000**k*(u - 1)**6*(145152000*u + 80640*(u - 1)**5 + 4999680*(u - 1)**4 + 43545600*(u - 1)**3 + 125798400*(u - 1)**2 - 87091200) + 92928000*188736014288683008000000**k*(u - 1)**6 + 954777600*188736014288683008000000**k*(u - 1)**5 + 188736014288683008000000**k*(u - 1)**4*(464486400*u + 30720*(u - 1)**6 + 3870720*(u - 1)**5 + 55480320*(u - 1)**4 + 258048000*(u - 1)**3 + 516096000*(u - 1)**2 - 309657600) + 4270694400*188736014288683008000000**k*(u - 1)**4 + 9754214400*188736014288683008000000**k*(u - 1)**3 + 188736014288683008000000**k*(u - 1)**2*(1625702400*u + 11520*(u - 1)**7 + 2926080*(u - 1)**6 + 66769920*(u - 1)**5 + 470292480*(u - 1)**4 + 1451520000*(u - 1)**3 + 2206310400*(u - 1)**2 - 1161216000) + 11921817600*188736014288683008000000**k*(u - 1)**2 + 188736014288683008000000**k*(7431782400*u - 7431782400) + 1857945600*188736014288683008000000**k + 20970668254298112000000**k*(u - 1)**16*(405*(u - 1)**2 + 180) + 23592001786085376000000**k*(u - 1)**13*(-360*i**2*y**2*(u - 1)**3 - 2880*u - 6960*(u - 1)**5 - 5760*(u - 1)**3 - 1440*(u - 1)**2 + 2880) + 26962287755526144000000**k*(u - 1)**13*(8820*i**2*y**2*(u - 1)**3 + i**2*y**2*(5040*u - 5040) + 70560*u + 66150*(u - 1)**5 + 76440*(u - 1)**3 + 35280*(u - 1)**2 - 70560) + 26962287755526144000000**k*(u - 1)**12*(40320*u + 6720*(u - 1)**2) + 31456002381447168000000**k*(u - 1)**11*(-1260*i**4*y**4*(u - 1)**3 - 86940*i**2*y**2*(u - 1)**5 - 90720*i**2*y**2*(u - 1)**3 + i**2*y**2*(-60480*u - 30240*(u - 1)**2 + 60480) - 725760*u - 379638*(u - 1)**7 - 544320*(u - 1)**5 - 120960*(u - 1)**3 + (u - 1)**2*(-695520*u - 347760*(u - 1)**2 + 695520) - 725760*(u - 1)**2 + 725760) + 31456002381447168000000**k*(u - 1)**9*(-483840*u - 20160*(u - 1)**4 - 282240*(u - 1)**3 - 725760*(u - 1)**2 + 483840) + 37747202857736601600000**k*i**2*y**2*(u - 1)**10*(604800*u + 100800*(u - 1)**2) + 37747202857736601600000**k*(u - 1)**12*(5040000*u + 840000*(u - 1)**2) + 37747202857736601600000**k*(u - 1)**11*(15750*i**4*y**4*(u - 1)**3 + i**4*y**4*(12600*u - 12600) + 441000*i**2*y**2*(u - 1)**5 + 630000*i**2*y**2*(u - 1)**3 + i**2*y**2*(756000*u + 378000*(u - 1)**2 - 756000) + 1346625*(u - 1)**7 + 2244900*(u - 1)**5 + (u - 1)**2*(3528000*u + 1764000*(u - 1)**2 - 3528000)) + 37747202857736601600000**k*(u - 1)**10*(9072000*u + 252000*(u - 1)**3 + 3528000*(u - 1)**2 - 3024000) + 37747202857736601600000**k*(u - 1)**8*(9676800*u + 40320*(u - 1)**4 + 1209600*(u - 1)**3 + 6048000*(u - 1)**2 - 4838400) + 47184003572170752000000**k*i**2*y**2*(-4838400*u - 806400*(u - 1)**2)*(u - 1)**10 + 47184003572170752000000**k*i**2*y**2*(u - 1)**7*(-4838400*u - 201600*(u - 1)**4 - 2822400*(u - 1)**3 - 7257600*(u - 1)**2 + 4838
*(u - 1)**2 - 40320))/10 + 25408235049795191288514211830656044654224180510720000000000000**k*x**3*(u - 1)**3*(17418240**k*i**2*y**2*(u - 1)**4*(1209600*u + 201600*(u - 1)**2) + 17418240**k*i**2*y**2*(u - 1)**2*(7257600*u + 201600*(u - 1)**3 + 2822400*(u - 1)**2 - 2419200) + 17418240**k*(u - 1)**6*(1209600*u + 201600*(u - 1)**2) + 17418240**k*(u - 1)**6*(840*i**6*y**6 + 8400*i**4*y**4*(u - 1)**2 + 25200*i**4*y**4 + 60480*i**2*y**2*(u - 1)**4 + 151200*i**2*y**2*(u - 1)**2 + 86400*(u - 1)**6 + 201600*(u - 1)**4 + 241920*(u - 1)*(2*u + (u - 1)**2 - 2)) + 17418240**k*(u - 1)**5*(120*i**2*y**2*(3360*u + 1680*(u - 1)**2 - 3360) + 53760) + 17418240**k*(u - 1)**4*(4838400*u + 134400*(u - 1)**3 + 1881600*(u - 1)**2 - 1612800) + 3333120*17418240**k*(u - 1)**4 + 17418240**k*(u - 1)**3*(120*i**4*y**4*(840*u + 420*(u - 1)**2 - 840) + 29030400) + 17418240**k*(u - 1)**2*(19353600*u + 80640*(u - 1)**4 + 2419200*(u - 1)**3 + 12096000*(u - 1)**2 - 9676800) + 83865600*17418240**k*(u - 1)**2 + 17418240**k*(96768000*u - 96768000) + 38707200*17418240**k + 840*2488320**k*(u - 1)**12 + 2903040**k*(u - 1)**10*(-15120*(u - 1)**2 - 10080) + 3483648**k*(u - 1)**7*(12600*i**2*y**2*(u - 1)**3 + 100800*u + 105000*(u - 1)**5 + 126000*(u - 1)**3 + 50400*(u - 1)**2 - 100800) + 4354560**k*(u - 1)**7*(120*i**2*y**2*(840 - 840*u) - 100800*i**2*y**2*(u - 1)**3 - 806400*u - 352800*(u - 1)**5 - 571200*(u - 1)**3 - 403200*(u - 1)**2 + 806400) + 4354560**k*(u - 1)**5*(-806400*u - 134400*(u - 1)**3 - 806400*(u - 1)**2 + 806400) + 5806080**k*i**2*y**2*(u - 1)**5*(604800*u + 302400*(u - 1)**2 - 604800) + 5806080**k*(u - 1)**7*(120*i**4*y**4*(105*u - 105) + 264600*i**2*y**2*(u - 1)**3 + 120*i**2*y**2*(3780*u - 3780) + 2116800*u + 584640*(u - 1)**5 + 1134000*(u - 1)**3 + 1058400*(u - 1)**2 - 2116800) + 5806080**k*(u - 1)**6*(3628800*u + 604800*(u - 1)**2) + 5806080**k*(u - 1)**4*(7257600*u + 201600*(u - 1)**3 + 2822400*(u - 1)**2 - 2419200) + 8709120**k*i**2*y**2*(u - 1)**5*(-1209600*u - 604800*(u - 1)**2 + 1209600) + 8709120**k*i**2*y**2*(u - 1)**3*(-2419200*u - 403200*(u - 1)**3 - 2419200*(u - 1)**2 + 2419200) + 8709120**k*(u - 1)**6*(-25200*i**4*y**4*(u - 1)**2 - 50400*i**4*y**4 - 252000*i**2*y**2*(u - 1)**4 - 554400*i**2*y**2*(u - 1)**2 - 423360*(u - 1)**6 - 920640*(u - 1)**4 - 1008000*(u - 1)*(2*u + (u - 1)**2 - 2)) + 8709120**k*(u - 1)**5*(-4435200*u - 739200*(u - 1)**3 - 4435200*(u - 1)**2 + 4435200) + 8709120**k*(u - 1)**3*(-9676800*u - 403200*(u - 1)**4 - 5644800*(u - 1)**3 - 14515200*(u - 1)**2 + 9676800) - 161280*8709120**k*(u - 1)*(120*u + (u - 1)**5 + 30*(u - 1)**4 + 150*(u - 1)**3 + 240*(u - 1)**2 - 120))/10 + 307338011162322633825867906303615516137495687457669120000000000000**k*x**5*(u - 1)**5*(1440**k*(u - 1)**4*(1260*i**4*y**4 + 5040*i**2*y**2*(u - 1)**2 + 15120*i**2*y**2 + 6048*(u - 1)**4 + 15120*(u - 1)**2) + 1440**k*(u - 1)**3*(40320*u + 20160*(u - 1)**2 - 20160) + 1440**k*(u - 1)**2*(120960*u + 20160*(u - 1)**2) + 282240*1440**k*(u - 1)**2 + 30240*1440**k*(u - 1)*(i**2*y**2*(2*u + (u - 1)**2 - 2) + 24) + 483840*1440**k + 1260*288**k*(u - 1)**8 + 360**k*(u - 1)**6*(-10080*(u - 1)**2 - 10080) + 480**k*(u - 1)**6*(7560*i**2*y**2 + 26460*(u - 1)**2 + 45360) + 480**k*(u - 1)**3*(60480*u + 30240*(u - 1)**2 - 60480) + 720**k*(u - 1)**4*(-15120*i**2*y**2*(u - 1)**2 - 30240*i**2*y**2 - 25200*(u - 1)**4 - 55440*(u - 1)**2) + 720**k*(u - 1)**3*(-120960*u - 60480*(u - 1)**2 + 120960) - 40320*720**k*(u - 1)*(6*u + (u - 1)**3 + 6*(u - 1)**2 - 6))/10 + 4411151918367220709811495109488896641358364672000000000000**k*x**2*(u - 1)**2*(100329062400**k*i**4*y**4*(u - 1)**4*(604800*u + 100800*(u - 1)**2) + 100329062400**k*i**2*y**2*(u - 1)**6*(2419200*u + 403200*(u - 1)**2) + 100329062400**k*i**2*y**2*(u - 1)**4*(10886400*u + 302400*(u - 1)**3 + 4233600*(u - 1)**2 - 3628800) + 100329062400**k*i**2*y**2*(u - 1)**2*(58060800*u + 241920*(u - 1)**4 + 7257600*(u - 1)**3 + 36288000*(u - 1)**2 - 29030400) + 100329062400**k*(u - 1)**8*(2903040*u + 483840*(u - 1)**2) + 100329062400**k*(u - 1)**7*(180*i**6*y**6*(7*u - 7) + 18900*i**4*y**4*(u - 1)**3 + 180*i**4*y**4*(280*u - 280) + 151200*i**2*y**2*(u - 1)**5 + 362880*i**2*y**2*(u - 1)**3 + 180*i**2*y**2*(5040*u + 2520*(u - 1)**2 - 5040) + 226800*(u - 1)**7 + 518400*(u - 1)**5 + 180*(u - 1)**2*(6720*u + 3360*(u - 1)**2 - 6720)) + 100329062400**k*(u - 1)**6*(5040*i**6*y**6 + 46080) + 100329062400**k*(u - 1)**6*(10886400*u + 302400*(u - 1)**3 + 4233600*(u - 1)**2 - 3628800) + 100329062400**k*(u - 1)**5*(180*i**4*y**4*(840*u + 420*(u - 1)**2 - 840) + 5806080) + 100329062400**k*(u - 1)**4*(38707200*u
000) + 50164531200**k*(u - 1)**7*(180*i**6*y**6*(14 - 14*u) + 180*i**4*y**4*(840 - 840*u) - 69300*i**4*y**4*(u - 1)**3 - 690480*i**2*y**2*(u - 1)**5 - 1512000*i**2*y**2*(u - 1)**3 + 180*i**2*y**2*(-18480*u - 9240*(u - 1)**2 + 18480) - 1176120*(u - 1)**7 - 2540160*(u - 1)**5 + 180*(u - 1)**2*(-30688*u - 15344*(u - 1)**2 + 30688)) + 50164531200**k*(u - 1)**5*(-26611200*u - 1108800*(u - 1)**4 - 15523200*(u - 1)**3 - 39916800*(u - 1)**2 + 26611200) + 50164531200**k*(u - 1)**3*(-58060800*u - 483840*(u - 1)**5 - 14515200*(u - 1)**4 - 72576000*(u - 1)**3 - 116121600*(u - 1)**2 + 58060800) - 161280*50164531200**k*(u - 1)*(720*u + (u - 1)**6 + 62*(u - 1)**5 + 540*(u - 1)**4 + 1560*(u - 1)**3 + 1800*(u - 1)**2 - 720))/10 + 442566736073744592709249785077206343237993789939043532800000000000000**k*x**9*(u - 1)**9 + 73761122678957432118208297512867723872998964989840588800000000000000**k*x**7*(u - 1)**7*(6**k*(u - 1)**2*(360*i**2*y**2 + 240*(u - 1)**2 + 720) + 6**(k + 1)*(240*u + 240) + (u - 1)**2*(360*2**k*(u - 1)**2 - 720*3**k*(u - 1)**2 - 1440*3**k))/10 + 8537166976731184272940775175100431003819324651601920000000000000**k*x**4*(u - 1)**4*(10368**k*(u - 1)**8*(15750*(u - 1)**2 + 12600) + 12960**k*(u - 1)**5*(-12600*i**2*y**2*(u - 1)**3 - 100800*u - 71400*(u - 1)**5 - 100800*(u - 1)**3 - 50400*(u - 1)**2 + 100800) + 17280**k*(u - 1)**6*(56700*i**2*y**2*(u - 1)**2 + 75600*i**2*y**2 + 141750*(u - 1)**4 + 264600*(u - 1)**2) + 17280**k*(u - 1)**5*(453600*u + 226800*(u - 1)**2 - 453600) + 17280**k*(u - 1)**4*(604800*u + 100800*(u - 1)**2) + 25920**k*i**2*y**2*(u - 1)**3*(-302400*u - 151200*(u - 1)**2 + 302400) + 25920**k*(u - 1)**5*(210*i**4*y**4*(30 - 30*u) + 210*i**2*y**2*(720 - 720*u) - 69300*i**2*y**2*(u - 1)**3 - 554400*u - 115080*(u - 1)**5 - 252000*(u - 1)**3 - 277200*(u - 1)**2 + 554400) + 25920**k*(u - 1)**3*(-1209600*u - 201600*(u - 1)**3 - 1209600*(u - 1)**2 + 1209600) - 100800*25920**k*(u - 1)*(24*u + (u - 1)**4 + 14*(u - 1)**3 + 36*(u - 1)**2 - 24) + 51840**k*i**2*y**2*(u - 1)**2*(604800*u + 100800*(u - 1)**2) + 51840**k*(u - 1)**5*(210*i**4*y**4*(15*u - 15) + 18900*i**2*y**2*(u - 1)**3 + 210*i**2*y**2*(240*u - 240) + 151200*u + 25200*(u - 1)**5 + 60480*(u - 1)**3 + 75600*(u - 1)**2 - 151200) + 51840**k*(u - 1)**4*(403200*u + 67200*(u - 1)**2) + 51840**k*(u - 1)**4*(12600*i**4*y**4 + 40320) + 51840**k*(u - 1)**3*(210*i**2*y**2*(720*u + 360*(u - 1)**2 - 720) + 1209600) + 51840**k*(u - 1)**2*(1814400*u + 50400*(u - 1)**3 + 705600*(u - 1)**2 - 604800) + 6048000*51840**k*(u - 1)**2 + 51840**k*(9676800*u - 9676800) + 4838400*51840**k - 1260*8640**k*(u - 1)**10)/10 + 9220140334869679014776037189108465484124870623730073600000000000000**k*x**6*(u - 1)**6*(-840*12**k*(u - 1)**6 + 16**k*(u - 1)**3*(5040*u + 3780*(u - 1)**3 - 5040) + 24**k*(u - 1)**3*(420*i**2*y**2*(6 - 6*u) - 10080*u - 4620*(u - 1)**3 + 10080) - 420*24**(k + 1)*(u - 1)*(2*u + (u - 1)**2 - 2) + 48**k*(u - 1)**3*(420*i**2*y**2*(3*u - 3) + 3360*u + 1260*(u - 1)**3 - 3360) + 48**k*(u - 1)**2*(5040*i**2*y**2 + 6720) + 5040*48**k*(u - 1)*(2*u + (u - 1)**2 + 6) + 840*48**(k + 1))/10)/(442566736073744592709249785077206343237993789939043532800000000000000**k*(u - 1)**9)
# Substitute i with the imaginary unit (1j)
polynomial = polynomial.subs(i, 1j)

# Function to plot zeros for given parameter values
def plot_zeros(poly, k_value, u_value, y_value, x_range=(-20, 20), y_range=(-20, 20), title=""):
    # Substitute the parameter values
    poly_at_values = poly.subs({k: k_value, u: u_value, y: y_value})
    
    # Calculate the roots
    roots = sp.solveset(poly_at_values, x, domain=sp.S.Complexes)
    
    # Convert the roots to a list of complex numbers
    roots_list = [root.evalf() for root in roots]
    
    # Separate real and imaginary parts
    real_parts = [root.as_real_imag()[0] for root in roots_list]
    imag_parts = [root.as_real_imag()[1] for root in roots_list]
    
    # Plot the zeros
    plt.figure(figsize=(10, 8))
    plt.scatter(real_parts, imag_parts, color='blue', marker='o', s=200, label='Zeros')
    plt.axhline(0, color='black', linewidth=1)
    plt.axvline(0, color='black', linewidth=1)
    plt.xlim(x_range[0], x_range[1])
    plt.ylim(y_range[0], y_range[1])
    plt.xlabel("Real Part")
    plt.ylabel("Imaginary Part")
    plt.title(title)
    plt.grid(True)
    
    # Create a filename from the title (remove special characters)
    filename = f"zeros_k_{k_value}_u_{u_value}_y_{y_value}.png"
    
    # Save the figure
    plt.savefig(filename, bbox_inches='tight', dpi=300)
    plt.close()  # Close the figure to free memory
    

# Example plots with different parameter values
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=-3, 
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=-3)")
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=0, 
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=0)")
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=0.5, 
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=0.5)")
plot_zeros(polynomial, k_value=2, u_value=-2, y_value=3, 
           title="Distribution of Zeros T^(k,C)_(9,1)(x,y;u) where (k=2, u=-2, y=3)")

# %%
TYPE 2 SINE POLYNOMIALS

# %%
import sympy as sp

# Define all needed symbols including imaginary unit i
y, x, t, u, k, i = sp.symbols('y x t u k i')

# Evaluate coefficients
#k=1
#u=-1
#y=0
#x=0

# Define the polyexponential function Ei_k(x)
def Ei_k(x, k, n_terms=10):
    return sum((x**n) / (n**k * sp.factorial(n-1)) for n in range(1, n_terms + 1))

# Define the cosine function using Euler's formula
def sp_sin(y_val, t_val):
    return (sp.exp(i * y_val * t_val) - sp.exp(-i * y_val * t_val)) / (2 * i)

# Define the generating function
numerator = Ei_k(sp.log(1 + (1 - u) * t), k)
denominator = t * (sp.exp(2 * t) - u)
generating_function = (numerator / denominator)  * sp_sin(y, t)

# Number of terms to compute
n_terms = 10

# Compute Taylor series expansion
try:
    taylor_series = sp.series(generating_function, t, 0, n_terms).removeO()
except Exception as e:
    print(f"Error computing series: {e}")
    taylor_series = 0

# List to store the tangent numbers
tangent_number = []

# Compute the first few tangent numbers
for n in range(n_terms):
    try:
        # Coefficient of t^n in the Taylor series
        coeff = taylor_series.coeff(t, n) if taylor_series != 0 else 0
        # Multiply by n! to get T_n(x)
        T_n = coeff * sp.factorial(n)
        tangent_number.append(sp.simplify(T_n))
    except Exception as e:
        print(f"Error processing term n={n}: {e}")
        tangent_number.append(0)

# Now, generate the polynomials T_n(x, y)
print("\nGeneralized polynomials:")
polynomials_x_y = []
for n in range(n_terms):
    try:
        T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
        simplified = sp.simplify(T_n_x_y)
        polynomials_x_y.append(simplified)
        print(f"T^(C)_{n}(x, y) = {simplified}")
    except Exception as e:
        print(f"Error generating polynomial for n={n}: {e}")
        polynomials_x_y.append(0)
# Out:
# Generalized polynomials:
# T^(C)_0(x, y) = 0
# T^(C)_1(x, y) = y
# T^(C)_2(x, y) = y*(2**k*(u - 1)**2 + 2**(k + 1)*x*(u - 1) + 2**(k + 2) - 2*(u - 1)**2)/(2**k*(u - 1))
# T^(C)_3(x, y) = y*(3*12**k*x**2*(u - 1)**3 + 2**k*(3*2**k*(u - 1)**5 - 6*3**k*(u - 1)**3*((u - 1)**2 + 2) + 6**k*(u - 1)**3*(i**2*y**2 + 2*(u - 1)**2 + 6) + 12*6**k*(2*u + (u - 1)**2 - 2)) + 3*6**k*x*(u - 1)**2*(2**k*(u - 1)**2 + 4*2**k - 2*(u - 1)**2))/(12**k*(u - 1)**3)
# ...

# %%
TYPE 2 SINE (CHECKED)

# %%
import sympy as sp

# Define all needed symbols including imaginary unit i
y, x, t, u, k, i = sp.symbols('y x t u k i')

# Evaluate coefficients
k=1
u=-1
y=0
#x=0

# Define the polyexponential function Ei_k(x)
def Ei_k(x, k, n_terms=10):
    return sum((x**n) / (n**k * sp.factorial(n-1)) for n in range(1, n_terms + 1))

# Define the cosine function using Euler's formula
def sp_sin(y_val, t_val):
    return (sp.exp(i * y_val * t_val) - sp.exp(-i * y_val * t_val)) / (2 * i)

# Define the generating function
numerator = Ei_k(sp.log(1 + (1 - u) * t), k)
denominator = t * (sp.exp(2 * t) - u)
generating_function = (numerator / denominator)  * sp_sin(y, t)

# Number of terms to compute
n_terms = 5

# Compute Taylor series expansion
try:
    taylor_series = sp.series(generating_function, t, 0, n_terms).removeO()
except Exception as e:
    print(f"Error computing series: {e}")
    taylor_series = 0

# List to store the tangent numbers
tangent_number = []

# Compute the first few tangent numbers
for n in range(n_terms):
    try:
        # Coefficient of t^n in the Taylor series
        coeff = taylor_series.coeff(t, n) if taylor_series != 0 else 0
        # Multiply by n! to get T_n(x)
        T_n = coeff * sp.factorial(n)
        tangent_number.append(sp.simplify(T_n))
    except Exception as e:
        print(f"Error processing term n={n}: {e}")
        tangent_number.append(0)

# Display the polynomials I_n(x)
print("\nType I Frobenius-type poly-tangent polynomials:")
for n, T_n in enumerate(tangent_number):
    print(f"T_{n,1}^(({k}))(x) = {T_n}")  # Fixed to show k in output

# Now, generate the polynomials T_n(x, y)
print("\nGeneralized polynomials:")
polynomials_x_y = []
for n in range(n_terms):
    try:
        T_n_x_y = sum(sp.binomial(n, k) * x**(n-k) * tangent_number[k] for k in range(n+1))
        simplified = sp.simplify(T_n_x_y)
        polynomials_x_y.append(simplified)
        print(f"T^(C)_{n}(x, y) = {simplified}")
    except Exception as e:
        print(f"Error generating polynomial for n={n}: {e}")
        polynomials_x_y.append(0)
# Out:
# Type I Frobenius-type poly-tangent polynomials:
# T_(0, 1)^((1))(x) = 0
# T_(1, 1)^((1))(x) = 0
# T_(2, 1)^((1))(x) = 0
# T_(3, 1)^((1))(x) = 0
# T_(4, 1)^((1))(x) = 0
#
# Generalized polynomials:
# T^(C)_0(x, y) = 0
# T^(C)_1(x, y) = 0
# T^(C)_2(x, y) = 0
# T^(C)_3(x, y) = 0
# T^(C)_4(x, y) = 0

# %%
SINE OF SINE TYPE 2

# %%
import sympy as sp
import matplotlib.pyplot as plt

# Define the symbols
x, y, u, k, i = sp.symbols('x y u k i')

# Define the polynomial
polynomial = y*(180*1172449089119823027419951279438089420800000000**k*x**7*(u - 1)**7*(2**k*(u - 1)**2 + 4*2**k - 2*(u - 1)**2) + 180*134623140928110191089335234723840000000**k*x**2*(u - 1)**2*(84*17418240**k*i**4*y**4*(u - 1)**3*(2*u + (u - 1)**2 - 2) + 560*17418240**k*i**2*y**2*(u - 1)**5*(2*u + (u - 1)**2 - 2) + 560*17418240**k*i**2*y**2*(u - 1)**4*(6*u + (u - 1)**2) + 560*17418240**k*i**2*y**2*(u - 1)**2*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 1680*17418240**k*(u - 1)**6*(6*u + (u - 1)**2) + 17418240**k*(u - 1)**6*(i**6*y**6 + 14*i**4*y**4*(u - 1)**2 + 42*i**4*y**4 + 168*i**2*y**2*(u - 1)**4 + 420*i**2*y**2*(u - 1)**2 + 720*(u - 1)**6 + 1680*(u - 1)**4 + 2016*(u - 1)*(2*u + (u - 1)**2 - 2)) + 1120*17418240**k*(u - 1)**4*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 672*17418240**k*(u - 1)**2*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) + 448*17418240**k*(1800*u + (u - 1)**5 + 62*(u - 1)**4 + 540*(u - 1)**3 + 1560*(u - 1)**2 - 1080) + 7*2488320**k*(u - 1)**12 - 42*2903040**k*(u - 1)**10*(3*(u - 1)**2 + 2) + 35*3483648**k*(u - 1)**7*(i**2*y**2*(u - 1)**3 + 24*u + 25*(u - 1)**5 + 30*(u - 1)**3 + 12*(u - 1)**2 - 24) + 140*4354560**k*(u - 1)**7*(2*i**2*y**2*(1 - u) - 2*i**2*y**2*(u - 1)**3 - 48*u - 21*(u - 1)**5 - 34*(u - 1)**3 - 24*(u - 1)**2 + 48) - 1120*4354560**k*(u - 1)**6*(6*u + (u - 1)**2) + 840*5806080**k*i**2*y**2*(u - 1)**5*(2*u + (u - 1)**2 - 2) + 21*5806080**k*(u - 1)**7*(i**4*y**4*(u - 1) + 35*i**2*y**2*(u - 1)**3 + 60*i**2*y**2*(u - 1) + 840*u + 232*(u - 1)**5 + 450*(u - 1)**3 + 420*(u - 1)**2 - 840) + 5040*5806080**k*(u - 1)**6*(6*u + (u - 1)**2) + 1680*5806080**k*(u - 1)**4*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 1680*8709120**k*i**2*y**2*(u - 1)**5*(-2*u - (u - 1)**2 + 2) - 1120*8709120**k*i**2*y**2*(u - 1)**4*(6*u + (u - 1)**2) - 6160*8709120**k*(u - 1)**6*(6*u + (u - 1)**2) - 14*8709120**k*(u - 1)**6*(3*i**4*y**4*(u - 1)**2 + 6*i**4*y**4 + 50*i**2*y**2*(u - 1)**4 + 110*i**2*y**2*(u - 1)**2 + 252*(u - 1)**6 + 548*(u - 1)**4 + 600*(u - 1)*(2*u + (u - 1)**2 - 2)) + 3360*8709120**k*(u - 1)**4*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) + 1344*8709120**k*(u - 1)**2*(-240*u - (u - 1)**4 - 30*(u - 1)**3 - 150*(u - 1)**2 + 120)) + 210*1628401512666420871416598999219568640000000**k*x**4*(u - 1)**4*(120*1440**k*i**2*y**2*(u - 1)*(2*u + (u - 1)**2 - 2) + 1440**k*(u - 1)**4*(3*i**4*y**4 + 20*i**2*y**2*(u - 1)**2 + 60*i**2*y**2 + 72*(u - 1)**4 + 180*(u - 1)**2) + 240*1440**k*(u - 1)**3*(2*u + (u - 1)**2 - 2) + 240*1440**k*(u - 1)**2*(6*u + (u - 1)**2) + 240*1440**k*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 15*288**k*(u - 1)**8 - 120*360**k*(u - 1)**6*((u - 1)**2 + 1) + 15*480**k*(u - 1)**6*(2*i**2*y**2 + 21*(u - 1)**2 + 36) + 360*480**k*(u - 1)**3*(2*u + (u - 1)**2 - 2) - 60*720**k*(u - 1)**4*(i**2*y**2*(u - 1)**2 + 2*i**2*y**2 + 5*(u - 1)**4 + 11*(u - 1)**2) + 720*720**k*(u - 1)**3*(-2*u - (u - 1)**2 + 2) - 480*720**k*(u - 1)**2*(6*u + (u - 1)**2)) + 60*23372073077796908175231811584000000**k*x*(u - 1)*(12*100329062400**k*i**6*y**6*(u - 1)**6 + 252*100329062400**k*i**4*y**4*(u - 1)**5*(2*u + (u - 1)**2 - 2) + 336*100329062400**k*i**4*y**4*(u - 1)**4*(6*u + (u - 1)**2) + 2240*100329062400**k*i**2*y**2*(u - 1)**6*(6*u + (u - 1)**2) + 1680*100329062400**k*i**2*y**2*(u - 1)**4*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 1344*100329062400**k*i**2*y**2*(u - 1)**2*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) + 8064*100329062400**k*(u - 1)**8*(6*u + (u - 1)**2) + 3*100329062400**k*(u - 1)**7*(i**6*y**6*(u - 1) + 21*i**4*y**4*(u - 1)**3 + 56*i**4*y**4*(u - 1) + 280*i**2*y**2*(u - 1)**5 + 672*i**2*y**2*(u - 1)**3 + 840*i**2*y**2*(2*u + (u - 1)**2 - 2) + 1260*(u - 1)**7 + 2880*(u - 1)**5 + 3360*(u - 1)**2*(2*u + (u - 1)**2 - 2)) + 5040*100329062400**k*(u - 1)**6*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 2688*100329062400**k*(u - 1)**4*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) + 1344*100329062400**k*(u - 1)**2*(1800*u + (u - 1)**5 + 62*(u - 1)**4 + 540*(u - 1)**3 + 1560*(u - 1)**2 - 1080) + 768*100329062400**k*(15120*u + (u - 1)**6 + 126*(u - 1)**5 + 1806*(u - 1)**4 + 8400*(u - 1)**3 + 16800*(u - 1)**2 - 10080) - 6*12541132800**k*(u - 1)**14 + 21*14332723200**k*(u - 1)**12*(7*(u - 1)**2 + 4) + 21*16721510400**k*(u - 1)**9*(-2*i**2*y**2*(u - 1)**3 - 48*u - 69*(u - 1)**5 - 72*(u - 1)**3 - 24*(u - 1)**2 + 48) + 105*20065812480**k*(u - 1)**9*(5*i**2*y**2*(u - 1)**3 + 4*i**2*y**2*(u - 1) + 120*u + 70*(u - 1)**5 + 100*(u - 1)**3 + 60*(u - 1)**2 - 120) + 1680*20065812480**k*(u - 1)**8*(6*u + (u - 1)**2) - 13440*25082265600**k*(u - 1)**8*(6*u + (u - 1)**2) + 7*25082265600**k*(u - 1)**7*(-6*i**4*y**4*(u - 1)**3 - 340*i**2*y**2*(u - 1)**5 - 480*i**2*y**2*(u - 1)**3 + 240*i**2*y**2*(-2*u - (u - 1)**2 + 2) - 2901*(u - 1)**7 - 5040*(u - 1)**5 + 4080*(u - 1)**2*(-2*u - (u - 1)**2 + 2)) + 3360*25082265600**k*(u - 1)**6*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) + 7560*33443020800**k*i**2*y**2*(u - 1)**7*(2*u + (u - 1)**2 - 2) + 3360*33443020800**k*i**2*y**2*(u - 1)**6*(6*u + (u - 1)**2) + 35280*33443020800**k*(u - 1)**8*(6*u + (u - 1)**2) + 63*33443020800**k*(u - 1)**8*(3*i**4*y**4*(u - 1)**2 + 4*i**4*y**4 + 75*i**2*y**2*(u - 1)**4 + 140*i**2*y**2*(u - 1)**2 + 469*(u - 1)**6 + 928*(u - 1)**4 + 900*(u - 1)*(2*u + (u - 1)**2 - 2)) + 15120*33443020800**k*(u - 1)**6*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 4032*33443020800**k*(u - 1)**4*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) + 504*50164531200**k*i**4*y**4*(u - 1)**5*(-2*u - (u - 1)**2 + 2) - 6720*50164531200**k*i**2*y**2*(u - 1)**6*(6*u + (u - 1)**2) + 3360*50164531200**k*i**2*y**2*(u - 1)**4*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) - 33600*50164531200**k*(u - 1)**8*(6*u + (u - 1)**2) + 50164531200**k*(u - 1)**7*(6*i**6*y**6*(1 - u) + 504*i**4*y**4*(1 - u) - 231*i**4*y**4*(u - 1)**3 - 3836*i**2*y**2*(u - 1)**5 - 8400*i**2*y**2*(u - 1)**3 + 9240*i**2*y**2*(-2*u - (u - 1)**2 + 2) - 19602*(u - 1)**7 - 42336*(u - 1)**5 + 46032*(u - 1)**2*(-2*u - (u - 1)**2 + 2)) + 18480*50164531200**k*(u - 1)**6*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) + 8064*50164531200**k*(u - 1)**4*(-240*u - (u - 1)**4 - 30*(u - 1)**3 - 150*(u - 1)**2 + 120) + 2688*50164531200**k*(u - 1)**2*(-1800*u - (u - 1)**5 - 62*(u - 1)**4 - 540*(u - 1)**3 - 1560*(u - 1)**2 + 1080)) + 45*2344898178239646054839902558876178841600000000**k*x**8*(u - 1)**8 + 420*390816363039941009139983759812696473600000000**k*x**6*(u - 1)**5*(3*2**k*(u - 1)**5 - 6*3**k*(u - 1)**3*((u - 1)**2 + 2) + 6**k*(u - 1)**3*(i**2*y**2 + 2*(u - 1)**2 + 6) + 12*6**k*(2*u + (u - 1)**2 - 2)) + 420*45233375351845024206016638867210240000000**k*x**3*(u - 1)**3*(15*10368**k*(u - 1)**8*(5*(u - 1)**2 + 4) + 20*12960**k*(u - 1)**5*(-i**2*y**2*(u - 1)**3 - 24*u - 17*(u - 1)**5 - 24*(u - 1)**3 - 12*(u - 1)**2 + 24) + 15*17280**k*(u - 1)**6*(6*i**2*y**2*(u - 1)**2 + 8*i**2*y**2 + 45*(u - 1)**4 + 84*(u - 1)**2) + 1080*17280**k*(u - 1)**5*(2*u + (u - 1)**2 - 2) + 480*17280**k*(u - 1)**4*(6*u + (u - 1)**2) + 240*25920**k*i**2*y**2*(u - 1)**3*(-2*u - (u - 1)**2 + 2) + 2*25920**k*(u - 1)**5*(3*i**4*y**4*(1 - u) + 120*i**2*y**2*(1 - u) - 55*i**2*y**2*(u - 1)**3 - 1320*u - 274*(u - 1)**5 - 600*(u - 1)**3 - 660*(u - 1)**2 + 1320) - 960*25920**k*(u - 1)**4*(6*u + (u - 1)**2) + 480*25920**k*(u - 1)**2*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) + 12*51840**k*i**4*y**4*(u - 1)**4 + 120*51840**k*i**2*y**2*(u - 1)**3*(2*u + (u - 1)**2 - 2) + 160*51840**k*i**2*y**2*(u - 1)**2*(6*u + (u - 1)**2) + 51840**k*(u - 1)**5*(3*i**4*y**4*(u - 1) + 30*i**2*y**2*(u - 1)**3 + 80*i**2*y**2*(u - 1) + 720*u + 120*(u - 1)**5 + 288*(u - 1)**3 + 360*(u - 1)**2 - 720) + 320*51840**k*(u - 1)**4*(6*u + (u - 1)**2) + 240*51840**k*(u - 1)**2*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 192*51840**k*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) - 6*8640**k*(u - 1)**10) + 1260*48852045379992626142497969976587059200000000**k*x**5*(u - 1)**5*(-2*12**k*(u - 1)**6 + 3*16**k*(u - 1)**4*(3*(u - 1)**2 + 4) + 24**k*(u - 1)**3*(2*i**2*y**2*(1 - u) - 24*u - 11*(u - 1)**3 + 24) - 24*24**k*(u - 1)*(2*u + (u - 1)**2 - 2) + 4*48**k*i**2*y**2*(u - 1)**2 + 48**k*(u - 1)**4*(i**2*y**2 + 3*(u - 1)**2 + 8) + 12*48**k*(u - 1)*(2*u + (u - 1)**2 - 2) + 16*48**k*(6*u + (u - 1)**2)) + 75141695851970512394649600000**k*(15120*10402117189632000**k*i**4*y**4*(u - 1)**7*(2*u + (u - 1)**2 - 2) + 302400*10402117189632000**k*i**2*y**2*(u - 1)**8*(6*u + (u - 1)**2) + 100800*10402117189632000**k*i**2*y**2*(u - 1)**6*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 2268000*10402117189632000**k*(u - 1)**10*(6*u + (u - 1)**2) + 30*10402117189632000**k*(u - 1)**9*(6*i**6*y**6*(u - 1) + 441*i**4*y**4*(u - 1)**3 + 756*i**4*y**4*(u - 1) + 9744*i**2*y**2*(u - 1)**5 + 18900*i**2*y**2*(u - 1)**3 + 17640*i**2*y**2*(2*u + (u - 1)**2 - 2) + 59062*(u - 1)**7 + 118188*(u - 1)**5 + 116928*(u - 1)**2*(2*u + (u - 1)**2 - 2)) + 1058400*10402117189632000**k*(u - 1)**8*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 362880*10402117189632000**k*(u - 1)**6*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) + 80640*10402117189632000**k*(u - 1)**4*(1800*u + (u - 1)**5 + 62*(u - 1)**4 + 540*(u - 1)**3 + 1560*(u - 1)**2 - 1080) + 30240*15603175784448000**k*i**4*y**4*(u - 1)**7*(-2*u - (u - 1)**2 + 2) + 20160*15603175784448000**k*i**4*y**4*(u - 1)**5*(-6*u - (u - 1)**3 - 6*(u - 1)**2 + 6) + 369600*15603175784448000**k*i**2*y**2*(u - 1)**7*(-6*u - (u - 1)**3 - 6*(u - 1)**2 + 6) + 201600*15603175784448000**k*i**2*y**2*(u - 1)**5*(-24*u - (u - 1)**4 - 14*(u - 1)**3 - 36*(u - 1)**2 + 24) + 80640*15603175784448000**k*i**2*y**2*(u - 1)**3*(-120*u - (u - 1)**5 - 30*(u - 1)**4 - 150*(u - 1)**3 - 240*(u - 1)**2 + 120) - 1841280*15603175784448000**k*(u - 1)**10*(6*u + (u - 1)**2) + 1
896000**k*(141120*u + (u - 1)**7 + 254*(u - 1)**6 + 5796*(u - 1)**5 + 40824*(u - 1)**4 + 126000*(u - 1)**3 + 191520*(u - 1)**2 - 100800) + 45*3467372396544000**k*(u - 1)**16 - 720*3900793946112000**k*(u - 1)**14*(2*(u - 1)**2 + 1) + 210*4458050224128000**k*(u - 1)**11*(2*i**2*y**2*(u - 1)**3 + 48*u + 91*(u - 1)**5 + 84*(u - 1)**3 + 24*(u - 1)**2 - 48) + 2520*5201058594816000**k*(u - 1)**11*(2*i**2*y**2*(1 - u) - 3*i**2*y**2*(u - 1)**3 - 72*u - 54*(u - 1)**5 - 69*(u - 1)**3 - 36*(u - 1)**2 + 72) - 20160*5201058594816000**k*(u - 1)**10*(6*u + (u - 1)**2) + 252000*6241270313779200**k*(u - 1)**10*(6*u + (u - 1)**2) + 105*6241270313779200**k*(u - 1)**9*(6*i**4*y**4*(u - 1)**3 + 500*i**2*y**2*(u - 1)**5 + 600*i**2*y**2*(u - 1)**3 + 240*i**2*y**2*(2*u + (u - 1)**2 - 2) + 5345*(u - 1)**7 + 8400*(u - 1)**5 + 6000*(u - 1)**2*(2*u + (u - 1)**2 - 2)) + 50400*6241270313779200**k*(u - 1)**8*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 67200*7801587892224000**k*i**2*y**2*(u - 1)**7*(-6*u - (u - 1)**3 - 6*(u - 1)**2 + 6) - 1142400*7801587892224000**k*(u - 1)**10*(6*u + (u - 1)**2) + 840*7801587892224000**k*(u - 1)**9*(6*i**4*y**4*(1 - u) - 6*i**4*y**4*(u - 1)**3 - 210*i**2*y**2*(u - 1)**5 - 340*i**2*y**2*(u - 1)**3 + 240*i**2*y**2*(-2*u - (u - 1)**2 + 2) - 1602*(u - 1)**7 - 2901*(u - 1)**5 + 2520*(u - 1)**2*(-2*u - (u - 1)**2 + 2)) + 403200*7801587892224000**k*(u - 1)**8*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) + 80640*7801587892224000**k*(u - 1)**6*(-240*u - (u - 1)**4 - 30*(u - 1)**3 - 150*(u - 1)**2 + 120)))/(5*2344898178239646054839902558876178841600000000**k*(u - 1)**8)

# Substitute i with the imaginary unit (1j)
polynomial = polynomial.subs(i, 1j)

# Function to plot zeros for given parameter values
def plot_zeros(poly, k_value, u_value, x_value, x_range=(-20, 20), y_range=(-20, 20), title=""):
    # Substitute the parameter values
    poly_at_values = poly.subs({k: k_value, u: u_value, x: x_value})
    
    # Calculate the roots
    roots = sp.solveset(poly_at_values, y, domain=sp.S.Complexes)
    
    # Convert the roots to a list of complex numbers
    roots_list = [root.evalf() for root in roots]
    
    # Separate real and imaginary parts
    real_parts = [root.as_real_imag()[0] for root in roots_list]
    imag_parts = [root.as_real_imag()[1] for root in roots_list]
    
    # Plot the zeros
    plt.figure(figsize=(10, 8))
    plt.scatter(real_parts, imag_parts, color='blue', marker='o', s=200, label='Zeros')
    plt.axhline(0, color='black', linewidth=1)
    plt.axvline(0, color='black', linewidth=1)
    plt.xlim(x_range[0], x_range[1])
    plt.ylim(y_range[0], y_range[1])
    plt.xlabel("Real Part")
    plt.ylabel("Imaginary Part")
    plt.title(title)
    plt.grid(True)
    plt.show()

# Example plots with different parameter values
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=-3, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=-3)")
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=1, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=1)")
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=-1, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=-1)")
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=3, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=3)")

# %%
SAVE IT INTO PNG

# %%
import sympy as sp
import matplotlib.pyplot as plt

# Define the symbols
x, y, u, k, i = sp.symbols('x y u k i')

# Define the polynomial
polynomial = y*(180*1172449089119823027419951279438089420800000000**k*x**7*(u - 1)**7*(2**k*(u - 1)**2 + 4*2**k - 2*(u - 1)**2) + 180*134623140928110191089335234723840000000**k*x**2*(u - 1)**2*(84*17418240**k*i**4*y**4*(u - 1)**3*(2*u + (u - 1)**2 - 2) + 560*17418240**k*i**2*y**2*(u - 1)**5*(2*u + (u - 1)**2 - 2) + 560*17418240**k*i**2*y**2*(u - 1)**4*(6*u + (u - 1)**2) + 560*17418240**k*i**2*y**2*(u - 1)**2*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 1680*17418240**k*(u - 1)**6*(6*u + (u - 1)**2) + 17418240**k*(u - 1)**6*(i**6*y**6 + 14*i**4*y**4*(u - 1)**2 + 42*i**4*y**4 + 168*i**2*y**2*(u - 1)**4 + 420*i**2*y**2*(u - 1)**2 + 720*(u - 1)**6 + 1680*(u - 1)**4 + 2016*(u - 1)*(2*u + (u - 1)**2 - 2)) + 1120*17418240**k*(u - 1)**4*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 672*17418240**k*(u - 1)**2*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) + 448*17418240**k*(1800*u + (u - 1)**5 + 62*(u - 1)**4 + 540*(u - 1)**3 + 1560*(u - 1)**2 - 1080) + 7*2488320**k*(u - 1)**12 - 42*2903040**k*(u - 1)**10*(3*(u - 1)**2 + 2) + 35*3483648**k*(u - 1)**7*(i**2*y**2*(u - 1)**3 + 24*u + 25*(u - 1)**5 + 30*(u - 1)**3 + 12*(u - 1)**2 - 24) + 140*4354560**k*(u - 1)**7*(2*i**2*y**2*(1 - u) - 2*i**2*y**2*(u - 1)**3 - 48*u - 21*(u - 1)**5 - 34*(u - 1)**3 - 24*(u - 1)**2 + 48) - 1120*4354560**k*(u - 1)**6*(6*u + (u - 1)**2) + 840*5806080**k*i**2*y**2*(u - 1)**5*(2*u + (u - 1)**2 - 2) + 21*5806080**k*(u - 1)**7*(i**4*y**4*(u - 1) + 35*i**2*y**2*(u - 1)**3 + 60*i**2*y**2*(u - 1) + 840*u + 232*(u - 1)**5 + 450*(u - 1)**3 + 420*(u - 1)**2 - 840) + 5040*5806080**k*(u - 1)**6*(6*u + (u - 1)**2) + 1680*5806080**k*(u - 1)**4*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 1680*8709120**k*i**2*y**2*(u - 1)**5*(-2*u - (u - 1)**2 + 2) - 1120*8709120**k*i**2*y**2*(u - 1)**4*(6*u + (u - 1)**2) - 6160*8709120**k*(u - 1)**6*(6*u + (u - 1)**2) - 14*8709120**k*(u - 1)**6*(3*i**4*y**4*(u - 1)**2 + 6*i**4*y**4 + 50*i**2*y**2*(u - 1)**4 + 110*i**2*y**2*(u - 1)**2 + 252*(u - 1)**6 + 548*(u - 1)**4 + 600*(u - 1)*(2*u + (u - 1)**2 - 2)) + 3360*8709120**k*(u - 1)**4*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) + 1344*8709120**k*(u - 1)**2*(-240*u - (u - 1)**4 - 30*(u - 1)**3 - 150*(u - 1)**2 + 120)) + 210*1628401512666420871416598999219568640000000**k*x**4*(u - 1)**4*(120*1440**k*i**2*y**2*(u - 1)*(2*u + (u - 1)**2 - 2) + 1440**k*(u - 1)**4*(3*i**4*y**4 + 20*i**2*y**2*(u - 1)**2 + 60*i**2*y**2 + 72*(u - 1)**4 + 180*(u - 1)**2) + 240*1440**k*(u - 1)**3*(2*u + (u - 1)**2 - 2) + 240*1440**k*(u - 1)**2*(6*u + (u - 1)**2) + 240*1440**k*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 15*288**k*(u - 1)**8 - 120*360**k*(u - 1)**6*((u - 1)**2 + 1) + 15*480**k*(u - 1)**6*(2*i**2*y**2 + 21*(u - 1)**2 + 36) + 360*480**k*(u - 1)**3*(2*u + (u - 1)**2 - 2) - 60*720**k*(u - 1)**4*(i**2*y**2*(u - 1)**2 + 2*i**2*y**2 + 5*(u - 1)**4 + 11*(u - 1)**2) + 720*720**k*(u - 1)**3*(-2*u - (u - 1)**2 + 2) - 480*720**k*(u - 1)**2*(6*u + (u - 1)**2)) + 60*23372073077796908175231811584000000**k*x*(u - 1)*(12*100329062400**k*i**6*y**6*(u - 1)**6 + 252*100329062400**k*i**4*y**4*(u - 1)**5*(2*u + (u - 1)**2 - 2) + 336*100329062400**k*i**4*y**4*(u - 1)**4*(6*u + (u - 1)**2) + 2240*100329062400**k*i**2*y**2*(u - 1)**6*(6*u + (u - 1)**2) + 1680*100329062400**k*i**2*y**2*(u - 1)**4*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 1344*100329062400**k*i**2*y**2*(u - 1)**2*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) + 8064*100329062400**k*(u - 1)**8*(6*u + (u - 1)**2) + 3*100329062400**k*(u - 1)**7*(i**6*y**6*(u - 1) + 21*i**4*y**4*(u - 1)**3 + 56*i**4*y**4*(u - 1) + 280*i**2*y**2*(u - 1)**5 + 672*i**2*y**2*(u - 1)**3 + 840*i**2*y**2*(2*u + (u - 1)**2 - 2) + 1260*(u - 1)**7 + 2880*(u - 1)**5 + 3360*(u - 1)**2*(2*u + (u - 1)**2 - 2)) + 5040*100329062400**k*(u - 1)**6*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 2688*100329062400**k*(u - 1)**4*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) + 1344*100329062400**k*(u - 1)**2*(1800*u + (u - 1)**5 + 62*(u - 1)**4 + 540*(u - 1)**3 + 1560*(u - 1)**2 - 1080) + 768*100329062400**k*(15120*u + (u - 1)**6 + 126*(u - 1)**5 + 1806*(u - 1)**4 + 8400*(u - 1)**3 + 16800*(u - 1)**2 - 10080) - 6*12541132800**k*(u - 1)**14 + 21*14332723200**k*(u - 1)**12*(7*(u - 1)**2 + 4) + 21*16721510400**k*(u - 1)**9*(-2*i**2*y**2*(u - 1)**3 - 48*u - 69*(u - 1)**5 - 72*(u - 1)**3 - 24*(u - 1)**2 + 48) + 105*20065812480**k*(u - 1)**9*(5*i**2*y**2*(u - 1)**3 + 4*i**2*y**2*(u - 1) + 120*u + 70*(u - 1)**5 + 100*(u - 1)**3 + 60*(u - 1)**2 - 120) + 1680*20065812480**k*(u - 1)**8*(6*u + (u - 1)**2) - 13440*25082265600**k*(u - 1)**8*(6*u + (u - 1)**2) + 7*25082265600**k*(u - 1)**7*(-6*i**4*y**4*(u - 1)**3 - 340*i**2*y**2*(u - 1)**5 - 480*i**2*y**2*(u - 1)**3 + 240*i**2*y**2*(-2*u - (u - 1)**2 + 2) - 2901*(u - 1)**7 - 5040*(u - 1)**5 + 4080*(u - 1)**2*(-2*u - (u - 1)**2 + 2)) + 3360*25082265600**k*(u - 1)**6*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) + 7560*33443020800**k*i**2*y**2*(u - 1)**7*(2*u + (u - 1)**2 - 2) + 3360*33443020800**k*i**2*y**2*(u - 1)**6*(6*u + (u - 1)**2) + 35280*33443020800**k*(u - 1)**8*(6*u + (u - 1)**2) + 63*33443020800**k*(u - 1)**8*(3*i**4*y**4*(u - 1)**2 + 4*i**4*y**4 + 75*i**2*y**2*(u - 1)**4 + 140*i**2*y**2*(u - 1)**2 + 469*(u - 1)**6 + 928*(u - 1)**4 + 900*(u - 1)*(2*u + (u - 1)**2 - 2)) + 15120*33443020800**k*(u - 1)**6*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 4032*33443020800**k*(u - 1)**4*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) + 504*50164531200**k*i**4*y**4*(u - 1)**5*(-2*u - (u - 1)**2 + 2) - 6720*50164531200**k*i**2*y**2*(u - 1)**6*(6*u + (u - 1)**2) + 3360*50164531200**k*i**2*y**2*(u - 1)**4*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) - 33600*50164531200**k*(u - 1)**8*(6*u + (u - 1)**2) + 50164531200**k*(u - 1)**7*(6*i**6*y**6*(1 - u) + 504*i**4*y**4*(1 - u) - 231*i**4*y**4*(u - 1)**3 - 3836*i**2*y**2*(u - 1)**5 - 8400*i**2*y**2*(u - 1)**3 + 9240*i**2*y**2*(-2*u - (u - 1)**2 + 2) - 19602*(u - 1)**7 - 42336*(u - 1)**5 + 46032*(u - 1)**2*(-2*u - (u - 1)**2 + 2)) + 18480*50164531200**k*(u - 1)**6*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) + 8064*50164531200**k*(u - 1)**4*(-240*u - (u - 1)**4 - 30*(u - 1)**3 - 150*(u - 1)**2 + 120) + 2688*50164531200**k*(u - 1)**2*(-1800*u - (u - 1)**5 - 62*(u - 1)**4 - 540*(u - 1)**3 - 1560*(u - 1)**2 + 1080)) + 45*2344898178239646054839902558876178841600000000**k*x**8*(u - 1)**8 + 420*390816363039941009139983759812696473600000000**k*x**6*(u - 1)**5*(3*2**k*(u - 1)**5 - 6*3**k*(u - 1)**3*((u - 1)**2 + 2) + 6**k*(u - 1)**3*(i**2*y**2 + 2*(u - 1)**2 + 6) + 12*6**k*(2*u + (u - 1)**2 - 2)) + 420*45233375351845024206016638867210240000000**k*x**3*(u - 1)**3*(15*10368**k*(u - 1)**8*(5*(u - 1)**2 + 4) + 20*12960**k*(u - 1)**5*(-i**2*y**2*(u - 1)**3 - 24*u - 17*(u - 1)**5 - 24*(u - 1)**3 - 12*(u - 1)**2 + 24) + 15*17280**k*(u - 1)**6*(6*i**2*y**2*(u - 1)**2 + 8*i**2*y**2 + 45*(u - 1)**4 + 84*(u - 1)**2) + 1080*17280**k*(u - 1)**5*(2*u + (u - 1)**2 - 2) + 480*17280**k*(u - 1)**4*(6*u + (u - 1)**2) + 240*25920**k*i**2*y**2*(u - 1)**3*(-2*u - (u - 1)**2 + 2) + 2*25920**k*(u - 1)**5*(3*i**4*y**4*(1 - u) + 120*i**2*y**2*(1 - u) - 55*i**2*y**2*(u - 1)**3 - 1320*u - 274*(u - 1)**5 - 600*(u - 1)**3 - 660*(u - 1)**2 + 1320) - 960*25920**k*(u - 1)**4*(6*u + (u - 1)**2) + 480*25920**k*(u - 1)**2*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) + 12*51840**k*i**4*y**4*(u - 1)**4 + 120*51840**k*i**2*y**2*(u - 1)**3*(2*u + (u - 1)**2 - 2) + 160*51840**k*i**2*y**2*(u - 1)**2*(6*u + (u - 1)**2) + 51840**k*(u - 1)**5*(3*i**4*y**4*(u - 1) + 30*i**2*y**2*(u - 1)**3 + 80*i**2*y**2*(u - 1) + 720*u + 120*(u - 1)**5 + 288*(u - 1)**3 + 360*(u - 1)**2 - 720) + 320*51840**k*(u - 1)**4*(6*u + (u - 1)**2) + 240*51840**k*(u - 1)**2*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 192*51840**k*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) - 6*8640**k*(u - 1)**10) + 1260*48852045379992626142497969976587059200000000**k*x**5*(u - 1)**5*(-2*12**k*(u - 1)**6 + 3*16**k*(u - 1)**4*(3*(u - 1)**2 + 4) + 24**k*(u - 1)**3*(2*i**2*y**2*(1 - u) - 24*u - 11*(u - 1)**3 + 24) - 24*24**k*(u - 1)*(2*u + (u - 1)**2 - 2) + 4*48**k*i**2*y**2*(u - 1)**2 + 48**k*(u - 1)**4*(i**2*y**2 + 3*(u - 1)**2 + 8) + 12*48**k*(u - 1)*(2*u + (u - 1)**2 - 2) + 16*48**k*(6*u + (u - 1)**2)) + 75141695851970512394649600000**k*(15120*10402117189632000**k*i**4*y**4*(u - 1)**7*(2*u + (u - 1)**2 - 2) + 302400*10402117189632000**k*i**2*y**2*(u - 1)**8*(6*u + (u - 1)**2) + 100800*10402117189632000**k*i**2*y**2*(u - 1)**6*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 2268000*10402117189632000**k*(u - 1)**10*(6*u + (u - 1)**2) + 30*10402117189632000**k*(u - 1)**9*(6*i**6*y**6*(u - 1) + 441*i**4*y**4*(u - 1)**3 + 756*i**4*y**4*(u - 1) + 9744*i**2*y**2*(u - 1)**5 + 18900*i**2*y**2*(u - 1)**3 + 17640*i**2*y**2*(2*u + (u - 1)**2 - 2) + 59062*(u - 1)**7 + 118188*(u - 1)**5 + 116928*(u - 1)**2*(2*u + (u - 1)**2 - 2)) + 1058400*10402117189632000**k*(u - 1)**8*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 362880*10402117189632000**k*(u - 1)**6*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) + 80640*10402117189632000**k*(u - 1)**4*(1800*u + (u - 1)**5 + 62*(u - 1)**4 + 540*(u - 1)**3 + 1560*(u - 1)**2 - 1080) + 30240*15603175784448000**k*i**4*y**4*(u - 1)**7*(-2*u - (u - 1)**2 + 2) + 20160*15603175784448000**k*i**4*y**4*(u - 1)**5*(-6*u - (u - 1)**3 - 6*(u - 1)**2 + 6) + 369600*15603175784448000**k*i**2*y**2*(u - 1)**7*(-6*u - (u - 1)**3 - 6*(u - 1)**2 + 6) + 201600*15603175784448000**k*i**2*y**2*(u - 1)**5*(-24*u - (u - 1)**4 - 14*(u - 1)**3 - 36*(u - 1)**2 + 24) + 80640*15603175784448000**k*i**2*y**2*(u - 1)**3*(-120*u - (u - 1)**5 - 30*(u - 1)**4 - 150*(u - 1)**3 - 240*(u - 1)**2 + 120) - 1841280*15603175784448000**k*(u - 1)**10*(6*u + (u - 1)**2) + 1008000*15603175784448000**k*(u - 1)**8*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) + 120*15603175784448000**k*(u - 1)**8*(-3*i**6*y**6*(u - 1)**2 - 6*i**6*y**6 - 105*i**4*y**4*(u - 1)**4 - 231*i**4*y**4*(u - 1)**2 - 1764*i**2*y**2*(u - 1)**6 - 3836*i**2*y**2*(u - 1)**4 - 4200*i**2*y**2*(u - 1)*(2*u + (u - 1)**2 - 2) - 9132*(u - 1)**8 - 19602*(u - 1)**6 + 21168*(u - 1)**3*(-2*u - (u - 1)**2 + 2)) + 443520*15603175784448000**k*(u - 1)**6*(-240*u - (u - 1)**4 - 30*(u - 1)**3 - 150*(u - 1)**2 + 120) + 161280*15603175784448000**k*(u - 1)**4*(-1800*u - (u - 1)**5 - 62*(u - 1)**4 - 540*(u - 1)**3 - 1560*(u - 1)**2 + 1080) + 46080*15603175784448000**k*(u - 1)**2*(-15120*u - (u - 1)**6 - 126*(u - 1)**5 - 1806*(u - 1)**4 - 8400*(u - 1)**3 - 16800*(u - 1)**2 + 10080) + 720*31206351568896000**k*i**6*y**6*(u - 1)**5*(2*u + (u - 1)**2 - 2) + 10080*31206351568896000**k*i**4*y**4*(u - 1)**7*(2*u + (u - 1)**2 - 2) + 10080*31206351568896000**k*i**4*y**4*(u - 1)**6*(6*u + (u - 1)**2) + 10080*31206351568896000**k*i**4*y**4*(u - 1)**4*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 100800*31206351568896000**k*i**2*y**2*(u - 1)**8*(6*u + (u - 1)**2) + 67200*31206351568896000**k*i**2*y**2*(u - 1)**6*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 40320*31206351568896000**k*i**2*y**2*(u - 1)**4*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) + 26880*31206351568896000**k*i**2*y**2*(u - 1)**2*(1800*u + (u - 1)**5 + 62*(u - 1)**4 + 540*(u - 1)**3 + 1560*(u - 1)**2 - 1080) + 403200*31206351568896000**k*(u - 1)**10*(6*u + (u - 1)**2) + 241920*31206351568896000**k*(u - 1)**8*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 31206351568896000**k*(u - 1)**8*(5*i**8*y**8 + 120*i**6*y**6*(u - 1)**2 + 360*i**6*y**6 + 3024*i**4*y**4*(u - 1)**4 + 7560*i**4*y**4*(u - 1)**2 + 43200*i**2*y**2*(u - 1)**6 + 100800*i**2*y**2*(u - 1)**4 + 120960*i**2*y**2*(u - 1)*(2*u + (u - 1)**2 - 2) + 201600*(u - 1)**8 + 453600*(u - 1)**6 + 518400*(u - 1)**3*(2*u + (u - 1)**2 - 2)) + 120960*31206351568896000**k*(u - 1)**6*(240*u + (u - 1)**4 + 30*(u - 1)**3 + 150*(u - 1)**2 - 120) + 53760*31206351568896000**k*(u - 1)**4*(1800*u + (u - 1)**5 + 62*(u - 1)**4 + 540*(u - 1)**3 + 1560*(u - 1)**2 - 1080) + 23040*31206351568896000**k*(u - 1)**2*(15120*u + (u - 1)**6 + 126*(u - 1)**5 + 1806*(u - 1)**4 + 8400*(u - 1)**3 + 16800*(u - 1)**2 - 10080) + 11520*31206351568896000**k*(141120*u + (u - 1)**7 + 254*(u - 1)**6 + 5796*(u - 1)**5 + 40824*(u - 1)**4 + 126000*(u - 1)**3 + 191520*(u - 1)**2 - 100800) + 45*3467372396544000**k*(u - 1)**16 - 720*3900793946112000**k*(u - 1)**14*(2*(u - 1)**2 + 1) + 210*4458050224128000**k*(u - 1)**11*(2*i**2*y**2*(u - 1)**3 + 48*u + 91*(u - 1)**5 + 84*(u - 1)**3 + 24*(u - 1)**2 - 48) + 2520*5201058594816000**k*(u - 1)**11*(2*i**2*y**2*(1 - u) - 3*i**2*y**2*(u - 1)**3 - 72*u - 54*(u - 1)**5 - 69*(u - 1)**3 - 36*(u - 1)**2 + 72) - 20160*5201058594816000**k*(u - 1)**10*(6*u + (u - 1)**2) + 252000*6241270313779200**k*(u - 1)**10*(6*u + (u - 1)**2) + 105*6241270313779200**k*(u - 1)**9*(6*i**4*y**4*(u - 1)**3 + 500*i**2*y**2*(u - 1)**5 + 600*i**2*y**2*(u - 1)**3 + 240*i**2*y**2*(2*u + (u - 1)**2 - 2) + 5345*(u - 1)**7 + 8400*(u - 1)**5 + 6000*(u - 1)**2*(2*u + (u - 1)**2 - 2)) + 50400*6241270313779200**k*(u - 1)**8*(36*u + (u - 1)**3 + 14*(u - 1)**2 - 12) + 67200*7801587892224000**k*i**2*y**2*(u - 1)**7*(-6*u - (u - 1)**3 - 6*(u - 1)**2 + 6) - 1142400*7801587892224000**k*(u - 1)**10*(6*u + (u - 1)**2) + 840*7801587892224000**k*(u - 1)**9*(6*i**4*y**4*(1 - u) - 6*i**4*y**4*(u - 1)**3 - 210*i**2*y**2*(u - 1)**5 - 340*i**2*y**2*(u - 1)**3 + 240*i**2*y**2*(-2*u - (u - 1)**2 + 2) - 1602*(u - 1)**7 - 2901*(u - 1)**5 + 2520*(u - 1)**2*(-2*u - (u - 1)**2 + 2)) + 403200*7801587892224000**k*(u - 1)**8*(-36*u - (u - 1)**3 - 14*(u - 1)**2 + 12) + 80640*7801587892224000**k*(u - 1)**6*(-240*u - (u - 1)**4 - 30*(u - 1)**3 - 150*(u - 1)**2 + 120)))/(5*2344898178239646054839902558876178841600000000**k*(u - 1)**8)

# Substitute i with the imaginary unit (1j)
polynomial = polynomial.subs(i, 1j)

# Function to plot zeros for given parameter values
def plot_zeros(poly, k_value, u_value, x_value, x_range=(-20, 20), y_range=(-20, 20), title=""):
    # Substitute the parameter values
    poly_at_values = poly.subs({k: k_value, u: u_value, x: x_value})
    
    # Calculate the roots
    roots = sp.solveset(poly_at_values, y, domain=sp.S.Complexes)
    
    # Convert the roots to a list of complex numbers
    roots_list = [root.evalf() for root in roots]
    
    # Separate real and imaginary parts
    real_parts = [root.as_real_imag()[0] for root in roots_list]
    imag_parts = [root.as_real_imag()[1] for root in roots_list]
    
    # Plot the zeros
    plt.figure(figsize=(10, 8))
    plt.scatter(real_parts, imag_parts, color='blue', marker='o', s=200, label='Zeros')
    plt.axhline(0, color='black', linewidth=1)
    plt.axvline(0, color='black', linewidth=1)
    plt.xlim(x_range[0], x_range[1])
    plt.ylim(y_range[0], y_range[1])
    plt.xlabel("Real Part")
    plt.ylabel("Imaginary Part")
    plt.title(title)
    plt.grid(True)

    # Create a structured filename
    filename = f"zeros_k_{k_value}_u_{u_value}_x_{x_value}.png"
    
    # Save the figure
    plt.savefig(filename, bbox_inches='tight', dpi=300)
    plt.close()  # Close the figure to free memory

# Example plots with different parameter values
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=-3, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=-3)")
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=1, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=1)")
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=-1, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=-1)")
plot_zeros(polynomial, k_value=2, u_value=-2, x_value=3, 
           title="Distribution of Zeros  T^(k,S)_(9,1)(x,y;u) where (k=2, u=-2, x=3)")
